# %%
import pandas as pd
import requests

import sys
# !{sys.executable} -m pip install knoema
import knoema

# %%
climate = pd.read_csv('climate-change_bra.csv')

# %%
clean_climate = climate[['Year', 'Indicator Name', 'Value']]
clean_climate
# Out:
#             Year                            Indicator Name  \
# 0     #date+year                           #indicator+name
# 1           2016                Agricultural land (sq. km)
# 2           2015                Agricultural land (sq. km)
# 3           2014                Agricultural land (sq. km)
# 4           2013                Agricultural land (sq. km)
# ...          ...                                       ...
# 1831        1964  Urban population (% of total population)
# 1832        1963  Urban population (% of total population)
# 1833        1962  Urban population (% of total population)
# 1834        1961  Urban population (% of total population)
# 1835        1960  Urban population (% of total population)
#
#                      Value
# 0     #indicator+value+num
# 1                  2835460
# 2                  2840830
# 3                  2835790
# 4                  2795620
# ...                    ...
# 1831                50.059
# 1832                49.078
# ...

# %%
# Different Indicators of the table

cc = set(clean_climate['Indicator Name'].values)

cc
# Out:
# {'#indicator+name',
#  'Access to electricity (% of population)',
#  'Agricultural irrigated land (% of total agricultural land)',
#  'Agricultural land (% of land area)',
#  'Agricultural land (sq. km)',
#  'Agriculture, forestry, and fishing, value added (% of GDP)',
#  'Annual freshwater withdrawals, total (% of internal resources)',
#  'Annual freshwater withdrawals, total (billion cubic meters)',
#  'Arable land (% of land area)',
#  'Average precipitation in depth (mm per year)',
#  'CO2 emissions (kg per 2010 US$ of GDP)',
#  'CO2 emissions (kg per 2017 PPP $ of GDP)',
#  'CO2 emissions (kg per PPP $ of GDP)',
#  'CO2 emissions (kt)',
#  'CO2 emissions (metric tons per capita)',
#  'CO2 emissions from gaseous fuel consumption (% of total)',
#  'CO2 emissions from gaseous fuel consumption (kt)',
#  'CO2 emissions from liquid fuel consumption (% of total)',
#  'CO2 emissions from liquid fuel consumption (kt)',
#  'CO2 emissions from solid fuel consumption (% of total)',
# ...

# %%
# Emissions

emissions = clean_climate[clean_climate['Indicator Name'] == 'CO2 emissions (kt)']
emissions
# Out:
#      Year      Indicator Name       Value
# 622  2014  CO2 emissions (kt)   529808.16
# 623  2013  CO2 emissions (kt)  503677.118
# 624  2012  CO2 emissions (kt)  470028.726
# 625  2011  CO2 emissions (kt)  439412.943
# 626  2010  CO2 emissions (kt)  419754.156
# 627  2009  CO2 emissions (kt)  367147.374
# 628  2008  CO2 emissions (kt)  387631.236
# 629  2007  CO2 emissions (kt)  363212.683
# 630  2006  CO2 emissions (kt)   347668.27
# 631  2005  CO2 emissions (kt)  347308.904
# 632  2004  CO2 emissions (kt)  337826.042
# 633  2003  CO2 emissions (kt)  321621.569
# 634  2002  CO2 emissions (kt)   332266.87
# 635  2001  CO2 emissions (kt)  337433.673
# 636  2000  CO2 emissions (kt)  327983.814
# 637  1999  CO2 emissions (kt)  320173.104
# 638  1998  CO2 emissions (kt)  312289.054
# 639  1997  CO2 emissions (kt)   300547.32
# 640  1996  CO2 emissions (kt)  284782.887
# 641  1995  CO2 emissions (kt)  258347.484
# 642  1994  CO2 emissions (kt)  242154.012
# ...

# %%
knoema.get('WBWDI2019Jan', frequency='A', Country='BRA', Series='AG.PRD.CREL.MT')
# Out:
# Country                             Brazil
# Series     Cereal production (metric tons)
# Frequency                                A
# 1961-01-01                      15036353.0
# 1962-01-01                      15918336.0
# 1963-01-01                      16616892.0
# 1964-01-01                      16469226.0
# 1965-01-01                      20350793.0
# 1966-01-01                      17867924.0
# 1967-01-01                      20322328.0
# 1968-01-01                      20418801.0
# 1969-01-01                      20549860.0
# 1970-01-01                      23698316.0
# 1971-01-01                      22814265.0
# 1972-01-01                      22703928.0
# 1973-01-01                      23721606.0
# 1974-01-01                      26240014.0
# 1975-01-01                      26238419.0
# 1976-01-01                      31143200.0
# 1977-01-01                      30913834.0
# 1978-01-01                      24033646.0
# 1979-01-01                      27147322.0
# ...
