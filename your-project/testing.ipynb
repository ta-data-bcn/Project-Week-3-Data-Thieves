# %%
from youtube_api import YouTubeDataAPI
import pandas as pd
import requests
from apikey import api_key

# %%
 api_key = {YOUR_KEY_HERE}
yt = YouTubeDataAPI(api_key)
yt.search('Vegeta777')
# Out:
# [{'video_id': 'TBFn748OC_U',
#   'channel_title': 'VEGETTA777',
#   'channel_id': 'UCam8T03EOFBsNdR0thrFHdQ',
#   'video_publish_date': datetime.datetime(2016, 6, 4, 17, 33, 24),
#   'video_title': 'SLITHER.IO - TOP 1! MI MEJOR PARTIDA!',
#   'video_description': 'Regresamos a un nuevo video de Slither.IO y esta vez lo vamos a petarrrrrrrrrrrrrrrr! espero que os guste mucho y gracias por vuestros consejos y ...',
#   'video_category': None,
#   'video_thumbnail': 'https://i.ytimg.com/vi/TBFn748OC_U/hqdefault.jpg',
#   'collection_date': datetime.datetime(2019, 11, 8, 13, 56, 29, 586669)},
#  {'video_id': 'e0HOR7Jq_5k',
#   'channel_title': 'VEGETTA777',
#   'channel_id': 'UCam8T03EOFBsNdR0thrFHdQ',
#   'video_publish_date': datetime.datetime(2013, 1, 5, 22, 8, 37),
#   'video_title': 'JUEGOS DEL HAMBRE CON SUSCRIPTORES: LUCHANDO CONTRA EL DESTINO',
# ...

# %%
url = 'https://www.googleapis.com/youtube/v3/videos?id=TBFn748OC_U%2Ce0HOR7Jq_5k&key={YOUR_KEY_HERE}&part=contentDetails'

# %%
empty_url = 'https://www.googleapis.com/youtube/v3/videos?id=[VIDEO_ID%2C]&key={YOUR_KEY_HERE}&part=contentDetails'

# %%
channel_url = 'https://www.googleapis.com/youtube/v3/channels?part=snippet%2CcontentDetails%2Cstatistics&forUsername=GoogleDevelopers&key={YOUR_KEY_HERE}'

# %%
test_channel = requests.get(channel_url)

# %%
test_channel.json()
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '"j6xRRd8dTPVVptg711_CSPADRfg/5uhe-8AI7CMnQS7hUSeFda1zM58"',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '"j6xRRd8dTPVVptg711_CSPADRfg/y6xLLhcaDRJeOdVwtjxKDhr9S8g"',
#    'id': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#    'snippet': {'title': 'Google Developers',
#     'description': 'The Google Developers channel features talks from events, educational series, best practices, tips, and the latest updates across our products and platforms.',
#     'customUrl': 'googledevelopers',
#     'publishedAt': '2007-08-23T00:34:43.000Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/a/AGF-l78iFtAxyRZcUBzG91kbKMES19z-zGW5KT20_g=s88-c-k-c0xffffffff-no-rj-mo',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/a/AGF-l78iFtAxyRZcUBzG91kbKMES19z-zGW5KT20_g=s240-c-k-c0xffffffff-no-rj-mo',
#       'width': 240,
#       'height': 240},
# ...

# %%
search_url = 'https://www.googleapis.com/youtube/v3/search?key={YOUR_KEY_HERE}&channelId=UCam8T03EOFBsNdR0thrFHdQ&part=snippet,id&order=date&maxResults=20'

# %%
test_search = requests.get(search_url)

# %%
test_search.json()
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': '"j6xRRd8dTPVVptg711_CSPADRfg/dJaOVeyq63zpDWabavKlxmQdkpI"',
#  'nextPageToken': 'CBQQAA',
#  'regionCode': 'ES',
#  'pageInfo': {'totalResults': 56821, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '"j6xRRd8dTPVVptg711_CSPADRfg/zR-LdiGErToK77cw02KLIdFUTv8"',
#    'id': {'kind': 'youtube#video', 'videoId': 'fJIx5HVxzS8'},
#    'snippet': {'publishedAt': '2019-11-08T11:47:13.000Z',
#     'channelId': 'UCam8T03EOFBsNdR0thrFHdQ',
#     'title': 'DEATH STRANDING - UN MUNDO DESCONOCIDO (Hideo Kojima)',
#     'description': 'Compra Death Stranding para Playstation: https://store.playstation.com/es-es/product/EP9000-CUSA12606_00-DEATHSTPREORDPSN 🦄 Hazte miembro del ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fJIx5HVxzS8/default_live.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fJIx5HVxzS8/mqdefault_live.jpg',
# ...

# %%
search_url_medchannel = 'https://www.googleapis.com/youtube/v3/search?key={YOUR_KEY_HERE}&channelId=UCa3DVlGH2_QhvwuWlPa6MDQ&part=snippet,id&order=date&maxResults=50'

# %%
medchannel = requests.get(search_url_medchannel)

# %%
medchannel.json()
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': '"j6xRRd8dTPVVptg711_CSPADRfg/zdSNFmoMAN6-5pFJ7K6dUov4VJw"',
#  'nextPageToken': 'CBQQAA',
#  'regionCode': 'ES',
#  'pageInfo': {'totalResults': 198, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '"j6xRRd8dTPVVptg711_CSPADRfg/iSvCJtE15ADxnYtcRiV-jYK8siA"',
#    'id': {'kind': 'youtube#video', 'videoId': 'i89Hq_d1PfA'},
#    'snippet': {'publishedAt': '2019-11-04T18:01:20.000Z',
#     'channelId': 'UCa3DVlGH2_QhvwuWlPa6MDQ',
#     'title': 'Mi Experiencia Tocando en Televisión (con Agoney)',
#     'description': 'Cómo es ir a tocar a la tele? ¿En qué se diferencia de una actuación normal? Y bueno, ya que nos ponemos... ¡¿Cómo es una actuación normal?! ¿Cómo se ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/i89Hq_d1PfA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/i89Hq_d1PfA/mqdefault.jpg',
#       'width': 320,
# ...

# %%
search_url_medchannel_p2 = 'https://www.googleapis.com/youtube/v3/search?key={YOUR_KEY_HERE}&channelId=UCa3DVlGH2_QhvwuWlPa6MDQ&part=snippet,id&order=date&maxResults=50&nextPageToken=CBQQAA'

# %%
medchannel_p2 = requests.get(search_url_medchannel_p2)

# %%
medchannel_p2.json()
# Out:
#  'snippet': {'publishedAt': '2019-03-25T18:29:59.000Z',
#     'channelId': 'UCa3DVlGH2_QhvwuWlPa6MDQ',
#     'title': 'El Instrumento Que Revolucionó La Música: El Sintetizador (ft. QuantumFracture)',
#     'description': 'Los sintetizadores son un instrumento mágico. Capaz de fabricar sonido a partir de su estructura más básica: ondas. Para adentrarnos en cómo funcionan ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yttwGJumrrY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/yttwGJumrrY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/yttwGJumrrY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Jaime Altozano',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"j6xRRd8dTPVVptg711_CSPADRfg/OedGyGI57FODTkTCljGlr3abo-Y"',
# ...
