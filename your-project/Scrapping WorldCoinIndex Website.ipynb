# %%
# Importing every library needed
import requests
from bs4 import BeautifulSoup
import pandas as pd
from requests import get
import re

# %%
# Scrapping cryptocurrency prices
url = 'https://www.worldcoinindex.com/trending/overview'
html = requests.get(url).content
html_soup = BeautifulSoup(html, 'html.parser')
print(html_soup.prettify())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# Scrapping cryptocurrency volume for last year (2 of march 2019)
url = 'https://web.archive.org/web/20190302000818/https://www.worldcoinindex.com/exchange'
html = requests.get(url).content
html_soup = BeautifulSoup(html, 'html.parser')

# %%
print(html_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html style="background-color: #FFF">
#  <head>
#   <script src="//archive.org/includes/analytics.js?v=cf34f82" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    window.addEventListener('DOMContentLoaded',function(){var v=archive_analytics.values;v.service='wb';v.server_name='wwwb-app101.us.archive.org';v.server_ms=1603;archive_analytics.send_pageview({});});
#   </script>
#   <script charset="utf-8" src="/_static/js/ait-client-rewrite.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    WB_wombat_Init("https://web.archive.org/web/", "20190302000818", "www.worldcoinindex.com");
#   </script>
#   <script charset="utf-8" src="/_static/js/wbhack.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    __wbhack.init('https://web.archive.org/web');
#   </script>
#   <link href="/_static/css/banner-styles.css" rel="stylesheet" type="text/css"/>
# ...

# %%
# Scrapping cryptocurrency volume for 20th of April 

url = 'https://www.worldcoinindex.com/exchange'
html = requests.get(url).content
html_soup = BeautifulSoup(html, 'html.parser')

# %%
print(html_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html style="background-color: #FFF">
#  <head>
#   <meta content="text/html" http-equiv="Content-Type"/>
#   <meta charset="utf-8">
#    <meta content="yes" name="mobile-web-app-capable"/>
#    <meta content="Find all cryptocurrency exchanges and other information." name="description">
#     <meta content="WorldCoinIndex, worldcoinindex.com, World, Coin, Index, worldcoin, coinindex, worldindex, Cryptocoins, Crypto, traded, exchanges, ranked,marketcap, coins, Cryptocurrency ,coinprices, price, price, lasttradetime, trade, last, market, cap, trading, traded, volume" name="keywords"/>
#     <meta content="width=device-width, initial-scale=1, user-scalable = no" name="viewport"/>
#     <meta content="yes" name="apple-mobile-web-app-capable">
#      <meta content="efad6eed15cdd45139ef34d287cc06ff" name="propeller"/>
#      <title>
#       List of all cryptocurrency exchanges - WorldCoinIndex
#      </title>
#      <link href="/manifest.json?v=4" rel="manifest"/>
# ...
