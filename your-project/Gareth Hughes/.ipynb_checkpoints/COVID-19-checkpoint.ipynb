# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import seaborn as sns
import requests
from pandas_datareader import data
# Out:
# C:\Users\Gareth\Anaconda3\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
csv = 'owid-covid-data.csv'

# %%
df = pd.read_csv(csv)

# %% [markdown]
# ## PANDAS DataAnalysis with WHO COVID19 Data

# %%
df
# Out:
#       iso_code  location        date  total_cases  new_cases  total_deaths  \
# 0          ABW     Aruba  2020-03-13            2          2             0
# 1          ABW     Aruba  2020-03-20            4          2             0
# 2          ABW     Aruba  2020-03-24           12          8             0
# 3          ABW     Aruba  2020-03-25           17          5             0
# 4          ABW     Aruba  2020-03-26           19          2             0
# ...        ...       ...         ...          ...        ...           ...
# 11396      ZWE  Zimbabwe  2020-04-13           14          0             3
# 11397      ZWE  Zimbabwe  2020-04-14           17          3             3
# 11398      ZWE  Zimbabwe  2020-04-15           17          0             3
# 11399      ZWE  Zimbabwe  2020-04-16           23          6             3
# 11400      ZWE  Zimbabwe  2020-04-17           24          1             3
#
#        new_deaths  total_cases_per_million  new_cases_per_million  \
# 0               0                   18.733                 18.733
# 1               0                   37.465                 18.733
# 2               0                  112.395                 74.930
# 3               0                  159.227                 46.831
# 4               0                  177.959                 18.733
# ...           ...                      ...                    ...
# 11396           0                    0.942                  0.000
# 11397           0                    1.144                  0.202
# 11398           0                    1.144                  0.000
# 11399           0                    1.547                  0.404
# 11400           0                    1.615                  0.067
#
#        total_deaths_per_million  new_deaths_per_million  total_tests  \
# 0                         0.000                     0.0          NaN
# 1                         0.000                     0.0          NaN
# 2                         0.000                     0.0          NaN
# 3                         0.000                     0.0          NaN
# 4                         0.000                     0.0          NaN
# ...                         ...                     ...          ...
# 11396                     0.202                     0.0          NaN
# 11397                     0.202                     0.0          NaN
# 11398                     0.202                     0.0          NaN
# 11399                     0.202                     0.0          NaN
# 11400                     0.202                     0.0          NaN
#
#        new_tests  total_tests_per_thousand  new_tests_per_thousand tests_units
# 0            NaN                       NaN                     NaN         NaN
# 1            NaN                       NaN                     NaN         NaN
# 2            NaN                       NaN                     NaN         NaN
# 3            NaN                       NaN                     NaN         NaN
# 4            NaN                       NaN                     NaN         NaN
# ...          ...                       ...                     ...         ...
# 11396        NaN                       NaN                     NaN         NaN
# 11397        NaN                       NaN                     NaN         NaN
# 11398        NaN                       NaN                     NaN         NaN
# 11399        NaN                       NaN                     NaN         NaN
# 11400        NaN                       NaN                     NaN         NaN
#
# [11401 rows x 16 columns]

# %%
df.describe()
# Out:
#          total_cases     new_cases  total_deaths    new_deaths  \
# count   11401.000000  11401.000000  11401.000000  11401.000000
# mean     3064.109552    185.384879    167.676520     12.730199
# std     21704.677850   1382.745007   1330.798624    105.329207
# min         0.000000      0.000000      0.000000      0.000000
# 25%         0.000000      0.000000      0.000000      0.000000
# 50%        14.000000      1.000000      0.000000      0.000000
# 75%       233.000000     20.000000      3.000000      0.000000
# max    671331.000000  35527.000000  33284.000000   4928.000000
#
#        total_cases_per_million  new_cases_per_million  \
# count             11236.000000           11236.000000
# mean                194.333601              11.608349
# std                 785.818422              70.616721
# min                   0.000000               0.000000
# 25%                   0.000000               0.000000
# 50%                   2.097000               0.030000
# 75%                  55.169000               2.684250
# max               12552.301000            4944.376000
#
#        total_deaths_per_million  new_deaths_per_million   total_tests  \
# count              11236.000000            11236.000000  2.083000e+03
# mean                   7.105144                0.505230  8.091202e+04
# std                   50.888747                3.859358  2.434716e+05
# min                    0.000000                0.000000  1.000000e+00
# 25%                    0.000000                0.000000  2.407000e+03
# 50%                    0.000000                0.000000  1.558400e+04
# 75%                    0.392000                0.000000  5.520350e+04
# max                 1119.689000              176.793000  3.242755e+06
#
#            new_tests  total_tests_per_thousand  new_tests_per_thousand
# count    1822.000000               2083.000000             1823.000000
# mean     5798.558727                  4.303788                0.265041
# std     17458.515803                  9.845400                0.544606
# min         1.000000                  0.000000                0.000000
# 25%       276.500000                  0.111000                0.015000
# 50%      1198.500000                  0.796000                0.080000
# 75%      4115.000000                  4.278000                0.321000
# max    229268.000000                111.308000                7.243000

# %%
df.size
# Out:
# 182416

# %%
df.dtypes
# Out:
# iso_code                     object
# location                     object
# date                         object
# total_cases                   int64
# new_cases                     int64
# total_deaths                  int64
# new_deaths                    int64
# total_cases_per_million     float64
# new_cases_per_million       float64
# total_deaths_per_million    float64
# new_deaths_per_million      float64
# total_tests                 float64
# new_tests                   float64
# total_tests_per_thousand    float64
# new_tests_per_thousand      float64
# tests_units                  object
# dtype: object

# %%
pd.to_datetime(df['date'])
# Out:
# 0       2020-03-13
# 1       2020-03-20
# 2       2020-03-24
# 3       2020-03-25
# 4       2020-03-26
#            ...
# 11396   2020-04-13
# 11397   2020-04-14
# 11398   2020-04-15
# 11399   2020-04-16
# 11400   2020-04-17
# Name: date, Length: 11401, dtype: datetime64[ns]

# %%
df['iso_code'].unique()
# Out:
# array(['ABW', 'AFG', 'AGO', 'AIA', 'ALB', 'AND', 'ARE', 'ARG', 'ARM',
#        'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BES', 'BFA',
#        'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BMU', 'BOL',
#        'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CHE', 'CHL',
#        'CHN', 'CIV', 'CMR', 'COD', 'COG', 'COL', 'CPV', 'CRI', 'CUB',
#        'CUW', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI', 'DMA', 'DNK', 'DOM',
#        'DZA', 'ECU', 'EGY', 'ERI', 'ESP', 'EST', 'ETH', 'FIN', 'FJI',
#        'FLK', 'FRA', 'FRO', 'GAB', 'GBR', 'GEO', 'GGY', 'GHA', 'GIB',
#        'GIN', 'GMB', 'GNB', 'GNQ', 'GRC', 'GRD', 'GRL', 'GTM', 'GUM',
#        'GUY', 'HKG', 'HND', 'HRV', 'HTI', 'HUN', 'IDN', 'IMN', 'IND',
#        'IRL', 'IRN', 'IRQ', 'ISL', 'ISR', 'ITA', 'JAM', 'JEY', 'JOR',
#        'JPN', 'KAZ', 'KEN', 'KGZ', 'KHM', 'KNA', 'KOR', 'KWT', 'LAO',
#        'LBN', 'LBR', 'LBY', 'LCA', 'LIE', 'LKA', 'LTU', 'LUX', 'LVA',
#        'MAR', 'MCO', 'MDA', 'MDG', 'MDV', 'MEX', 'MKD', 'MLI', 'MLT',
#        'MMR', 'MNE', 'MNG', 'MNP', 'MOZ', 'MRT', 'MSR', 'MUS', 'MWI',
#        'MYS', 'NAM', 'NCL', 'NER', 'NGA', 'NIC', 'NLD', 'NOR', 'NPL',
#        'NZL', 'OMN', 'PAK', 'PAN', 'PER', 'PHL', 'PNG', 'POL', 'PRI',
#        'PRT', 'PRY', 'PSE', 'PYF', 'QAT', 'RKS', 'ROU', 'RUS', 'RWA',
#        'SAU', 'SDN', 'SEN', 'SGP', 'SLE', 'SLV', 'SMR', 'SOM', 'SRB',
#        'SSD', 'STP', 'SUR', 'SVK', 'SVN', 'SWE', 'SWZ', 'SXM', 'SYC',
#        'SYR', 'TCA', 'TCD', 'TGO', 'THA', 'TLS', 'TTO', 'TUN', 'TUR',
#        'TWN', 'TZA', 'UGA', 'UKR', 'URY', 'USA', 'UZB', 'VAT', 'VCT',
#        'VEN', 'VGB', 'VIR', 'VNM', 'YEM', 'ZAF', 'ZMB', 'ZWE'],
#       dtype=object)

# %%
df['iso_code'].unique().size
# Out:
# 206

# %%
df['location'].unique()
# Out:
# array(['Aruba', 'Afghanistan', 'Angola', 'Anguilla', 'Albania', 'Andorra',
#        'United Arab Emirates', 'Argentina', 'Armenia',
#        'Antigua and Barbuda', 'Australia', 'Austria', 'Azerbaijan',
#        'Burundi', 'Belgium', 'Benin', 'Bonaire Sint Eustatius and Saba',
#        'Burkina Faso', 'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei', 'Bhutan', 'Botswana',
#        'Central African Republic', 'Canada', 'Switzerland', 'Chile',
#        'China', "Cote d'Ivoire", 'Cameroon',
#        'Democratic Republic of Congo', 'Congo', 'Colombia', 'Cape Verde',
#        'Costa Rica', 'Cuba', 'Curacao', 'Cayman Islands', 'Cyprus',
#        'Czech Republic', 'Germany', 'Djibouti', 'Dominica', 'Denmark',
#        'Dominican Republic', 'Algeria', 'Ecuador', 'Egypt', 'Eritrea',
#        'Spain', 'Estonia', 'Ethiopia', 'Finland', 'Fiji',
#        'Falkland Islands', 'France', 'Faeroe Islands', 'Gabon',
#        'United Kingdom', 'Georgia', 'Guernsey', 'Ghana', 'Gibraltar',
#        'Guinea', 'Gambia', 'Guinea-Bissau', 'Equatorial Guinea', 'Greece',
#        'Grenada', 'Greenland', 'Guatemala', 'Guam', 'Guyana', 'Hong Kong',
#        'Honduras', 'Croatia', 'Haiti', 'Hungary', 'Indonesia',
#        'Isle of Man', 'India', 'Ireland', 'Iran', 'Iraq', 'Iceland',
#        'Israel', 'Italy', 'Jamaica', 'Jersey', 'Jordan', 'Japan',
#        'Kazakhstan', 'Kenya', 'Kyrgyzstan', 'Cambodia',
#        'Saint Kitts and Nevis', 'South Korea', 'Kuwait', 'Laos',
#        'Lebanon', 'Liberia', 'Libya', 'Saint Lucia', 'Liechtenstein',
#        'Sri Lanka', 'Lithuania', 'Luxembourg', 'Latvia', 'Morocco',
#        'Monaco', 'Moldova', 'Madagascar', 'Maldives', 'Mexico',
#        'Macedonia', 'Mali', 'Malta', 'Myanmar', 'Montenegro', 'Mongolia',
#        'Northern Mariana Islands', 'Mozambique', 'Mauritania',
#        'Montserrat', 'Mauritius', 'Malawi', 'Malaysia', 'Namibia',
#        'New Caledonia', 'Niger', 'Nigeria', 'Nicaragua', 'Netherlands',
#        'Norway', 'Nepal', 'New Zealand', 'Oman', 'Pakistan', 'Panama',
#        'Peru', 'Philippines', 'Papua New Guinea', 'Poland', 'Puerto Rico',
#        'Portugal', 'Paraguay', 'Palestine', 'French Polynesia', 'Qatar',
#        'Kosovo', 'Romania', 'Russia', 'Rwanda', 'Saudi Arabia', 'Sudan',
#        'Senegal', 'Singapore', 'Sierra Leone', 'El Salvador',
#        'San Marino', 'Somalia', 'Serbia', 'South Sudan',
#        'Sao Tome and Principe', 'Suriname', 'Slovakia', 'Slovenia',
#        'Sweden', 'Swaziland', 'Sint Maarten (Dutch part)', 'Seychelles',
#        'Syria', 'Turks and Caicos Islands', 'Chad', 'Togo', 'Thailand',
#        'Timor', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Taiwan',
#        'Tanzania', 'Uganda', 'Ukraine', 'Uruguay', 'United States',
#        'Uzbekistan', 'Vatican', 'Saint Vincent and the Grenadines',
#        'Venezuela', 'British Virgin Islands',
#        'United States Virgin Islands', 'Vietnam', 'Yemen', 'South Africa',
#        'Zambia', 'Zimbabwe'], dtype=object)

# %%
# Earliest reported date in the database.
first_reported = df[df['date'] == df['date'].min()]

first_reported[first_reported['total_cases'] > 0]
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 2014      CHN    China  2019-12-31           27         27             0
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 2014           0                    0.019                  0.019
#
#       total_deaths_per_million  new_deaths_per_million  total_tests  \
# 2014                       0.0                     0.0          NaN
#
#       new_tests  total_tests_per_thousand  new_tests_per_thousand tests_units
# 2014        NaN                       NaN                     NaN         NaN

# %%
first_reported.location.unique().size
# Out:
# 66

# %%
latest_report = df[df['date'] == df['date'].max()]
latest_report.location.unique().size
# Out:
# 205

# %%
df = df.fillna(0)

# %%
df['total_tests_per_thousand'].mode()
# Out:
# 0    0.0
# dtype: float64

# %%
df['total_tests_per_thousand'].mean()
# Out:
# 0.7863161126217015

# %% [markdown]
# ## Analysis of Min Max of Different Parameters

# %% [markdown]
# ### Tests per thousand, best country.

# %%
df[df['total_tests_per_thousand'] == df['total_tests_per_thousand'].max()]
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 5470      ISL  Iceland  2020-04-16         1727          7             8
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 5470           0                 5060.806                 20.513
#
#       total_deaths_per_million  new_deaths_per_million  total_tests  \
# 5470                    23.443                     0.0      38204.0
#
#       new_tests  total_tests_per_thousand  new_tests_per_thousand  \
# 5470      818.0                   111.308                   2.383
#
#         tests_units
# 5470  units unclear

# %% [markdown]
# ### Highest new deaths.

# %%
df[df['new_deaths'] == df['new_deaths'].max()]
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 11001      USA  United States  2020-04-16       639664      30148
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 11001         30985        4928                 1932.504
#
#        new_cases_per_million  total_deaths_per_million  \
# 11001                 91.081                     93.61
#
#        new_deaths_per_million  total_tests  new_tests  \
# 11001                  14.888          0.0        0.0
#
#        total_tests_per_thousand  new_tests_per_thousand tests_units
# 11001                       0.0                     0.0           0

# %% [markdown]
# ### Highest total deaths.

# %%
df[df['total_deaths'] == df['total_deaths'].max()]
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 11002      USA  United States  2020-04-17       671331      31667
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 11002         33284        2299                 2028.174
#
#        new_cases_per_million  total_deaths_per_million  \
# 11002                  95.67                   100.555
#
#        new_deaths_per_million  total_tests  new_tests  \
# 11002                   6.946          0.0        0.0
#
#        total_tests_per_thousand  new_tests_per_thousand tests_units
# 11002                       0.0                     0.0           0

# %% [markdown]
# ### Highest total cases.

# %%
df[df['total_cases'] == df['total_cases'].max()]
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 11002      USA  United States  2020-04-17       671331      31667
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 11002         33284        2299                 2028.174
#
#        new_cases_per_million  total_deaths_per_million  \
# 11002                  95.67                   100.555
#
#        new_deaths_per_million  total_tests  new_tests  \
# 11002                   6.946          0.0        0.0
#
#        total_tests_per_thousand  new_tests_per_thousand tests_units
# 11002                       0.0                     0.0           0

# %% [markdown]
# ## Subsetting based on a specific date to get monthly updates.

# %%
april = df[df.date == '2020-04-17']

# %%
april_tc = april[['date','location','total_cases','total_deaths','total_tests']]
april_tc
april_tc.columns
# Out:
# Index(['date', 'location', 'total_cases', 'total_deaths', 'total_tests'], dtype='object')

# %%
march = df[df.date == '2020-03-31']

# %%
feb = df[df.date == '2020-02-29']

# %%
jan = df[df.date == '2020-01-31']

# %%
first_reported = df[df.date == '2019-12-31']

# %%
march_tc = march[['date','location','total_cases','total_deaths','total_tests']]

# %% [markdown]
# ### Month_tc = Dataframes whereby Total_Cases, Total_Deaths and Total_Tests are subset based from a specific date.

# %%
# here are the total number of cases as March 31st 2020.
march_tc
# Out:
#              date                location  total_cases  total_deaths  \
# 107    2020-03-31             Afghanistan          141             4
# 134    2020-03-31                  Angola            7             2
# 156    2020-03-31                Anguilla            2             0
# 196    2020-03-31                 Albania          223            12
# 231    2020-03-31                 Andorra          370             8
# ...           ...                     ...          ...           ...
# 11133  2020-03-31  British Virgin Islands            3             0
# 11265  2020-03-31                 Vietnam          229             0
# 11325  2020-03-31            South Africa         1326             3
# 11355  2020-03-31                  Zambia           35             0
# 11383  2020-03-31                Zimbabwe            7             1
#
#        total_tests
# 107            0.0
# 134            0.0
# 156            0.0
# 196            0.0
# 231            0.0
# ...            ...
# 11133          0.0
# 11265          0.0
# 11325      41072.0
# 11355          0.0
# 11383          0.0
#
# [193 rows x 5 columns]

# %%
# here are the total number of cases as Feb 29th 2020.
feb_tc = feb[['date','location','total_cases','total_deaths','total_tests']]

# %%
feb_tc
# Out:
#              date              location  total_cases  total_deaths  \
# 86     2020-02-29           Afghanistan            1             0
# 309    2020-02-29  United Arab Emirates           19             0
# 454    2020-02-29               Armenia            0             0
# 583    2020-02-29             Australia           25             0
# 692    2020-02-29               Austria            7             0
# ...           ...                   ...          ...           ...
# 10157  2020-02-29                Sweden           12             0
# 10471  2020-02-29              Thailand           42             0
# 10718  2020-02-29                Taiwan           39             1
# 10954  2020-02-29         United States           66             0
# 11235  2020-02-29               Vietnam           16             0
#
#        total_tests
# 86             0.0
# 309            0.0
# 454            0.0
# 583            0.0
# 692         1649.0
# ...            ...
# 10157          0.0
# 10471          0.0
# 10718          0.0
# 10954         18.0
# 11235          0.0
#
# [71 rows x 5 columns]

# %%
jan_tc = jan[['date','location','total_cases','total_deaths','total_tests']]
jan_tc
# Out:
#              date              location  total_cases  total_deaths  \
# 57     2020-01-31           Afghanistan            0             0
# 280    2020-01-31  United Arab Emirates            4             0
# 425    2020-01-31               Armenia            0             0
# 554    2020-01-31             Australia            7             0
# 663    2020-01-31               Austria            0             0
# ...           ...                   ...          ...           ...
# 10128  2020-01-31                Sweden            0             0
# 10442  2020-01-31              Thailand           14             0
# 10689  2020-01-31                Taiwan            9             0
# 10925  2020-01-31         United States            6             0
# 11206  2020-01-31               Vietnam            5             0
#
#        total_tests
# 57             0.0
# 280            0.0
# 425            0.0
# 554            0.0
# 663            0.0
# ...            ...
# 10128          0.0
# 10442          0.0
# 10689          0.0
# 10925          0.0
# 11206          0.0
#
# [67 rows x 5 columns]

# %%
first_reported_tc = first_reported[['date','location','total_cases','total_deaths','total_tests']]
first_reported_tc
# Out:
#              date              location  total_cases  total_deaths  \
# 26     2019-12-31           Afghanistan            0             0
# 249    2019-12-31  United Arab Emirates            0             0
# 394    2019-12-31               Armenia            0             0
# 523    2019-12-31             Australia            0             0
# 632    2019-12-31               Austria            0             0
# ...           ...                   ...          ...           ...
# 10097  2019-12-31                Sweden            0             0
# 10411  2019-12-31              Thailand            0             0
# 10658  2019-12-31                Taiwan            0             0
# 10894  2019-12-31         United States            0             0
# 11175  2019-12-31               Vietnam            0             0
#
#        total_tests
# 26             0.0
# 249            0.0
# 394            0.0
# 523            0.0
# 632            0.0
# ...            ...
# 10097          0.0
# 10411          0.0
# 10658          0.0
# 10894          0.0
# 11175          0.0
#
# [66 rows x 5 columns]

# %%
first_reported_tc[first_reported_tc['total_cases'] > 0 ]
# Out:
#             date location  total_cases  total_deaths  total_tests
# 2014  2019-12-31    China           27             0          0.0

# %% [markdown]
# ### Testing of Stockmarket Module of Pandas

# %%
start_date = '2016-12-31'
end_date = '2020-04-19'
panel_data = data.DataReader('^IBEX', 'yahoo', start_date, end_date)

# %%
panel_data
# Out:
#                    High          Low         Open        Close       Volume  \
# Date
# 2017-01-03  9552.099609  9438.799805  9448.299805  9494.700195  280878700.0
# 2017-01-04  9538.400391  9424.099609  9522.099609  9462.900391  238018000.0
# 2017-01-05  9507.200195  9413.599609  9427.900391  9488.200195  221279300.0
# 2017-01-06  9515.900391  9451.200195  9487.000000  9515.900391  144566300.0
# 2017-01-09  9536.900391  9446.200195  9536.900391  9492.799805  194378000.0
# ...                 ...          ...          ...          ...          ...
# 2020-04-09  7116.799805  6918.700195  7049.299805  7070.600098  240348600.0
# 2020-04-14  7209.700195  7080.299805  7209.700195  7108.600098  259986200.0
# 2020-04-15  7086.799805  6816.399902  7065.600098  6839.500000  289924500.0
# 2020-04-16  6950.899902  6733.100098  6930.799805  6763.399902  237962600.0
# 2020-04-17  7000.299805  6845.000000  6942.500000  6875.799805  251272600.0
#
#               Adj Close
# Date
# 2017-01-03  9494.700195
# 2017-01-04  9462.900391
# 2017-01-05  9488.200195
# 2017-01-06  9515.900391
# 2017-01-09  9492.799805
# ...                 ...
# 2020-04-09  7070.600098
# 2020-04-14  7108.600098
# 2020-04-15  6839.500000
# 2020-04-16  6763.399902
# 2020-04-17  6875.799805
#
# [839 rows x 6 columns]

# %% [markdown]
# ### Subsetting of Spain from overall Dataframe, useful for specific market analysis?

# %%
spain = df[df['location'] == 'Spain']

# %%
spain
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 3320      ESP    Spain  2019-12-31            0          0             0
# 3321      ESP    Spain  2020-01-01            0          0             0
# 3322      ESP    Spain  2020-01-02            0          0             0
# 3323      ESP    Spain  2020-01-03            0          0             0
# 3324      ESP    Spain  2020-01-04            0          0             0
# ...       ...      ...         ...          ...        ...           ...
# 3424      ESP    Spain  2020-04-13       166019       4167         16972
# 3425      ESP    Spain  2020-04-14       169496       3477         17489
# 3426      ESP    Spain  2020-04-15       172541       3045         18056
# 3427      ESP    Spain  2020-04-16       177633       5092         18579
# 3428      ESP    Spain  2020-04-17       182816       5183         19130
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 3320           0                    0.000                  0.000
# 3321           0                    0.000                  0.000
# 3322           0                    0.000                  0.000
# 3323           0                    0.000                  0.000
# 3324           0                    0.000                  0.000
# ...          ...                      ...                    ...
# 3424         619                 3550.845                 89.125
# 3425         517                 3625.212                 74.367
# 3426         567                 3690.339                 65.127
# 3427         523                 3799.248                108.909
# 3428         551                 3910.103                110.855
#
#       total_deaths_per_million  new_deaths_per_million  total_tests  \
# 3320                     0.000                   0.000          0.0
# 3321                     0.000                   0.000          0.0
# 3322                     0.000                   0.000          0.0
# 3323                     0.000                   0.000          0.0
# 3324                     0.000                   0.000          0.0
# ...                        ...                     ...          ...
# 3424                   363.000                  13.239          0.0
# 3425                   374.058                  11.058          0.0
# 3426                   386.185                  12.127          0.0
# 3427                   397.371                  11.186          0.0
# 3428                   409.156                  11.785          0.0
#
#       new_tests  total_tests_per_thousand  new_tests_per_thousand tests_units
# 3320        0.0                       0.0                     0.0           0
# 3321        0.0                       0.0                     0.0           0
# 3322        0.0                       0.0                     0.0           0
# 3323        0.0                       0.0                     0.0           0
# 3324        0.0                       0.0                     0.0           0
# ...         ...                       ...                     ...         ...
# 3424        0.0                       0.0                     0.0           0
# 3425        0.0                       0.0                     0.0           0
# 3426        0.0                       0.0                     0.0           0
# 3427        0.0                       0.0                     0.0           0
# 3428        0.0                       0.0                     0.0           0
#
# [109 rows x 16 columns]

# %%
transposed_df = spain.T
transposed_df.to_excel('spain_dataset.xlsx')

# %% [markdown]
# ## Subsetting Spain dates into one DataFrame

# %%
spain_sets = spain[(spain['date'] == '2020-01-31')
                   | (spain['date'] == '2020-02-29')
                   | (spain['date'] == '2020-03-16')
                    | (spain['date'] == '2020-03-31')
                   | (spain['date'] == '2020-04-08')
                   | (spain['date'] == '2020-04-17')]

# %%
spain_sets
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 3351      ESP    Spain  2020-01-31            0          0             0
# 3380      ESP    Spain  2020-02-29           34          9             0
# 3396      ESP    Spain  2020-03-16         7753       2000           288
# 3411      ESP    Spain  2020-03-31        85195       6398          7340
# 3419      ESP    Spain  2020-04-08       140510       5478         13798
# 3428      ESP    Spain  2020-04-17       182816       5183         19130
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 3351           0                    0.000                  0.000
# 3380           0                    0.727                  0.192
# 3396         152                  165.823                 42.776
# 3411         812                 1822.167                136.842
# 3419         743                 3005.254                117.164
# 3428         551                 3910.103                110.855
#
#       total_deaths_per_million  new_deaths_per_million  total_tests  \
# 3351                     0.000                   0.000          0.0
# 3380                     0.000                   0.000          0.0
# 3396                     6.160                   3.251          0.0
# 3411                   156.989                  17.367          0.0
# 3419                   295.114                  15.891          0.0
# 3428                   409.156                  11.785          0.0
#
#       new_tests  total_tests_per_thousand  new_tests_per_thousand tests_units
# 3351        0.0                       0.0                     0.0           0
# 3380        0.0                       0.0                     0.0           0
# 3396        0.0                       0.0                     0.0           0
# 3411        0.0                       0.0                     0.0           0
# 3419        0.0                       0.0                     0.0           0
# 3428        0.0                       0.0                     0.0           0

# %%
spain_sets.plot(x = 'date', y = 'total_cases', kind = 'bar')

# %%
sort = df.sort_values(by = 'total_cases', ascending = False)

# %%
sort
# Out:
#       iso_code        location        date  total_cases  new_cases  \
# 11002      USA   United States  2020-04-17       671331      31667
# 11001      USA   United States  2020-04-16       639664      30148
# 11000      USA   United States  2020-04-15       609516      26922
# 10999      USA   United States  2020-04-14       582594      25023
# 10998      USA   United States  2020-04-13       557571      27620
# ...        ...             ...         ...          ...        ...
# 2540       CZE  Czech Republic  2020-02-12            0          0
# 2539       CZE  Czech Republic  2020-02-11            0          0
# 2538       CZE  Czech Republic  2020-02-10            0          0
# 2537       CZE  Czech Republic  2020-02-09            0          0
# 8366       NZL     New Zealand  2020-01-27            0          0
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 11002         33284        2299                 2028.174
# 11001         30985        4928                 1932.504
# 11000         26057        2408                 1841.423
# 10999         23649        1541                 1760.089
# 10998         22108        1500                 1684.491
# ...             ...         ...                      ...
# 2540              0           0                    0.000
# 2539              0           0                    0.000
# 2538              0           0                    0.000
# 2537              0           0                    0.000
# 8366              0           0                    0.000
#
#        new_cases_per_million  total_deaths_per_million  \
# 11002                 95.670                   100.555
# 11001                 91.081                    93.610
# 11000                 81.335                    78.721
# 10999                 75.598                    71.447
# 10998                 83.443                    66.791
# ...                      ...                       ...
# 2540                   0.000                     0.000
# 2539                   0.000                     0.000
# 2538                   0.000                     0.000
# 2537                   0.000                     0.000
# 8366                   0.000                     0.000
#
#        new_deaths_per_million  total_tests  new_tests  \
# 11002                   6.946          0.0        0.0
# 11001                  14.888          0.0        0.0
# 11000                   7.275    3242755.0   161135.0
# 10999                   4.656    3081620.0   146614.0
# 10998                   4.532    2935006.0   129114.0
# ...                       ...          ...        ...
# 2540                    0.000         75.0        1.0
# 2539                    0.000         74.0        2.0
# 2538                    0.000         72.0        8.0
# 2537                    0.000         64.0        0.0
# 8366                    0.000          0.0        0.0
#
#        total_tests_per_thousand  new_tests_per_thousand  \
# 11002                     0.000                   0.000
# 11001                     0.000                   0.000
# 11000                     9.784                   0.486
# 10999                     9.298                   0.442
# 10998                     8.856                   0.390
# ...                         ...                     ...
# 2540                      0.007                   0.000
# 2539                      0.007                   0.000
# 2538                      0.007                   0.001
# 2537                      0.006                   0.000
# 8366                      0.000                   0.000
#
#                                        tests_units
# 11002                                            0
# 11001                                            0
# 11000  inconsistent units (COVID Tracking Project)
# 10999  inconsistent units (COVID Tracking Project)
# 10998  inconsistent units (COVID Tracking Project)
# ...                                            ...
# 2540                               tests performed
# 2539                               tests performed
# 2538                               tests performed
# 2537                               tests performed
# 8366                                             0
#
# [11401 rows x 16 columns]

# %% [markdown]
# ## COVID19 Plots with Time

# %%
april_top10 = sort[sort['date'] == '2020-04-17'].head(15)
april_top10['location'].unique()
# Out:
# array(['United States', 'Spain', 'Italy', 'Germany', 'France',
#        'United Kingdom', 'China', 'Iran', 'Turkey', 'Belgium', 'Brazil',
#        'Canada', 'Netherlands', 'Russia', 'Switzerland'], dtype=object)

# %%
april_top10 = sort[sort['date'] == '2020-04-17'].head(15)
april_top10.plot(x = 'location', y = 'total_cases', kind = 'bar', legend = None)
plt.gca().invert_xaxis()
plt.title("Total Coronavirus Cases as of 2020-04-17")
plt.xlabel("Location")
plt.ylabel("Cases")
plt.gcf().set_size_inches(20,10)
plt.savefig('2020-04-17.png', bbox_inches='tight')
plt.show()

# %%
earlyapril_top10 = sort[sort['date'] == '2020-04-08'].head(10)

# %%
earlyapril_top10.plot(x = 'location', y = 'total_cases', kind = 'bar', legend = None)
plt.gca().invert_xaxis()
plt.title("Total Coronavirus Cases as of 2020-04-08")
plt.xlabel("Location")
plt.ylabel("Cases")
plt.gcf().set_size_inches(20,10)
plt.savefig('2020-04-08.png', bbox_inches='tight')
plt.show()

# %%
endmarch_top10 = sort[sort['date'] == '2020-03-31'].head(10)

# %%
endmarch_top10.plot(x = 'location', y = 'total_cases', kind = 'bar', legend = None)
plt.gca().invert_xaxis()
plt.title("Total Coronavirus Cases as of 2020-03-31")
plt.xlabel("Location")
plt.ylabel("Cases")
plt.gcf().set_size_inches(20,10)
plt.savefig('2020-03-31.png', bbox_inches='tight')
plt.show()

# %%
midmarch_top10 = sort[sort['date'] == '2020-03-16'].head(10)

# %%
midmarch_top10.plot(x = 'location', y = 'total_cases', kind = 'bar', legend = None)
plt.gca().invert_xaxis()
plt.title("Total Coronavirus Cases as of 2020-03-16")
plt.xlabel("Location")
plt.ylabel("Cases")
plt.gcf().set_size_inches(20,10)
plt.savefig('2020-03-16.png', bbox_inches='tight')
plt.show()

# %%
startmarch_top10 = sort[sort['date'] == '2020-03-08'].head(10)

# %%
startmarch_top10.plot(x = 'location', y = 'total_cases', kind = 'bar', legend = None)
plt.gca().invert_xaxis()
plt.title("Total Coronavirus Cases as of 2020-03-08")
plt.xlabel("Location")
plt.ylabel("Cases")
plt.gcf().set_size_inches(20,10)
plt.savefig('2020-03-08.png', bbox_inches='tight')
plt.show()

# %%
feb_top10 = sort[sort['date'] == '2020-02-29'].head(10)

# %%
feb_top10.plot(x = 'location', y = 'total_cases', kind = 'bar', legend = None)
plt.gca().invert_xaxis()
plt.title("Total Coronavirus Cases as of 2020-02-29")
plt.xlabel("Location")
plt.ylabel("Cases")
plt.gcf().set_size_inches(20,10)
plt.savefig('2020-02-29.png', bbox_inches='tight')
plt.show()

# %%
jan_top10 = sort[sort['date'] == '2020-01-30'].head(3)
jan_top10.plot(x = 'location', y = 'total_cases', kind = 'bar', legend = None)
plt.gca().invert_xaxis()
plt.title("Total Coronavirus Cases as of 2020-01-30")
plt.ylabel("Cases")
plt.gcf().set_size_inches(10,5)
plt.show()

# %% [markdown]
# ### Plots with Time with Fixed Countries

# %%
select15 = df[(df['location'] == 'United States') |
               (df['location'] == 'Spain') |
               (df['location'] == 'Italy') |
               (df['location'] == 'Germany') |
                (df['location'] == 'France') |
                (df['location'] == 'United Kingdom') |
                (df['location'] == 'China') |
                (df['location'] == 'Iran') |
                (df['location'] == 'Turkey') |
                (df['location'] == 'Belgium') |
                (df['location'] == 'Brazil') |
                (df['location'] == 'Canada') |
                (df['location'] == 'Netherlands') |
                (df['location'] == 'Russia') |
                (df['location'] == 'Switzerland')]

# %%
select15_time = select15[((select15['date'] == '2020-01-31')
                   | (select15['date'] == '2020-02-29')
                   | (select15['date'] == '2020-03-16')
                    | (select15['date'] == '2020-03-31')
                   | (select15['date'] == '2020-04-08')
                   | (select15['date'] == '2020-04-17'))]

# %%
select15_time.tail(10)
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 10625      TUR         Turkey  2020-03-16           18         16
# 10640      TUR         Turkey  2020-03-31        10827       1610
# 10648      TUR         Turkey  2020-04-08        34109       3892
# 10657      TUR         Turkey  2020-04-17        74193       4801
# 10925      USA  United States  2020-01-31            6          1
# 10954      USA  United States  2020-02-29           66          6
# 10970      USA  United States  2020-03-16         3774        823
# 10985      USA  United States  2020-03-31       164620      21595
# 10993      USA  United States  2020-04-08       398809      30613
# 11002      USA  United States  2020-04-17       671331      31667
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 10625             0           0                    0.213
# 10640           168          37                  128.375
# 10648           725          76                  404.427
# 10657          1643         125                  879.699
# 10925             0           0                    0.018
# 10954             0           0                    0.199
# 10970            69          12                   11.402
# 10985          3170         661                  497.337
# 10993         12895        1906                 1204.851
# 11002         33284        2299                 2028.174
#
#        new_cases_per_million  total_deaths_per_million  \
# 10625                  0.190                     0.000
# 10640                 19.090                     1.992
# 10648                 46.147                     8.596
# 10657                 56.925                    19.481
# 10925                  0.003                     0.000
# 10954                  0.018                     0.000
# 10970                  2.486                     0.208
# 10985                 65.241                     9.577
# 10993                 92.486                    38.957
# 11002                 95.670                   100.555
#
#        new_deaths_per_million  total_tests  new_tests  \
# 10625                   0.000          0.0        0.0
# 10640                   0.439      92403.0    15422.0
# 10648                   0.901     247768.0    18900.0
# 10657                   1.482          0.0        0.0
# 10925                   0.000          0.0        0.0
# 10954                   0.000         18.0        9.0
# 10970                   0.036      42286.0    14760.0
# 10985                   1.997    1066365.0   106972.0
# 10993                   5.758    2212566.0   139536.0
# 11002                   6.946          0.0        0.0
#
#        total_tests_per_thousand  new_tests_per_thousand  \
# 10625                     0.000                   0.000
# 10640                     1.102                   0.184
# 10648                     2.955                   0.225
# 10657                     0.000                   0.000
# 10925                     0.000                   0.000
# 10954                     0.000                   0.000
# 10970                     0.128                   0.045
# 10985                     3.217                   0.323
# 10993                     6.676                   0.421
# 11002                     0.000                   0.000
#
#                                        tests_units
# 10625                                            0
# 10640                                units unclear
# 10648                                units unclear
# 10657                                            0
# 10925                                            0
# 10954  inconsistent units (COVID Tracking Project)
# 10970  inconsistent units (COVID Tracking Project)
# 10985  inconsistent units (COVID Tracking Project)
# 10993  inconsistent units (COVID Tracking Project)
# 11002                                            0

# %%
jan_top10 = select15_time[select15_time['date'] == '2020-01-31']

# %%
jan_top10
jan_top10.plot(x = 'location', y = 'total_cases', kind = 'bar', legend = None, color=['black','red','gold','royalblue','deepskyblue','peru','orangered','lime','cyan','indigo','orchid','maroon','oldlace','g','forestgreen'])
plt.gca().invert_xaxis()
plt.rc('font', size= 15) 
plt.title("Total Coronavirus Cases as of 2020-01-31")
plt.ylabel("Cases")
plt.gcf().set_size_inches(10,5)
plt.savefig('Top 15 2020-01-31.png', bbox_inches='tight')
plt.show()

# %%
feb_top10 = select15_time[select15_time['date'] == '2020-02-29']

# %%
feb_top10.plot(x = 'location', y = 'total_cases', kind = 'bar', legend = None, color=['black','red','gold','royalblue','deepskyblue','peru','orangered','lime','cyan','indigo','orchid','maroon','oldlace','g','forestgreen'])
plt.gca().invert_xaxis()
plt.rc('font', size= 15) 
plt.title("Total Coronavirus Cases as of 2020-02-29")
plt.ylabel("Cases")
plt.gcf().set_size_inches(10,5)
plt.savefig('Top 15 2020-02-29.png', bbox_inches='tight')
plt.show()

# %%
'''select15_time = select15[((select15['date'] == '2020-01-31')
                   | (select15['date'] == '2020-02-29')
                   | (select15['date'] == '2020-03-16')
                    | (select15['date'] == '2020-03-31')
                   | (select15['date'] == '2020-04-08')
                   | (select15['date'] == '2020-04-17'))]'''

# %%
marstart_top10 = select15_time[select15_time['date'] == '2020-03-16']

# %%
marstart_top10.plot(x = 'location', y = 'total_cases', kind = 'bar', legend = None, color=['black','red','gold','royalblue','deepskyblue','peru','orangered','lime','cyan','indigo','orchid','maroon','oldlace','g','forestgreen'])
plt.gca().invert_xaxis()
plt.rc('font', size= 15) 
plt.title("Total Coronavirus Cases as of 2020-03-16")
plt.ylabel("Cases")
plt.gcf().set_size_inches(10,5)
plt.savefig('Top 15 2020-03-16.png', bbox_inches='tight')
plt.show()

# %%
marend_top10 = select15_time[select15_time['date'] == '2020-03-16']

# %%
marend_top10.plot(x = 'location', y = 'total_cases', kind = 'bar', legend = None, color=['black','red','gold','royalblue','deepskyblue','peru','orangered','lime','cyan','indigo','orchid','maroon','oldlace','g','forestgreen'])
plt.gca().invert_xaxis()
plt.rc('font', size= 15) 
plt.title("Total Coronavirus Cases as of 2020-03-31")
plt.ylabel("Cases")
plt.gcf().set_size_inches(10,5)
plt.savefig('Top 15 2020-03-31.png', bbox_inches='tight')
plt.show()

# %%
aprilstart_top10 = select15_time[select15_time['date'] == '2020-04-08']

# %%
aprilstart_top10.plot(x = 'location', y = 'total_cases', kind = 'bar', legend = None, color=['black','red','gold','royalblue','deepskyblue','peru','orangered','lime','cyan','indigo','orchid','maroon','oldlace','g','forestgreen'])
plt.gca().invert_xaxis()
plt.rc('font', size= 15) 
plt.title("Total Coronavirus Cases as of 2020-04-08")
plt.ylabel("Cases")
plt.gcf().set_size_inches(10,5)
plt.savefig('Top 15 2020-04-08.png', bbox_inches='tight')
plt.show()

# %%
aprilend_top10 = select15_time[select15_time['date'] == '2020-04-17']

# %%
aprilend_top10.plot(x = 'location', y = 'total_cases', kind = 'bar', legend = None, color=['black','red','gold','royalblue','deepskyblue','peru','orangered','lime','cyan','indigo','orchid','maroon','oldlace','g','forestgreen'])
plt.gca().invert_xaxis()
plt.rc('font', size= 15) 
plt.title("Total Coronavirus Cases as of 2020-04-17")
plt.ylabel("Cases")
plt.gcf().set_size_inches(10,5)
plt.savefig('Top 15 2020-04-17.png', bbox_inches='tight')
plt.show()
