# %%
#youtube API key:
api_key = 'AIzaSyBBouPW0Ug4r5tWzccLsSJetvMZL4edv-Q'

#if your are not so sure about how to get this key

# %%
import os
import google_auth_oauthlib.flow
import googleapiclient.discovery
import googleapiclient.errors

import pandas as pd

# %%
# If we just use "googleapiclient.discovery" we will have an error.
# We have to use the following line ir order to be able to use the 'build' function.

from googleapiclient.discovery import build

youtube = build('youtube', 'v3', developerKey = api_key )

# %%
# this is a good sign

type(youtube)
# Out:
# googleapiclient.discovery.Resource

# %% [markdown]
# ''' Lets try to make a new request to the api. Im using this tutorial: https://www.youtube.com/watch?v=b_jOJNUD350
#  Note: It is funny Im using a youtube video to learn how to use the youtube's API.
# '''
# req = youtube.search().list(q = ['harry potter', 'book','jk rowling'], part = 'snippet', type = 'video', maxResults = 20)
#
# '''See how I said here 'hey youtube, give me 20 results. By default it gives you 5 results.''''

# %%
#doing this I verify this is a 'request' as you can see below.

# type(req)

# %%
# Then, I create the execute:



'''

res = req.execute()

#We want to see the raw result. I use for this 'print(res)'
#print(res)
#print('------------------------------')
#Now, what are different features of each result? I use for this 'res['items']'
#print(res['items'])
#print('------------------------------')
# I can see the name of the videos picking a specific feature of the Item.
for item in res['items']:
    print('items:\n', item)
    print('snippet:\n', item['snippet'])
    print('snippet tittle:\n', item['snippet']['title'])
    print('------------------------------')
    
'''
  
    
'''
Ok. 
Using this we can see the snippet and the id of a video.
What could be interesing is too see



'''
# Out:
# '\nOk. \nUsing this we can see the snippet and the id of a video.\nWhat could be interesing is too see\n\n\n\n'

# %%
#now we are trying to search videos using data time

from datetime import datetime

# %%
start_time = datetime(year=2010, month=1, day=1).strftime('%Y-%m-%dT%H:%M:%SZ')
end_time = datetime(year=2011, month=1, day=1).strftime('%Y-%m-%dT%H:%M:%SZ')

res = youtube.search().list(part='snippet',
                            q=['harry potter', 'book', 'jk rowling'],
                            type='video',
                            publishedAfter=start_time,
                            publishedBefore=end_time,
                            maxResults=50).execute()

for item in sorted(res['items'], key=lambda x:x['snippet']['publishedAt']):
    print(item['snippet']['title'], item['snippet']['publishedAt'], item['id']['videoId'])
# Out:
# The Science, Magic and Medicine of Harry Potters World 2010-02-08T19:48:17.000Z -VMQrtJ93_w
# Book Eight. a Harry Potter song 2010-03-19T02:38:10.000Z Fzy36ItRm3w
# JK Rowling - Quick Inspiring Story 2010-03-23T06:27:27.000Z 4qFBLZ_k56E
# Harry Potter Book Trailer 2010-03-24T16:54:20.000Z s8zBR1l4Tgc
# BOOK REVIEW #2 [4/1/10] Harry Potter and the Sorcerer&#39;s Stone by: JK Rowling 2010-04-01T23:32:30.000Z 8VL1WJ3Kh1c
# JK Rowling Reads Harry Potter At White House Egg Roll 2010-04-05T19:19:32.000Z nEaJyGsnFd4
# JK Rowling Reading Harry Potter Book 1 2010-04-05T21:11:21.000Z x1PDpLayjAg
# J.K. Rowling Reads from &quot;Harry Potter and the Sorcerer&#39;s Stone&quot; 2010-04-06T00:15:25.000Z a5Uvf-_zYSs
# J.K. Rowling Reads 1st Harry Potter Book At White House Egg 2010-04-06T01:22:59.000Z yV_RPAKQAGM
# The last Harry Potter Movie is Out - And It&#39;s Dark 2010-11-19T00:29:59.000Z nNeFXMWlf6E
# book review : harry potter and the sorcerer&#39;s stone by J.K. ROWLING 2010-11-26T04:09:48.000Z n95whhD0Hb0
# Harry Potter and the Order of the Phoenix Book Review 2010-11-27T17:32:53.000Z IFDkmyOXEW8
# The Magic of JK Rowling 2010-12-02T15:19:19.000Z E92Ls8SxWTM
# J K Rowling shows off her bra 2010-12-12T09:12:36.000Z 2tPhoa33ZUM
# J.K. Rowling and the second Harry Potter book 2010-12-14T00:12:01.000Z KCmxGljmHTY
# Project for Awesome: The Harry Potter Alliance 2010-12-17T15:59:34.000Z gIEmO0L8Hkc
# Ein Jahr mit JK Rowling [HD] - Part 1/3 2010-12-22T21:32:09.000Z L3xDFs8yfOQ
# Ein Jahr mit JK Rowling [HD] - Part 3/3 2010-12-23T00:39:32.000Z Z60MtAbS9Qo
# J.K. Rowling&#39;s Biography from A&amp;E Part 2 of 4 2010-12-23T08:12:50.000Z rgWTUZyM7EQ
# J.K. Rowling&#39;s Biography from A&amp;E Part 1 of 4 2010-12-23T08:20:01.000Z ycrLE46w6tY
# Harry Potter and the Philosophers stone VS Sorcerer&#39;s Stone Bloomsbury VS scholastics 2010-12-28T00:25:12.000Z cfLEHDAOhBs

# %%
# now we are going to show the max number of views, according to the youtube API website:
# https://developers.google.com/youtube/v3/docs/search/list

# %%
res = youtube.search().list(part='snippet',
                            q=['harry potter', 'book'],
                            type='video',
                            publishedAfter=start_time,
                            publishedBefore=end_time,
                            maxResults=50).execute()

video_info = []
for item in sorted(res['items'], key=lambda x:x['snippet']['publishedAt']):
    print(item['snippet']['title'], item['snippet']['publishedAt'], item['id']['videoId'])
    video_info.append(item['snippet'])

video_info
# Out:
# Emma Watson and Rupert Grint talking about Reading Harry Potter Books on the Deathly Hallows Set 2010-01-10T00:03:34.000Z TUQJNFO62ng
# Harry Potter and the Goblet of Fire Deleted Scene: Hogwarts School Song 2010-01-23T21:03:21.000Z OOXBKdi9E7Y
# Details on Ollivander&#39;s Wand Shop at The Wizarding World of Harry Potter at Universal Orlando 2010-01-28T15:23:59.000Z XmG0K3eEfgE
# Seven Harry Potter Books in Seven Minutes 2010-01-31T09:57:57.000Z HtBYd6yap38
# The Science, Magic and Medicine of Harry Potters World 2010-02-08T19:48:17.000Z -VMQrtJ93_w
# Harry Potter&#39;s Herbology Class with Rare Books 2010-02-24T18:03:48.000Z EzglA2SFFT0
# Harry Potter Book Trailer 2010-03-24T16:54:20.000Z s8zBR1l4Tgc
# TTMThursday- Harry Potter and the Obsessed Book Collector 2010-04-01T21:09:43.000Z CrG_J74wVJY
# J.K. Rowling Reads from &quot;Harry Potter and the Sorcerer&#39;s Stone&quot; 2010-04-06T00:15:25.000Z a5Uvf-_zYSs
# J.K. Rowling Reads 1st Harry Potter Book At White House Egg 2010-04-06T01:22:59.000Z yV_RPAKQAGM
# Harry Potter Book Report 2010-04-21T01:11:17.000Z wVTYQGcA-6I
# Harry Potter Starts a Band! 2010-05-06T23:14:05.000Z UPVolA1K1Ug
...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-VMQrtJ93_w/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/-VMQrtJ93_w/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/-VMQrtJ93_w/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'University of Alabama at Birmingham',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-02-24T18:03:48.000Z',
#   'channelId': 'UCPXWOwTvTD3Wg-xSdopS_6g',
#   'title': 'Harry Potter&#39;s Herbology Class with Rare Books',
#   'description': "In the Harry Potter books and movies, Harry attends a class on herbology taught by Professor Sprout. Ed Valauskas uses the Garden's rare book collection to ...",
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/EzglA2SFFT0/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/EzglA2SFFT0/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/EzglA2SFFT0/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'chicagobotanicgarden',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-03-24T16:54:20.000Z',
#   'channelId': 'UCR79JJpUPtZFwr7477T0MOg',
#   'title': 'Harry Potter Book Trailer',
#   'description': 'No matter what you think you know... The real magic of Harry Potter lies within. Experience the adventure from the beginning.',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/s8zBR1l4Tgc/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/s8zBR1l4Tgc/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/s8zBR1l4Tgc/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Scholastic',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-04-01T21:09:43.000Z',
#   'channelId': 'UCil-HokkVZabu_9xpbvuK6A',
#   'title': 'TTMThursday- Harry Potter and the Obsessed Book Collector',
#   'description': "My Talk To Me Tuesday is 2 days late. So its TTMThursday this week. I'm going to start filming them on Mondays if I can. In this episode I show off my very ...",
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/CrG_J74wVJY/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/CrG_J74wVJY/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/CrG_J74wVJY/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Lola B.',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-04-06T00:15:25.000Z',
#   'channelId': 'UCDGknzyQfNiThyt4vg4MlTQ',
#   'title': 'J.K. Rowling Reads from &quot;Harry Potter and the Sorcerer&#39;s Stone&quot;',
#   'description': 'Author J.K. Rowling reads from her book "Harry Potter and the Sorcerer\'s Stone" at the 2010 White House Easter Egg Roll. April 5, 2010.',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/a5Uvf-_zYSs/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/a5Uvf-_zYSs/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/a5Uvf-_zYSs/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'The Obama White House',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-04-06T01:22:59.000Z',
#   'channelId': 'UCDIPsk87a6D3QqS0DeAUMPA',
#   'title': 'J.K. Rowling Reads 1st Harry Potter Book At White House Egg',
#   'description': "Author J.K. Rowling treats kids at the White House Easter Egg Roll to a reading of her first Harry Potter book -- Harry Potter and the Sorcerer's Stone.",
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yV_RPAKQAGM/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/yV_RPAKQAGM/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/yV_RPAKQAGM/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Michael McIntee',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-04-21T01:11:17.000Z',
#   'channelId': 'UCqAk1pVQQAn6lZ_Irlfdh3g',
#   'title': 'Harry Potter Book Report',
#   'description': "This is our book report on Harry Potter and the Deathly Hallows, a segment on pages 342 through 345. There's also an interview w/ the characters and some ...",
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wVTYQGcA-6I/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/wVTYQGcA-6I/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/wVTYQGcA-6I/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'girlfromMarz97',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-05-06T23:14:05.000Z',
#   'channelId': 'UC5O84sz_dGXE0kPGr0Cdofg',
#   'title': 'Harry Potter Starts a Band!',
#   'description': 'Like every teenager Harry Potter wants to play in a band. So get ready to be blown away.. ..by Dragonballs. Music: Summer and Starlight - This time ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UPVolA1K1Ug/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/UPVolA1K1Ug/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/UPVolA1K1Ug/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'PistolShrimps',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-05-24T13:09:27.000Z',
#   'channelId': 'UCL7Q3zcGPf3wdcGS5yGi-oA',
#   'title': 'Stars of Harry Potter visit Hogsmeade',
#   'description': 'Emma Watson, Robbie Coltrane, and others visit the new theme park at Universal Studios Florida.',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Rr4zIpqrro4/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/Rr4zIpqrro4/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/Rr4zIpqrro4/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Simon Willmore',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-06-05T23:03:35.000Z',
#   'channelId': 'UCqy0uX9AxRSKEj2UfBh3RkQ',
#   'title': 'Tom Hanks Finds New Harry Potter Book',
#   'description': 'SNAPE KILLS DUMBLEDORE! SPOILER ALERT! (Oh wait, I should have put that first.) http://www.ytmnd.com/',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/o1ARdZPEwsQ/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/o1ARdZPEwsQ/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/o1ARdZPEwsQ/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'YTMND2012',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-06-13T20:48:17.000Z',
#   'channelId': 'UCTlyM5PU8y_mg75Y_-kxHGg',
#   'title': 'Part 2 Harry Potter Book Club editions',
#   'description': 'Just some random info on book club editions and first edition. Actually kinda confusing the way I tried to explain but may help some.',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/IzNl04vslEk/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/IzNl04vslEk/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/IzNl04vslEk/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'eviltig',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-06-15T04:58:55.000Z',
#   'channelId': 'UCTlyM5PU8y_mg75Y_-kxHGg',
#   'title': 'Harry Potter 4 book cases, US and UK Collections',
#   'description': 'Filmed with a olympus pen epl1 As some of you know I got a new camera called the Pen e pl1 and ive been having a blast with it so now Im just looking around ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/thY_nn7X-FA/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/thY_nn7X-FA/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/thY_nn7X-FA/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'eviltig',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-06-18T18:13:24.000Z',
#   'channelId': 'UCYdNtGaJkrtn04tmsmRrWlw',
#   'title': 'Grand opening of the Wizarding World of Harry Potter with Daniel Radcliffe &amp; other movie stars',
#   'description': "On the morning of June 18, 2010, the first guests were officially welcomed into Universal Orlando's new Wizarding World of Harry Potter addition to the Islands of ...",
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ramuWv8rqpg/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/ramuWv8rqpg/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/ramuWv8rqpg/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Inside the Magic',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-06-26T15:43:54.000Z',
#   'channelId': 'UCkSNCh4WskRUEd7L9Z24WhQ',
#   'title': 'Book Review - Harry Potter Series',
#   'description': 'Looong overdue. Enjoy! :) Potter theme does not belong to me and such...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/iqjPi5P2Lqg/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/iqjPi5P2Lqg/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/iqjPi5P2Lqg/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'WriterfromNowhere',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-06-27T02:56:33.000Z',
#   'channelId': 'UCEZC34bJm1SXe0MY0sBncUg',
#   'title': 'Harry Potter Book and the Half-Blood Prince - TV Intro (fanmade)',
#   'description': "Sorry I kept everyone waiting. My life's been in a general state of flux with relocating to California and several other things coming up, so I've had to shake the ...",
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SeLtAmnURgQ/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/SeLtAmnURgQ/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/SeLtAmnURgQ/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Jordacar',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-06-28T23:06:50.000Z',
#   'channelId': 'UCjmJDM5pRKbUlVIzDYYWb6g',
#   'title': 'Harry Potter and the Deathly Hallows Official HD Trailer',
#   'description': 'Become a fan on Facebook: http://www.facebook.com/harrypottermovie www.harrypotter.com "Harry Potter and the Deathly Hallows," the seventh and final ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9hXH0Ackz6w/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/9hXH0Ackz6w/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/9hXH0Ackz6w/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Warner Bros. Pictures',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-06-30T17:22:23.000Z',
#   'channelId': 'UCKy1dAqELo0zrOtPkf0eTMw',
#   'title': 'Harry Potter and the Deathly Hallows: Part I Trailer [HD]',
#   'description': "Based on the seventh and final book in J.K. Rowling's literary series. The film's release is split into two parts.",
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LWEc_rwF4KA/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/LWEc_rwF4KA/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/LWEc_rwF4KA/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'IGN',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-07-01T04:12:29.000Z',
#   'channelId': 'UCT3ig7slsnaO5RJ9L5rxHbg',
#   'title': 'Harry Potter - Fun on the Set * from the Collectors Edition of LEGO HP*',
#   'description': 'Yesterday I got Lego Harry Potter Collectors Edition, and here is some footage of the fun the cast and crew have on the HP set :D.',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/84nUq4uStQA/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/84nUq4uStQA/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/84nUq4uStQA/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'RadcliffeWatson',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-07-11T07:50:49.000Z',
#   'channelId': 'UCYCEK7i8Uq-XtFtWolofxFg',
#   'title': 'Harry Potter and the Deathly Hallows: Part 1 | The video game OFFICIAL [HD] gameplay trailer #1',
#   'description': 'The video game will be released at the same time as the movie hits the theatres (November 17th, 2010) " Harry Potter und die Heiligtümer des Todes - Teil 1 ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3qQw5qjrrCs/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/3qQw5qjrrCs/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/3qQw5qjrrCs/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'moviemaniacsDE',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-07-20T22:59:23.000Z',
#   'channelId': 'UCbdTs9fanN16NOrYSmq1JeQ',
#   'title': 'Harry Potter and the Deathly Hallows &quot;The Story&quot; Featurette Official (HD)',
#   'description': 'http://Facebook.com/ClevverTV - Become a Fan! http://Twitter.com/ClevverTV - Follow Us! Go behind the scenes of one of the most anticipated films of the year.',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4OSW3nzE3jk/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/4OSW3nzE3jk/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/4OSW3nzE3jk/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'ClevverTV',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-08-18T00:46:15.000Z',
#   'channelId': 'UC8Gk82EhubhwdEBzV7uBBlg',
#   'title': 'LEGO Harry Potter(Year 3) - 13~News From Azkaban[Part 1]',
#   'description': 'Recorded by me, Ultimate7Life A.K.A SirSky~~! ＃ (Playthrough for PC version) Year 3 - Harry Potter and the Prisoner of Azkaban - Stop the Monster Book of ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/K0teQETyB9s/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/K0teQETyB9s/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/K0teQETyB9s/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'SkYari Temaki',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-08-22T21:54:16.000Z',
#   'channelId': 'UC9HWGsebsP6bZziTv6bDYiA',
#   'title': 'Unlikely Lines From the Final Harry Potter Book',
#   'description': '',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/D-IhimHc_oQ/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/D-IhimHc_oQ/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/D-IhimHc_oQ/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'MockTheWeekFan0',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-09-05T13:46:57.000Z',
#   'channelId': 'UC0v-tlzsn0QZwJnkiaUSJVQ',
#   'title': '50 Book Spoilers in 4 Minutes',
#   'description': 'NEW Videos Every Week! Subscribe: http://goo.gl/nxzGJv Spoilers Playlist: http://goo.gl/bg92e9 Time for a whole new way to be educated! Novels and books ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AapzgNJgtAw/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/AapzgNJgtAw/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/AapzgNJgtAw/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'FBE',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-09-13T21:40:48.000Z',
#   'channelId': 'UCApwHGBiNg31FQmIlIRLSvw',
#   'title': 'Harry Potter Film Wizardry',
#   'description': "Harry Potter: Film Wizardry gives readers a front row seat to the magical journey that brought J.K. Rowling's wizarding world to the big screen. Step off Platform ...",
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nw76LnI7PEw/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/nw76LnI7PEw/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/nw76LnI7PEw/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Dey Street Books',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-09-19T02:03:50.000Z',
#   'channelId': 'UCyen54Me63XkQH1eYWwlkCA',
#   'title': 'The Couples of Harry Potter ♥ and the Second Generation',
#   'description': 'This is a tribute to the couples (past present and future) of the amazing books HARRY POTTER :) ...okay I know it is a longish video, but I couldnt resist making ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/rNVZqmQcshI/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/rNVZqmQcshI/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/rNVZqmQcshI/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Lauren Samsel',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-09-23T01:41:48.000Z',
#   'channelId': 'UCbdTs9fanN16NOrYSmq1JeQ',
#   'title': 'Harry Potter and the Deathly Hallows Part 1 Trailer 2 Official HD',
#   'description': 'http://bit.ly/HPDH2-TRL - Watch HP and the Deathly Hallows Part 2 Official Trailer! http://Facebook.com/ClevverTV - Become a Fan! Harry Potter and the Deathly ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/YzfEH0UPEBo/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/YzfEH0UPEBo/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/YzfEH0UPEBo/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'ClevverTV',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-09-23T01:51:47.000Z',
#   'channelId': 'UCjmJDM5pRKbUlVIzDYYWb6g',
#   'title': 'Harry Potter and the Deathly Hallows - Main Trailer',
#   'description': 'http://www.facebook.com/harrypottermovie http://www.harrypotter.com Harry Potter and the Deathly Hallows, the seventh and final adventure in the Harry Potter ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Su1LOpjvdZ4/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/Su1LOpjvdZ4/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/Su1LOpjvdZ4/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Warner Bros. Pictures',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-09-24T15:46:28.000Z',
#   'channelId': 'UCqqkw6bhP-uL9LOyftoJnmQ',
#   'title': 'All Harry Potter Special Edition Books in 3 1/2 mins',
#   'description': "Harry potter and the Sorcerer's Stone: Special 10 year Anniversary Edition * Harry Potter and the Sorcerer's Stone *Green leather Edition Harry Potter and the ...",
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FiPu8v7rJi0/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/FiPu8v7rJi0/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/FiPu8v7rJi0/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'WizardrockFan1',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-10-14T11:07:52.000Z',
#   'channelId': 'UCQ6MkM5Mr5nwoFMDJs8ViQw',
#   'title': 'Harry Potter: A Pop-up Book by Bruce Foster, Andrew Williamson',
#   'description': 'This collectible Harry Potter pop-up book, based on the creative development of the films, features exquisite original artwork by Andrew Williamson, concept ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/C8A_dqvMPc8/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/C8A_dqvMPc8/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/C8A_dqvMPc8/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Waterstones',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-10-18T08:37:12.000Z',
#   'channelId': 'UCTlyM5PU8y_mg75Y_-kxHGg',
#   'title': 'Harry Potter and the order of the pheonix deathly Hallows and Half blood Prince deluxe books',
#   'description': 'I finally picked up the Halfblood prince deluxe edition that completes the three sleeved books in the collection. I found it on the way back from vacation at a outlet ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/q6_9KrM4CEE/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/q6_9KrM4CEE/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/q6_9KrM4CEE/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'eviltig',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-10-19T14:31:56.000Z',
#   'channelId': 'UCLlnZlfJ1HlHWYBzF9vcrnQ',
#   'title': 'Harry Potter And The Deathly Hallows Part 1 -- Trailer 2 (Revised)',
#   'description': 'Harry Potter and the Deathly Hallows," the seventh and final adventure in the Harry Potter film series, is a much-anticipated motion picture event to be told in two ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kekNB6rAZN4/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/kekNB6rAZN4/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/kekNB6rAZN4/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'ukharrypotter',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-10-26T04:55:27.000Z',
#   'channelId': 'UC4qoF_6egvtcYF_Qubg2eIw',
#   'title': '&quot;while their harry potter books were burned&quot;',
#   'description': '',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7SkzxiG8v5E/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/7SkzxiG8v5E/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/7SkzxiG8v5E/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'soupswimmer',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-10-26T23:17:32.000Z',
#   'channelId': 'UCKy1dAqELo0zrOtPkf0eTMw',
#   'title': 'Harry Potter and the Deathly Hallows - TV Trailer',
#   'description': 'A television trailer for the new Harry Potter and the Deathly Hallows movie. As the famous fantasy series draws to a close, can Harry and the wizarding world ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zoOoKMYfT6A/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/zoOoKMYfT6A/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/zoOoKMYfT6A/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'IGN',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-11-12T00:14:33.000Z',
#   'channelId': 'UCNM51jUVf9msC1Eac9LyRFw',
#   'title': 'Harry Potter Book Launch',
#   'description': 'Borders York Harry Potter & The Deathly Hallows.',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5vhxJAok0rI/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/5vhxJAok0rI/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/5vhxJAok0rI/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Steve Worsley',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-11-12T18:44:53.000Z',
#   'channelId': 'UCCj956IF62FbT7Gouszaj9w',
#   'title': 'Daniel Radcliffe sings &quot;The Elements&quot; - The Graham Norton Show - Series 8 Episode 4 - BBC One',
#   'description': 'Subscribe and to OFFICIAL BBC YouTube https://bit.ly/2IXqEIn Stream original BBC programmes FIRST on BBC iPlayer https://bbc.in/2J18jYJ ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/rSAaiYKF0cs/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/rSAaiYKF0cs/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/rSAaiYKF0cs/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'BBC',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-11-15T18:51:34.000Z',
#   'channelId': 'UCX0Li3JxkKVPIHAamYe-YmQ',
#   'title': 'MIKE RELM: THE HARRY POTTER REMIX',
#   'description': "Expecto Patronum! This is a remix celebrating the amazing saga of Harry Potter. What an incredible run! If you'd like to support, check out my Patreon: ...",
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PLL5MRijzI8/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/PLL5MRijzI8/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/PLL5MRijzI8/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Mike Relm',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-11-18T04:46:28.000Z',
#   'channelId': 'UCGaVdbSav8xWuFWTadK6loA',
#   'title': 'HARRY POTTER SONG!',
#   'description': 'In which Hank sings "This is Not Harry Potter. Lyrics below. Also, join Hank as he plays games at http://www.youtube.com/hankgames Subconsciously inspired ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lFZaCxfiUHs/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/lFZaCxfiUHs/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/lFZaCxfiUHs/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'vlogbrothers',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-11-19T00:29:59.000Z',
#   'channelId': 'UCVSNOxehfALut52NbkfRBaA',
#   'title': 'The last Harry Potter Movie is Out - And It&#39;s Dark',
#   'description': 'Almost 10 years after the first Harry Potter release, the film franchise is coming to an end with J.K. Rowling\'s last and bleakest book, "Harry Potter and the Deathly ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nNeFXMWlf6E/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/nNeFXMWlf6E/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/nNeFXMWlf6E/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'VOA News',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-11-21T07:00:43.000Z',
#   'channelId': 'UCcXeJa1qh1Xlm0P4K4ws_Jg',
#   'title': 'Mock the Week - Rejected First Lines from the new Harry Potter Book',
#   'description': 'Enjoy!',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zEyJWR-GliI/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/zEyJWR-GliI/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/zEyJWR-GliI/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'x0th101',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-11-24T20:03:48.000Z',
#   'channelId': 'UCRRtJojwuI4WEmBBw2W3X9A',
#   'title': 'Harry Potter Recording Sessions - The Mirror Of Erised',
#   'description': 'Harry uses the Cloak of Invisibility to sneak into the Restricted Section, upon searching for a book about Nicholas Flamel he comes across the Mirrir of Erised ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0_5-Q5l7xYg/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/0_5-Q5l7xYg/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/0_5-Q5l7xYg/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'jediking12',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-11-27T17:58:19.000Z',
#   'channelId': 'UCnBJp3JQksu-MyqFZtfBkoA',
#   'title': 'Harry Potter and the Half-Blood Prince Book Review',
#   'description': 'Title Says All.',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/65ER_ggteAU/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/65ER_ggteAU/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/65ER_ggteAU/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'KavonVlogs',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-11-29T22:47:35.000Z',
#   'channelId': 'UCRRtJojwuI4WEmBBw2W3X9A',
#   'title': 'Harry Potter and the Chamber of Secrets Soundtrack - 14. Meeting Tom Riddle',
#   'description': "Harry is transported through Tom Riddle's Diary 50 years ago and sees the night Myrtle is killed and Hagrid and Aragog.",
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/tWB5zlVaA08/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/tWB5zlVaA08/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/tWB5zlVaA08/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'jediking12',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-12-02T04:18:15.000Z',
#   'channelId': 'UCPs6rSYLyX_rPbhAdHbrLNA',
#   'title': 'My Favorite Harry Potter Book',
#   'description': 'The first of my Vlog Everyday December project. In horrible lighting, unfortunately. twitter: http://twitter.com/saymorsmordre.',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DPOCh586OXY/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/DPOCh586OXY/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/DPOCh586OXY/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'SamLovesHP',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-12-14T00:12:01.000Z',
#   'channelId': 'UCupKobijn-ivLYIVp70rfBw',
#   'title': 'J.K. Rowling and the second Harry Potter book',
#   'description': 'It was October 99 and a "The Story Teller Book Store" in Lafayette, hired us to cover an event. That included a reading and book signing from a young, single ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/KCmxGljmHTY/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/KCmxGljmHTY/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/KCmxGljmHTY/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Second Sight Video & Multimedia',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-12-22T00:43:30.000Z',
#   'channelId': 'UCjmJDM5pRKbUlVIzDYYWb6g',
#   'title': 'Harry Potter and the Deathly Hallows - Part 1: Now Playing #2',
#   'description': 'Harry Potter and the Deathly Hallows, the seventh and final adventure in the Harry Potter film series, is a much-anticipated motion picture event to be told in two ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/A6vXOZbzBYY/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/A6vXOZbzBYY/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/A6vXOZbzBYY/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Warner Bros. Pictures',
#   'liveBroadcastContent': 'none'},
#  {'publishedAt': '2010-12-28T00:25:12.000Z',
#   'channelId': 'UCTlyM5PU8y_mg75Y_-kxHGg',
#   'title': 'Harry Potter and the Philosophers stone VS Sorcerer&#39;s Stone Bloomsbury VS scholastics',
#   'description': 'First off I know 99.9% of the people that view this video will already know that there are two titles so this video isnt directed at you and you most likely wont get ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/cfLEHDAOhBs/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/cfLEHDAOhBs/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/cfLEHDAOhBs/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'eviltig',
#   'liveBroadcastContent': 'none'}]

# %%
#Im going to mix here the things Data Pythonist explains
#about getting the information of a video:
# https://github.com/nikhilkumarsingh/YouTubeAPI-Examples/blob/master/5.Most-Disliked-Channel-Vids.ipynb

# %%
#so, first, we'll get the IDs of the videos we find, doing this:
id_list = []
for item in sorted(res['items'], key=lambda x:x['snippet']['publishedAt']):
    #print(item['snippet']['title'], item['snippet']['publishedAt'], item['id']['videoId'])
    id_list.append(item['id']['videoId'])
    
print(id_list)

# now we have a list of ids. Remember. Where are taking here just 50 videos. If you want to analyze more videos
# you have to 
stats = []


res_video = youtube.videos().list(id=','.join(id_list),part='statistics').execute()
stats.append(res_video)

stats[0]['items']

for video in stats[0]['items']:
    print(video['statistics']['viewCount'])

#id_views = map(id_list, )
# Out:
# ['TUQJNFO62ng', 'OOXBKdi9E7Y', 'XmG0K3eEfgE', 'HtBYd6yap38', '-VMQrtJ93_w', 'EzglA2SFFT0', 's8zBR1l4Tgc', 'CrG_J74wVJY', 'a5Uvf-_zYSs', 'yV_RPAKQAGM', 'wVTYQGcA-6I', 'UPVolA1K1Ug', 'Rr4zIpqrro4', 'o1ARdZPEwsQ', 'IzNl04vslEk', 'thY_nn7X-FA', 'ramuWv8rqpg', 'iqjPi5P2Lqg', 'SeLtAmnURgQ', '9hXH0Ackz6w', 'LWEc_rwF4KA', '84nUq4uStQA', '3qQw5qjrrCs', '4OSW3nzE3jk', 'K0teQETyB9s', 'D-IhimHc_oQ', 'AapzgNJgtAw', 'nw76LnI7PEw', 'rNVZqmQcshI', 'YzfEH0UPEBo', 'Su1LOpjvdZ4', 'FiPu8v7rJi0', 'C8A_dqvMPc8', 'q6_9KrM4CEE', 'kekNB6rAZN4', '7SkzxiG8v5E', 'zoOoKMYfT6A', '5vhxJAok0rI', 'rSAaiYKF0cs', 'PLL5MRijzI8', 'lFZaCxfiUHs', 'nNeFXMWlf6E', 'zEyJWR-GliI', '0_5-Q5l7xYg', '65ER_ggteAU', 'tWB5zlVaA08', 'DPOCh586OXY', 'KCmxGljmHTY', 'A6vXOZbzBYY', 'cfLEHDAOhBs']
# 131961
# 480449
# 169860
# 6091
# 858
# 11109
# 108199
# 5412
# 147489
# 5207
# 228
# 1512139
# 7142516
# 3320
# 4874
# 19315
# 241870
# 9149
# 8688
# 4396899
# 1068921
# 19255588
# 446248
# 1959488
# 46077
# 9023
# 626149
# 85977
# 151923
# 12574654
# 1471355
# 6725
# 1774
# 12999
# 151612
# 4968
# 128218
# 436
# 7208042
# 1380592
# 544404
# 1305
# 386835
# 77121
# 1918
# 412166
# 401
# 12719
# 536145
# 17798

# %%
df_videos = pd.DataFrame(stats[0]['items'])
#df_videos

# %%
#df_staticsts = pd.DataFrame(stats[0]['items'])
#df_staticsts
video_statistics=[]
for elem in stats[0]['items']:
    #print(elem['statistics'])
    video_statistics.append(elem['statistics'])
    
video_statistics

df_statistcis = pd.DataFrame(video_statistics)
#df_statistcis

# %%
#lets concatenate. super - mega - definitive data set:

data_frames = [df_videos, df_statistcis]
data = pd.concat(data_frames, axis = 1)

#some columns are eliminated
data = data.drop(['kind','etag', 'statistics', 'favoriteCount'], axis=1)
data
# Out:
#              id viewCount likeCount dislikeCount commentCount
# 0   TUQJNFO62ng    131961       639            5           68
# 1   OOXBKdi9E7Y    480449      3856           37          592
# 2   XmG0K3eEfgE    169860       468           13          168
# 3   HtBYd6yap38      6091       147            7          108
# 4   -VMQrtJ93_w       858         4            0            1
# 5   EzglA2SFFT0     11109        89            3            3
# 6   s8zBR1l4Tgc    108199       351           12           27
# 7   CrG_J74wVJY      5412        42            3            8
# 8   a5Uvf-_zYSs    147489      1233           35          NaN
# 9   yV_RPAKQAGM      5207        30            0            9
# 10  wVTYQGcA-6I       228         3            0            4
# 11  UPVolA1K1Ug   1512139     23278          524         1570
# 12  Rr4zIpqrro4   7142516    112830         2014         4620
# 13  o1ARdZPEwsQ      3320        27            2            2
# 14  IzNl04vslEk      4874        27            1           15
# 15  thY_nn7X-FA     19315        70            5           35
# 16  ramuWv8rqpg    241870      1213           19          222
# 17  iqjPi5P2Lqg      9149        93           15           87
# 18  SeLtAmnURgQ      8688        30            2           13
# 19  9hXH0Ackz6w   4396899     22848          405         3799
# 20  LWEc_rwF4KA   1068921      2718          108         1101
# 21  84nUq4uStQA  19255588    222835         3051         5548
# 22  3qQw5qjrrCs    446248       505           50          219
# 23  4OSW3nzE3jk   1959488     14602          184         1365
# 24  K0teQETyB9s     46077        30            6            0
# 25  D-IhimHc_oQ      9023        51            2            4
# 26  AapzgNJgtAw    626149      5491          215         2807
# 27  nw76LnI7PEw     85977       488           28          104
# 28  rNVZqmQcshI    151923      1561           30          271
# 29  YzfEH0UPEBo  12574654     51642         1297        11052
# 30  Su1LOpjvdZ4   1471355      7122           89         1556
# 31  FiPu8v7rJi0      6725        41            8           20
# 32  C8A_dqvMPc8      1774         5            0            0
# 33  q6_9KrM4CEE     12999        80            1           41
# 34  kekNB6rAZN4    151612       213           12           72
# 35  7SkzxiG8v5E      4968        47            0            7
# 36  zoOoKMYfT6A    128218       595           23          267
# 37  5vhxJAok0rI       436         1            0            0
# 38  rSAaiYKF0cs   7208042     71056          777         9265
# 39  PLL5MRijzI8   1380592     27471          382         2652
# 40  lFZaCxfiUHs    544404     19838          318         2399
# 41  nNeFXMWlf6E      1305         4            1            0
# 42  zEyJWR-GliI    386835      2185           28          205
# 43  0_5-Q5l7xYg     77121       652            5          139
# 44  65ER_ggteAU      1918         4            4          NaN
# 45  tWB5zlVaA08    412166      1196           16          127
# 46  DPOCh586OXY       401         6            0            3
# 47  KCmxGljmHTY     12719       151            3           22
# 48  A6vXOZbzBYY    536145       508           87          472
# 49  cfLEHDAOhBs     17798        95           10          108

# %%
df_info = pd.DataFrame(video_info)
#df_info
df_info_clean = df_info.drop(['channelId', 'description', 'thumbnails', 'liveBroadcastContent'], axis=1)
df_info_clean
# Out:
#                  publishedAt  \
# 0   2010-01-10T00:03:34.000Z
# 1   2010-01-23T21:03:21.000Z
# 2   2010-01-28T15:23:59.000Z
# 3   2010-01-31T09:57:57.000Z
# 4   2010-02-08T19:48:17.000Z
# 5   2010-02-24T18:03:48.000Z
# 6   2010-03-24T16:54:20.000Z
# 7   2010-04-01T21:09:43.000Z
# 8   2010-04-06T00:15:25.000Z
# 9   2010-04-06T01:22:59.000Z
# 10  2010-04-21T01:11:17.000Z
# 11  2010-05-06T23:14:05.000Z
# 12  2010-05-24T13:09:27.000Z
# 13  2010-06-05T23:03:35.000Z
# 14  2010-06-13T20:48:17.000Z
# 15  2010-06-15T04:58:55.000Z
# 16  2010-06-18T18:13:24.000Z
# 17  2010-06-26T15:43:54.000Z
# 18  2010-06-27T02:56:33.000Z
# 19  2010-06-28T23:06:50.000Z
# 20  2010-06-30T17:22:23.000Z
# 21  2010-07-01T04:12:29.000Z
# 22  2010-07-11T07:50:49.000Z
# 23  2010-07-20T22:59:23.000Z
# 24  2010-08-18T00:46:15.000Z
# 25  2010-08-22T21:54:16.000Z
# 26  2010-09-05T13:46:57.000Z
# 27  2010-09-13T21:40:48.000Z
# 28  2010-09-19T02:03:50.000Z
# 29  2010-09-23T01:41:48.000Z
# 30  2010-09-23T01:51:47.000Z
# 31  2010-09-24T15:46:28.000Z
# 32  2010-10-14T11:07:52.000Z
# 33  2010-10-18T08:37:12.000Z
# 34  2010-10-19T14:31:56.000Z
# 35  2010-10-26T04:55:27.000Z
# 36  2010-10-26T23:17:32.000Z
# 37  2010-11-12T00:14:33.000Z
# 38  2010-11-12T18:44:53.000Z
# 39  2010-11-15T18:51:34.000Z
# 4   University of Alabama at Birmingham
# 5                  chicagobotanicgarden
# 6                            Scholastic
# 7                               Lola B.
# 8                 The Obama White House
# 9                       Michael McIntee
# 10                       girlfromMarz97
# 11                        PistolShrimps
# 12                       Simon Willmore
# 13                            YTMND2012
# 14                              eviltig
# 15                              eviltig
# 16                     Inside the Magic
# 17                    WriterfromNowhere
# 18                             Jordacar
# 19                Warner Bros. Pictures
# 20                                  IGN
# 21                      RadcliffeWatson
# 22                       moviemaniacsDE
# 23                            ClevverTV
# 24                        SkYari Temaki
# 25                      MockTheWeekFan0
# 26                                  FBE
# 27                     Dey Street Books
# 28                        Lauren Samsel
# 29                            ClevverTV
# 30                Warner Bros. Pictures
# 31                       WizardrockFan1
# 32                          Waterstones
# 33                              eviltig
# 34                        ukharrypotter
# 35                          soupswimmer
# 36                                  IGN
# 37                        Steve Worsley
# 38                                  BBC
# 39                            Mike Relm
# 40                         vlogbrothers
# 41                             VOA News
# 42                              x0th101
# 43                           jediking12
# 44                           KavonVlogs
# 45                           jediking12
# 46                           SamLovesHP
# 47      Second Sight Video & Multimedia
# 48                Warner Bros. Pictures
# 49                              eviltig

# %% [markdown]
# # TRYING A FULL COPIED EXAMPLE

# %% [markdown]
# !/usr/bin/python
#
# from apiclient.discovery import build
# from apiclient.errors import HttpError
# from oauth2client.tools import argparser
#
#
# # Set DEVELOPER_KEY to the API key value from the APIs & auth > Registered apps
# # tab of
# #   https://cloud.google.com/console
# # Please ensure that you have enabled the YouTube Data API for your project.
# DEVELOPER_KEY = api_key
# YOUTUBE_API_SERVICE_NAME = "youtube"
# YOUTUBE_API_VERSION = "v3"
#
# def youtube_search(options):
#      youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=DEVELOPER_KEY)
#
# # Call the search.list method to retrieve results matching the specified
# # query term.
# search_response = youtube.search().list(q = 'dune', part="id,snippet",maxResults= 20).execute()
#
# videos = []
# channels = []
# playlists = []
#
#   # Add each result to the appropriate list, and then display the lists of
#   # matching videos, channels, and playlists.
# for search_result in search_response.get("items", []):
#     if search_result["id"]["kind"] == "youtube#video":
#         videos.append("%s (%s)" % (search_result["snippet"]["title"], search_result["id"]["videoId"]))
#     elif search_result["id"]["kind"] == "youtube#channel":
#         channels.append("%s (%s)" % (search_result["snippet"]["title"],search_result["id"]["channelId"]))
#     elif search_result["id"]["kind"] == "youtube#playlist":
#         playlists.append("%s (%s)" % (search_result["snippet"]["title"],search_result["id"]["playlistId"]))
#
# print("Videos:\n", "\n".join(videos), "\n")
# print ("Channels:\n", "\n".join(channels), "\n")
# print ("Playlists:\n", "\n".join(playlists), "\n")
#
#
# if __name__ == "__main__":
#     argparser.add_argument("--q", help="Search term", default="Google")
#     argparser.add_argument("--max-results", help="Max results", default=25)
#     args = argparser.parse_args()
#
# try:
#     youtube_search(args)
# except (HttpError, e):
#     print("An HTTP error %d occurred:\n%s" % (e.resp.status, e.content))

# %% [markdown]
# # TRYING PYTHON-YOUTUBE LIBRARY

# %% [markdown]
# from pyyoutube import Api
#
# api_key = 'AIzaSyBBouPW0Ug4r5tWzccLsSJetvMZL4edv-Q'
#
# api = Api(api_key)
