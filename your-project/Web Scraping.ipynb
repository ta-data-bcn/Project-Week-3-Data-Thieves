# %%
#Import required libraries
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup #don't forget to pip install BS

# %%
#
html_doc = 'https://marketing4ecommerce.net/youtubers-mas-seguidos-de-espana-2019-50/'
page = requests.get("https://marketing4ecommerce.net/youtubers-mas-seguidos-de-espana-2019-50/")
soup = BeautifulSoup(html_doc, 'html.parser')

# %%
soup = BeautifulSoup(page.content, 'html.parser')
soup.find_all('h2')
# Out:
# [<h2><i class="fa fa-bolt"></i> Tendencias</h2>,
#  <h2 class="cb-post-title"><a href="https://marketing4ecommerce.net/asi-prepara-ebay-espana-la-mayor-temporada-de-ventas-del-ano/">Así prepara eBay España la mayor temporada de ventas del año</a></h2>,
#  <h2 class="cb-post-title"><a href="https://marketing4ecommerce.net/lead-ad-extensions-el-nuevo-formato-de-google-para-captar-leads-desde-el-buscador/">Lead Ad Extensions: el nuevo formato de Google para captar leads desde el buscador</a></h2>,
#  <h2 class="cb-post-title"><a href="https://marketing4ecommerce.net/que-es-la-politica-de-cookies-y-cuando-debo-introducirla-en-mi-sitio-web/">Cómo implementar correctamente la política de cookies (y evitar sanciones como la de Vueling)</a></h2>,
#  <h2>Top 50 de los youtubers más famosos de España</h2>,
#  <h2>1. elrubiusOMG</h2>,
#  <h2>2. VEGETTA777</h2>,
#  <h2>3-4. The WillyRex y Willyrex</h2>,
#  <h2>5. Doggy Doggy Cartoons</h2>,
#  <h2>6. AuronPlay</h2>,
#  <h2>7. iTownGamePlay *Terror&amp;Diversión*</h2>,
#  <h2>8. Makiman131</h2>,
#  <h2>9. Las Ratitas</h2>,
#  <h2>10. ExpCaseros</h2>,
#  <h2>11. Mejores Juguetes</h2>,
#  <h2>12. Toys And Funny Kids Play Doh Cartoons</h2>,
#  <h2>13. InfantiLandia</h2>,
#  <h2>14. TheGrefg</h2>,
#  <h2> 15. DaniRep | +6 Vídeos Diarios De GTA 5 Online</h2>,
#  <h2>16. L<strong>uzugames</strong></h2>,
#  <h2>17. DalasReview</h2>,
#  <h2>18. Mikecrack</h2>,
#  <h2>19. Adexe &amp; Nau</h2>,
#  <h2>20. El Rincón De Giorgio</h2>,
#  <h2>21. ZarcortGame</h2>,
#  <h2>22. Wismichu</h2>,
#  <h2>23. Funny Stop Motion videos</h2>,
#  <h2>24. Ya – Alisa</h2>,
#  <h2>25. Alexby11</h2>,
#  <h2>26. sTaXxCraft</h2>,
#  <h2>27. FC Barcelona</h2>,
#  <h2>28. gymvirtual</h2>,
#  <h2>29. Pocoyo</h2>,
#  <h2>30. TOYS on the go!</h2>,
#  <h2><strong>31. MangelRogel</strong></h2>,
#  <h2><strong>32. </strong>ElChurches</h2>,
#  <h2>33. TheShooterCoC</h2>,
#  <h2>34. StaxX</h2>,
#  <h2>35. patty dragona</h2>,
#  <h2><span style="font-size: 24px; font-weight: bold;">37. </span>TikTak Draw</h2>,
#  <h2>38. byViruZz</h2>,
#  <h2>39. DjMaRiiO</h2>,
#  <h2>40. LOLiTO FDEZ</h2>,
#  <h2>41. Experimentar En Casa</h2>,
#  <h2>42. Tri-line</h2>,
#  <h2>43. ElTrollino</h2>,
#  <h2>44. Keyblade</h2>,
#  <h2>45. Manucraft</h2>,
#  <h2>46. bytarifa</h2>,
#  <h2>47. Kronno Zomber</h2>,
#  <h2>48. Antena 3</h2>,
#  <h2>49. Alvaro845</h2>,
#  <h2>50. Real Madrid</h2>,
#  <h2 class="m4e-suscribe-popup-title">¡Todo lo que necesitas saber!</h2>]

# %%
df = pd.DataFrame(soup.find_all('h2'))

# %%
df = df.iloc[5:] #removed the first 5 rows as garbage

# %%
df.columns = ['raw_name']

# %%
df = df.drop([39,53], axis=0)

# %%
df
# Out:
#                                              raw_name
# 5                             <h2>1. elrubiusOMG</h2>
# 6                              <h2>2. VEGETTA777</h2>
# 7               <h2>3-4. The WillyRex y Willyrex</h2>
# 8                    <h2>5. Doggy Doggy Cartoons</h2>
# 9                               <h2>6. AuronPlay</h2>
# 10   <h2>7. iTownGamePlay *Terror&amp;Diversión*</h2>
# 11                             <h2>8. Makiman131</h2>
# 12                            <h2>9. Las Ratitas</h2>
# 13                            <h2>10. ExpCaseros</h2>
# 14                      <h2>11. Mejores Juguetes</h2>
# 15  <h2>12. Toys And Funny Kids Play Doh Cartoons<...
# 16                         <h2>13. InfantiLandia</h2>
# 17                              <h2>14. TheGrefg</h2>
# 18  <h2> 15. DaniRep | +6 Vídeos Diarios De GTA 5 ...
# 19            <h2>16. L<strong>uzugames</strong></h2>
# 20                           <h2>17. DalasReview</h2>
# 21                             <h2>18. Mikecrack</h2>
# 22                       <h2>19. Adexe &amp; Nau</h2>
# 23                  <h2>20. El Rincón De Giorgio</h2>
# 24                           <h2>21. ZarcortGame</h2>
# 25                              <h2>22. Wismichu</h2>
# 26              <h2>23. Funny Stop Motion videos</h2>
# 27                            <h2>24. Ya – Alisa</h2>
# 28                              <h2>25. Alexby11</h2>
# 29                            <h2>26. sTaXxCraft</h2>
# 30                          <h2>27. FC Barcelona</h2>
# 31                            <h2>28. gymvirtual</h2>
# 32                                <h2>29. Pocoyo</h2>
# 33                       <h2>30. TOYS on the go!</h2>
# 34          <h2><strong>31. MangelRogel</strong></h2>
# 35           <h2><strong>32. </strong>ElChurches</h2>
# 36                         <h2>33. TheShooterCoC</h2>
# 37                                 <h2>34. StaxX</h2>
# 38                         <h2>35. patty dragona</h2>
# 40                              <h2>38. byViruZz</h2>
# 41                              <h2>39. DjMaRiiO</h2>
# 42                           <h2>40. LOLiTO FDEZ</h2>
# 43                  <h2>41. Experimentar En Casa</h2>
# 44                              <h2>42. Tri-line</h2>
# 45                            <h2>43. ElTrollino</h2>
# 46                              <h2>44. Keyblade</h2>
# 47                             <h2>45. Manucraft</h2>
# 48                              <h2>46. bytarifa</h2>
# 49                         <h2>47. Kronno Zomber</h2>
# 50                              <h2>48. Antena 3</h2>
# 51                             <h2>49. Alvaro845</h2>
# 52                           <h2>50. Real Madrid</h2>

# %%
df['string'] = df['raw_name'].astype('str')  #convert dtype to string
#df['string'] = df['raw_name'].apply(lambda x: str(x))

# %%
df_bup = df #create backup

# %%
df["interim_name"] = df["string"].apply(lambda x:re.sub("<h2>", " ", x))
df["interim2_name"] = df["interim_name"].apply(lambda x:re.sub("</h2>", " ", x))
df["interim3_name"] = df["interim2_name"].apply(lambda x:re.sub("<strong>", " ", x))
df["interim4_name"] = df["interim3_name"].apply(lambda x:re.sub("</strong>", " ", x))
df['rank'] = df['interim4_name'].apply(lambda s:s.split('.')[0])

# %%
df['URL'] = 'https://marketing4ecommerce.net/youtubers-mas-seguidos-de-espana-2019-50/'

# %%
df_clean = df[['rank','interim4_name','URL']]

# %%
df_clean = df_clean.rename({'interim4_name': 'Channel'}, axis=1)

# %%
df_clean
# Out:
#     rank                                            Channel  \
# 5      1                                    1. elrubiusOMG
# 6      2                                     2. VEGETTA777
# 7    3-4                      3-4. The WillyRex y Willyrex
# 8      5                           5. Doggy Doggy Cartoons
# 9      6                                      6. AuronPlay
# 10     7           7. iTownGamePlay *Terror&amp;Diversión*
# 11     8                                     8. Makiman131
# 12     9                                    9. Las Ratitas
# 13    10                                    10. ExpCaseros
# 14    11                              11. Mejores Juguetes
# 15    12         12. Toys And Funny Kids Play Doh Cartoons
# 16    13                                 13. InfantiLandia
# 17    14                                      14. TheGrefg
# 18    15    15. DaniRep | +6 Vídeos Diarios De GTA 5 Onl...
# 19    16                                   16. L uzugames
# 20    17                                   17. DalasReview
# 21    18                                     18. Mikecrack
# 22    19                               19. Adexe &amp; Nau
# 23    20                          20. El Rincón De Giorgio
# 24    21                                   21. ZarcortGame
# 25    22                                      22. Wismichu
# 26    23                      23. Funny Stop Motion videos
# 27    24                                    24. Ya – Alisa
# 28    25                                      25. Alexby11
# 29    26                                    26. sTaXxCraft
# 30    27                                  27. FC Barcelona
# 31    28                                    28. gymvirtual
# 32    29                                        29. Pocoyo
# 33    30                               30. TOYS on the go!
# 34    31                                  31. MangelRogel
# 35    32                                   32.  ElChurches
# 36    33                                 33. TheShooterCoC
# 37    34                                         34. StaxX
# 38    35                                 35. patty dragona
# 40    38                                      38. byViruZz
# 41    39                                      39. DjMaRiiO
# 42    40                                   40. LOLiTO FDEZ
# 43    41                          41. Experimentar En Casa
# 44    42                                      42. Tri-line
# 45    43                                    43. ElTrollino
# 46    44                                      44. Keyblade
# 47    45                                     45. Manucraft
# 48    46                                      46. bytarifa
