# %%
from youtube_api import YouTubeDataAPI
import pandas as pd
from bs4 import BeautifulSoup
import json

# %% [markdown]
# https://www.youtube.com/channel/UCa3DVlGH2_QhvwuWlPa6MDQ
# https://www.youtube.com/channel/UC9ths7ZO0InEWmdYMBY0Y1g
# https://www.youtube.com/channel/UCCNgRIfWQKZyPkNvHEzPh7Q
# https://www.youtube.com/channel/UCLj5tilgmgH862bkmJnOo4g
#
# "Soy una pringada"
# "Jaime Altozano"
# "Ter"
# "Cocina Veggikinga"

# %%
api_key ="AIzaSyB468eeKyBOk-YFOUd4lzdEwHqwboJYQGI"
yt = YouTubeDataAPI(api_key)
yt.search('Vegeta777')
video_test = yt.get_video_metadata("TBFn748OC_U", part = ["statistics","snippet"])
video_test
# Out:
# {'channel_id': 'UCam8T03EOFBsNdR0thrFHdQ',
#  'channel_title': 'VEGETTA777',
#  'collection_date': datetime.datetime(2019, 11, 11, 19, 5, 14, 672710),
#  'video_category': '24',
#  'video_comment_count': '12432',
# ...

# %%
video_test = yt.get_video_metadata("TBFn748OC_U", part = ["statistics","snippet","contentDetails"])
video_test
# Out:
# {'channel_id': 'UCam8T03EOFBsNdR0thrFHdQ',
#  'channel_title': 'VEGETTA777',
#  'collection_date': datetime.datetime(2019, 11, 11, 12, 3, 31, 45640),
#  'video_category': '24',
#  'video_comment_count': '12432',
# ...

# %%
from youtube_api import YouTubeDataAPI
api_key ="AIzaSyB468eeKyBOk-YFOUd4lzdEwHqwboJYQGI"
yt = YouTubeDataAPI(api_key)

def getVideos(channel):
    return yt.search(channel, max_results=50)


channels = ['Vegeta777', 'ElRubius', 'Ter']  #aca mandas la lista de canales
channelVideos = [] #aca se carga la data


for channel in channels:
    channelVideos += getVideos(channel)
channelVideos
# Out:
# [{'channel_id': 'UCFpFEtgfyRgZOqecZmMfwUQ',
#   'channel_title': 'Tiger',
#   'collection_date': datetime.datetime(2019, 11, 12, 15, 26, 3, 600063),
#   'video_category': None,
#   'video_description': 'TWITTER DE MI AMIGO: http://bit.ly/twitterdemiamigo Vegeta777 es criticado por dos niños ratas que le odian a muerte Los niños rata critican a vegeta777 ...',
#   'video_id': '0TRr9Tduzeg',
#   'video_publish_date': datetime.datetime(2016, 11, 29, 20, 0, 5),
#   'video_thumbnail': 'https://i.ytimg.com/vi/0TRr9Tduzeg/hqdefault.jpg',
#   'video_title': 'NIÑOS RATAS ODIAN A VEGETA777'},
#  {'channel_id': 'UCam8T03EOFBsNdR0thrFHdQ',
#   'channel_title': 'VEGETTA777',
#   'collection_date': datetime.datetime(2019, 11, 12, 15, 26, 3, 600111),
#   'video_category': None,
#   'video_description': 'Hola a todos Guapisim@s aqui os traigo un nuevo video de Los Juegos del Hambre! espero que lo paseis genial y ya sabeis que siempre es un placer jugar ...',
#   'video_id': 'e0HOR7Jq_5k',
# ...

# %%
len(channelVideos)
# Out:
# 150

# %%
type(channelVideos[0])
# Out:
# list

# %%
yt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-501d7db39f55> in <module>()
# ----> 1 yt.activities()
#
# AttributeError: 'YouTubeDataAPI' object has no attribute 'activities'
