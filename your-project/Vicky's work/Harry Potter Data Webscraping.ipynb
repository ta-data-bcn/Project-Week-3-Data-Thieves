# %% [markdown]
# # Scraping Harry Potter Numbers

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
url = 'https://www.the-numbers.com/movies/franchise/Harry-Potter#tab=summary'

# %%
page = requests.get(url).content
page_soup = BeautifulSoup(page, 'html.parser')
page_soup
# Out:
# <!DOCTYPE html>
#
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-1343128-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-1343128-1');
# </script>
# <meta content='(PICS-1.1 "https://www.icra.org/ratingsv02.html" l gen true for "https://www.the-numbers.com/" r (cb 1 lz 1 nz 1 oz 1 vz 1) "https://www.rsac.org/ratingsv01.html" l gen true for "https://www.the-numbers.com/" r (n 0 s 0 v 0 l 0))' http-equiv="PICS-Label"/>
# <!--<meta http-equiv="Content-Type" content="text/html; charset=ISO-8859-1" >-->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="telephone=no" name="format-detection"/> <!-- for apple mobile -->
# <meta content="521546213" property="fb:admins">
# <script crossorigin="anonymous" integrity="sha256-FgpCb/KJQlLNfOu91ta32o/NMZxltwRo8QtmkMRdAu8=" src="https://code.jquery.com/jquery-3.3.1.min.js"></script>
# <meta content="initial-scale=1" name="viewport"/>
# <meta content="Harry Potter franchise box office earnings" name="description"/>
# <meta content="NOODP" name="robots"/>
# <meta content="movies, box office, The Numbers, Numbers, daily box office, weekly box office, movie stars, dvd sales, Blu-ray sales, release schedule" name="keywords"/>
# <meta content="Harry Potter Franchise Box Office History - The Numbers" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://www.the-numbers.com/movies/franchise/Harry-Potter" property="og:url"/>
# <meta content="Harry Potter franchise box office earnings" property="og:description"/>
# <meta content="The Numbers" property="og:site_name"/>
# <meta content="https://www.the-numbers.com/images/the-numbers-833x200.jpg" property="og:image"/>
# <meta content="833" property="og:image:width"/>
# <meta content="200" property="og:image:height"/>
# <meta content="The-Numbers Image" property="og:image:alt"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@MovieNumbers" name="twitter:site"/>
# <meta content="Harry Potter Franchise Box Office History - The Numbers" name="twitter:title"/>
# <meta content="Harry Potter franchise box office earnings" name="twitter:description"/>
# <meta content="https://www.the-numbers.com/movies/franchise/Harry-Potter" name="twitter:url"/>
# <meta content="https://www.the-numbers.com/images/the-numbers-833x200.jpg" name="twitter:image"/>
# <meta content="1585976611658631" property="fb:app_id"/>
# <title>Harry Potter Franchise Box Office History - The Numbers</title>
# <link href="/resources/the-numbers-desktop-combined.css" rel="stylesheet" type="text/css"/>
# <link href="https://m.the-numbers.com/movies/franchise/Harry-Potter" media="only screen and (max-width: 640px)" rel="alternate"/>
# <script type="text/javascript">
# 	if (screen.width <= 640)
# 	{
#         window.location = "https://m.the-numbers.com/movies/franchise/Harry-Potter";
#     }
# </script>
# <!-- Begin comScore Tag -->
# <script async="">
# var _comscore = _comscore || [];
# _comscore.push({ c1: "2", c2: "9873768" });
# (function() {
#  var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#  s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#  el.parentNode.insertBefore(s, el);
#  })();
# </script>
# <noscript>
# <img src="https://b.scorecardresearch.com/p?c1=2&amp;c2=9873768&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <!-- End comScore Tag -->
# <!-- Header Tag Code -->
# <script data-cfasync="false" type="text/javascript">
# /*<![CDATA[*/(function (a, c, s, u){'Insticator'in a || (a.Insticator={ad:{loadAd: function (b){Insticator.ad.q.push(b)}, q: []}, helper:{}, embed:{}, version: "3.0", q: [], load: function (t, o){Insticator.q.push({t: t, o: o})}}); var b=c.createElement(s); b.src=u; b.async=!0; var d=c.getElementsByTagName(s)[0]; d.parentNode.insertBefore(b, d)})(window, document, 'script', '//d2na2p72vtqyok.cloudfront.net/client-embed/65b21a35-f662-4947-80ea-07d6b99277bf.js');/*
# ]]>*/
# </script>
# <!-- End Header Tag Code -->
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({
#           google_ad_client: "ca-pub-0505053220181058",
#           enable_page_level_ads: true
#      });
# </script>
# <link href="https://cdn.datatables.net/v/dt/dt-1.10.18/datatables.min.css" rel="stylesheet" type="text/css">
# <script src="https://cdn.datatables.net/v/dt/dt-1.10.18/datatables.min.js" type="text/javascript"></script>
# <link href="https://cdn.datatables.net/buttons/1.6.1/css/buttons.dataTables.min.css" rel="stylesheet" type="text/css">
# <script src="https://cdn.datatables.net/buttons/1.6.1/js/dataTables.buttons.min.js" type="text/javascript"></script>
# <script src="https://cdn.datatables.net/buttons/1.6.1/js/buttons.colVis.min.js" type="text/javascript"></script>
# <script src="https://cdn.rawgit.com/jhyland87/DataTables-Keep-Conditions/118c5e107f1f603b1b91475dc139df6f53917e38/dist/dataTables.keepConditions.min.js" type="text/javascript"></script>
# </link></link></meta></head>
# <body>
# <script>
#   window.fbAsyncInit = function() {
#     FB.init({
#       appId            : '1585976611658631',
#       autoLogAppEvents : true,
#       xfbml            : true,
#       version          : 'v2.9'
#     });
#     FB.AppEvents.logPageView();
#   };
#
#   (function(d, s, id){
#      var js, fjs = d.getElementsByTagName(s)[0];
#      if (d.getElementById(id)) {return;}
#      js = d.createElement(s); js.id = id;
#      js.src = "//connect.facebook.net/en_US/sdk.js";
#      fjs.parentNode.insertBefore(js, fjs);
#    }(document, 'script', 'facebook-jssdk'));
# </script>
# <div id="wrap">
# <div id="header">
# <a href="/"><img alt="The Numbers - Where Data and Movies Meet" border="0" height="67" src="/images/the-numbers-banner.png" width="524"/>®
# <br/>    Where Data and the Movie Business Meet
# </a>
# </div>
# <div id="header_right" style="background: #663366; width:200px; height: 96px;">
# <div style="float:right;">
# Follow us on
# <a href="https://www.facebook.com/TheNumbers" target="_blank"><img height="32" src="https://www.the-numbers.com/images/icons/facebook.png" style="border:none;" title="Follow The Numbers on Facebook" width="32"/></a>
# <a href="https://www.twitter.com/MovieNumbers" target="_blank" title="Follow The Numbers on Twitter"><img height="32" src="https://www.the-numbers.com/images/icons/twitter.png" style="border:none;" width="32"/></a>
# </div>
# </div>
# <div id="nav">
# <ul>
# <li><a href="/news">News</a>
# <ul>
# <li><a href="/news">Latest News</a></li>
# <li><a href="/rss-feed">RSS Feed</a></li>
# <li><a href="/movies/release-schedule">Release Schedule</a></li>
# <li><a href="/on-this-day">On This Day</a></li>
# <li><a href="/oscars">Oscars</a></li>
# </ul>
# </li>
# <li><a href="/box-office">Box Office</a>
# <ul>
# <li><a href="/daily-box-office-chart">Daily Chart</a></li>
# <li><a href="/weekend-box-office-chart">Weekend Chart</a></li>
# <li><a href="/weekly-box-office-chart">Weekly Chart</a></li>
# <li><a href="/market/">Theatrical Market</a></li>
# <li><a href="/international-charts-overview">International Charts</a></li>
# <li><a href="/box-office-records/">Records</a></li>
# <li><a href="/box-office">Chart Index</a></li>
# <li><a href="/movies/release-schedule">Release Schedule</a></li>
# <li><a href="/box-office-records/domestic/all-movies/cumulative/released-in-2020">2020 Domestic</a></li>
# <li><a href="/box-office-records/worldwide/all-movies/cumulative/released-in-2020">2020 Worldwide</a></li>
# </ul>
# </li>
# <li><a href="/weekly-dvd-sales-chart">Home Video</a>
# <ul>
# <li><a href="/weekly-dvd-sales-chart">Weekly DVD Chart</a></li>
# <li><a href="/weekly-bluray-sales-chart">Weekly Blu-ray Chart</a></li>
# <li><a href="/weekly-video-sales-chart">Weekly Combined DVD+Blu-ray Chart</a></li>
# <li><a href="/weekly-deg-watched-at-home-chart">DEG Watched at Home Top 20 Chart</a></li>
# <li><a href="/home-market/dvd-sales/2020">2020 DVD Chart</a></li>
# <li><a href="/home-market/bluray-sales/2020">2020 Blu-ray Chart</a></li>
# <li><a href="/home-market/packaged-media-sales/2020">2020 Combined Chart</a></li>
# <li><a href="/alltime-bluray-sales-chart">All-Time Blu-ray</a></li>
# <li><a href="/home-market/release-schedule">Release Schedule</a></li>
# <li><a href="/home-market/distributors">Distributors</a></li>
# </ul>
# </li>
# <li><a href="/movies">Movies</a>
# <ul>
# <li><a href="/movie/budgets">Budgets and Finances</a></li>
# <li><a href="/movies/franchises">Franchises</a></li>
# <li><a href="/movies/keywords">Keywords</a></li>
# <li><a href="/movies">Movie Index</a></li>
# <li><a href="/movies/release-schedule">Release Schedule</a></li>
# <li><a href="/movies/most-anticipated">Most Anticipated</a></li>
# <li><a href="/movies/trending">Trending Movies</a></li>
# <li><a href="/movies/production-companies/">Production Companies</a></li>
# <li><a href="/movies/production-countries/">Production Countries</a></li>
# <li><a href="/movies/languages">Languages</a></li>
# <li><a href="/movies/comparisons">Comparisons</a></li>
# <li><a href="/movies/report-builder">Report Builder</a></li>
# </ul>
# </li>
# <li><a href="/people-index">People</a>
# <ul>
# <li><a href="/bankability">Bankability</a></li>
# <li><a href="/box-office-star-records/">Records</a></li>
# <li><a href="/people-index">People Index</a></li>
# <li><a href="/people/trending">Trending People</a></li>
# <li><a href="/box-office-star-records/domestic/yearly-acting/highest-grossing-2020-stars">Highest Grossing Stars of 2020</a></li>
# </ul>
# </li>
# <li><a href="/research-tools">Research Tools</a>
# <ul>
# <li><a href="/movies/report-builder">Report Builder</a></li>
# <li><a href="/movies/keywords">Keyword Analysis</a></li>
# <li><a href="/movies/custom-comparisons">Movie Comparison</a></li>
# <li><a href="/custom-search">Search</a></li>
# </ul>
# </li>
# <li><a href="/our-services">Our Services</a>
# <ul>
# <li><a href="/research-services">Research Services</a></li>
# <li><a href="/data-services">Data Services</a></li>
# <li><a href="/bankability">Bankability</a></li>
# <li><a href="/about-us">About Us</a></li>
# <li><a href="/support-us">Support Us</a></li>
# <li><a href="/contact">Contact</a></li>
# </ul>
# </li>
# <li><a href="/users/my-numbers">My Numbers</a>
# <ul>
# <li><a href="/users/register">Register</a></li>
# <li><a href="/users/login">Login</a></li>
# <li><a href="/users/forgot-password">Forgot Password</a></li>
# </ul>
# </li>
# <li style="background: #ffcc00;"><a href="https://m.the-numbers.com/movies/franchise/Harry-Potter?from_desktop=Yes" rel="nofollow" style="background: #ffcc00;">Mobile Website</a></li>
# <li><a href="/users/register">Register</a></li>
# <li><a href="/users/login?backtopage=/movies/franchise/Harry-Potter">Login</a></li>
# </ul>
# </div></div></body></html>
#
# <div id="banneradnew">
# <center>
# <script type="text/javascript"><!--
# e9 = new Object();
# e9.size = "728x90,970x250";
# //--></script>
# <script src="//tags.expo9.exponential.com/tags/TheNumbers/ROS/tags.js" type="text/javascript"></script>
# </center>
# </div>
# <div id="main">
# <div id="page_filling_chart">
# <div class="alignright" style="margin: 16px 0px -16px 0px;">
# <ul id="social_horizontal">
# <li>
# <a class="twitter-share-button" data-text="Harry Potter Franchise Box Office History - The Numbers" data-via="MovieNumbers" href="https://twitter.com/share" rel="nofollow"></a>
# <script>!function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src="//platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");</script>
# </li>
# <li>
# <div class="fb-share-button" data-href="https://www.the-numbers.com/movies/franchise/Harry-Potter" data-layout="button_count"></div>
# </li>
# <li>
# <div class="fb-like" data-action="like" data-colorscheme="light" data-href="https://www.the-numbers.com/movies/franchise/Harry-Potter" data-layout="button_count" data-send="false" data-show-faces="false"></div>
# </li>
# <li>
# <script src="//platform.linkedin.com/in.js" type="text/javascript"></script>
# <script data-counter="right" type="IN/Share"></script>
# </li>
# </ul>
# </div><div class="clearfloats"></div>
# <h1>Box Office History for Harry Potter Movies</h1>
# <center>
# <a href="/movies/franchises">← See all franchises</a>
# </center>
# </div>
# <br/>
# <ol id="toc">
# <li><a href="#summary">Summary</a></li>
# <li><a href="#video">Video</a></li><li><a href="#news">News</a></li><li><a href="#acting">Acting Credits</a></li>
# <li><a href="#technical">Technical Credits</a></li>
# </ol>
# <div class="content" id="summary">
# <div id="page_filling_chart">
# <script src="https://www.google.com/jsapi?autoload={
# 	'modules':[{
# 	'name':'visualization',
# 	'version':'1',
# 	'packages':['corechart']
# 	}]}" type="text/javascript">
# </script>
# <script type="text/javascript">
# google.setOnLoadCallback(drawChart);
#
# function drawChart() {
# var data = new google.visualization.DataTable();
# data.addColumn('number', 'Day');
# data.addColumn('number', 'Harry Potter and the Deathly Hallows: Part II');
# data.addColumn('number', 'Harry Potter and the Sorcererâs Stone');
# data.addColumn('number', 'Harry Potter and the Half-Blood Prince');
# data.addColumn('number', 'Harry Potter and the Deathly Hallows: Part I');
# data.addColumn('number', 'Harry Potter and the Order of the Phoenix');
# data.addColumn('number', 'Harry Potter and the Goblet of Fire');
# data.addColumn('number', 'Harry Potter and the Chamber of Secrets');
# data.addColumn('number', 'Harry Potter and the Prisoner of Azkaban');
# data.addColumn('number', 'Fantastic Beasts and Where to Find Them');
# data.addColumn('number', 'Fantastic Beasts: The Crimes of Grindelwald');
# data.addColumn('number', 'The Harry Potter IMAX Marathon');
# data.addRows(101);
# data.setValue(0, 0, 0);
# data.setValue(1, 0, 1);
# data.setValue(2, 0, 2);
# data.setValue(3, 0, 3);
# data.setValue(4, 0, 4);
# data.setValue(5, 0, 5);
# data.setValue(6, 0, 6);
# data.setValue(7, 0, 7);
# data.setValue(8, 0, 8);
# data.setValue(9, 0, 9);
# data.setValue(10, 0, 10);
# data.setValue(11, 0, 11);
# data.setValue(12, 0, 12);
# data.setValue(13, 0, 13);
# data.setValue(14, 0, 14);
# data.setValue(15, 0, 15);
# data.setValue(16, 0, 16);
# data.setValue(17, 0, 17);
# data.setValue(18, 0, 18);
# data.setValue(19, 0, 19);
# data.setValue(20, 0, 20);
# data.setValue(21, 0, 21);
# data.setValue(22, 0, 22);
# data.setValue(23, 0, 23);
# data.setValue(24, 0, 24);
# data.setValue(25, 0, 25);
# data.setValue(26, 0, 26);
# data.setValue(27, 0, 27);
# data.setValue(28, 0, 28);
# data.setValue(29, 0, 29);
# data.setValue(30, 0, 30);
# data.setValue(31, 0, 31);
# data.setValue(32, 0, 32);
# data.setValue(33, 0, 33);
# data.setValue(34, 0, 34);
# data.setValue(35, 0, 35);
# data.setValue(36, 0, 36);
# data.setValue(37, 0, 37);
# data.setValue(38, 0, 38);
# data.setValue(39, 0, 39);
# data.setValue(40, 0, 40);
# data.setValue(41, 0, 41);
# data.setValue(42, 0, 42);
# data.setValue(43, 0, 43);
# data.setValue(44, 0, 44);
# data.setValue(45, 0, 45);
# data.setValue(46, 0, 46);
# data.setValue(47, 0, 47);
# data.setValue(48, 0, 48);
# data.setValue(49, 0, 49);
# data.setValue(50, 0, 50);
# data.setValue(51, 0, 51);
# data.setValue(52, 0, 52);
# data.setValue(53, 0, 53);
# data.setValue(54, 0, 54);
# data.setValue(55, 0, 55);
# data.setValue(56, 0, 56);
# data.setValue(57, 0, 57);
# data.setValue(58, 0, 58);
# data.setValue(59, 0, 59);
# data.setValue(60, 0, 60);
# data.setValue(61, 0, 61);
# data.setValue(62, 0, 62);
# data.setValue(63, 0, 63);
# data.setValue(64, 0, 64);
# data.setValue(65, 0, 65);
# data.setValue(66, 0, 66);
# data.setValue(67, 0, 67);
# data.setValue(68, 0, 68);
# data.setValue(69, 0, 69);
# data.setValue(70, 0, 70);
# data.setValue(71, 0, 71);
# data.setValue(72, 0, 72);
# data.setValue(73, 0, 73);
# data.setValue(74, 0, 74);
# data.setValue(75, 0, 75);
# data.setValue(76, 0, 76);
# data.setValue(77, 0, 77);
# data.setValue(78, 0, 78);
# data.setValue(79, 0, 79);
# data.setValue(80, 0, 80);
# data.setValue(81, 0, 81);
# data.setValue(82, 0, 82);
# data.setValue(83, 0, 83);
# data.setValue(84, 0, 84);
# data.setValue(85, 0, 85);
# data.setValue(86, 0, 86);
# data.setValue(87, 0, 87);
# data.setValue(88, 0, 88);
# data.setValue(89, 0, 89);
# data.setValue(90, 0, 90);
# data.setValue(91, 0, 91);
# data.setValue(92, 0, 92);
# data.setValue(93, 0, 93);
# data.setValue(94, 0, 94);
# data.setValue(95, 0, 95);
# data.setValue(96, 0, 96);
# data.setValue(97, 0, 97);
# data.setValue(98, 0, 98);
# data.setValue(99, 0, 99);
# data.setValue(100, 0, 100);
# data.setValue(0, 1, 0);
# data.setValue(1, 1, 91071119);
# data.setValue(2, 1, 133485465);
# data.setValue(3, 1, 169189427);
# data.setValue(4, 1, 187232508);
# data.setValue(5, 1, 202620674);
# data.setValue(6, 1, 214887891);
# data.setValue(7, 1, 226117069);
# data.setValue(8, 1, 240671184);
# data.setValue(9, 1, 258934716);
# data.setValue(10, 1, 273539281);
# data.setValue(11, 1, 280016609);
# data.setValue(12, 1, 286495885);
# data.setValue(13, 1, 291662354);
# data.setValue(14, 1, 296534509);
# data.setValue(15, 1, 303092462);
# data.setValue(16, 1, 311549473);
# data.setValue(17, 1, 318511602);
# data.setValue(18, 1, 321839842);
# data.setValue(19, 1, 325139206);
# data.setValue(20, 1, 328025686);
# data.setValue(21, 1, 330641014);
# data.setValue(22, 1, 334015125);
# data.setValue(23, 1, 338850124);
# data.setValue(24, 1, 343086045);
# data.setValue(25, 1, 344890382);
# data.setValue(26, 1, 346901620);
# data.setValue(27, 1, 348563937);
# data.setValue(28, 1, 350085941);
# data.setValue(29, 1, 351946172);
# data.setValue(30, 1, 354708050);
# data.setValue(31, 1, 357337355);
# data.setValue(32, 1, 358495410);
# data.setValue(33, 1, 359637778);
# data.setValue(34, 1, 360565265);
# data.setValue(35, 1, 361496489);
# data.setValue(36, 1, 362682829);
# data.setValue(37, 1, 364460313);
# data.setValue(38, 1, 366007900);
# data.setValue(39, 1, 366602118);
# data.setValue(40, 1, 367203359);
# data.setValue(41, 1, 367711640);
# data.setValue(42, 1, 368240692);
# data.setValue(43, 1, 368929574);
# data.setValue(44, 1, 369959013);
# data.setValue(45, 1, 370805062);
# data.setValue(46, 1, 371163237);
# data.setValue(47, 1, 371535432);
# data.setValue(48, 1, 371844889);
# data.setValue(49, 1, 372150983);
# data.setValue(50, 1, 372710770);
# data.setValue(51, 1, 373615016);
# data.setValue(52, 1, 374623584);
# data.setValue(53, 1, 375552093);
# data.setValue(54, 1, 375755398);
# data.setValue(55, 1, 375934867);
# data.setValue(56, 1, 376103101);
# data.setValue(57, 1, 376367393);
# data.setValue(58, 1, 376817200);
# data.setValue(59, 1, 377104684);
# data.setValue(60, 1, 377190929);
# data.setValue(61, 1, 377290111);
# data.setValue(62, 1, 377382350);
# data.setValue(63, 1, 377480123);
# data.setValue(64, 1, 377660516);
# data.setValue(65, 1, 377974744);
# data.setValue(66, 1, 378180621);
# data.setValue(67, 1, 378240326);
# data.setValue(68, 1, 378305007);
# data.setValue(69, 1, 378366054);
# data.setValue(70, 1, 378436868);
# data.setValue(71, 1, 378533676);
# data.setValue(72, 1, 378709043);
# data.setValue(73, 1, 378824316);
# data.setValue(74, 1, 378858898);
# data.setValue(75, 1, 378894909);
# data.setValue(76, 1, 378930760);
# data.setValue(77, 1, 378972347);
# data.setValue(78, 1, 379041779);
# data.setValue(79, 1, 379167184);
# data.setValue(80, 1, 379245610);
# data.setValue(81, 1, 379268754);
# data.setValue(82, 1, 379293585);
# data.setValue(83, 1, 379317920);
# data.setValue(84, 1, 379344886);
# data.setValue(85, 1, 379457055);
# data.setValue(86, 1, 379626528);
# data.setValue(87, 1, 379750747);
# data.setValue(88, 1, 379816310);
# data.setValue(89, 1, 379862860);
# data.setValue(90, 1, 379903359);
# data.setValue(91, 1, 379950852);
# data.setValue(92, 1, 380032613);
# data.setValue(93, 1, 380155410);
# data.setValue(94, 1, 380235400);
# data.setValue(95, 1, 380260197);
# data.setValue(96, 1, 380288858);
# data.setValue(97, 1, 380316659);
# data.setValue(98, 1, 380350637);
# data.setValue(99, 1, 380405841);
# data.setValue(100, 1, 380484066);
# data.setValue(0, 2, 0);
# data.setValue(1, 2, 32333203);
# data.setValue(2, 2, 65846144);
# data.setValue(3, 2, 90294621);
# data.setValue(4, 2, 96937000);
# data.setValue(5, 2, 104591000);
# data.setValue(6, 2, 117246000);
# data.setValue(7, 2, 129566000);
# data.setValue(8, 2, 152478000);
# data.setValue(9, 2, 173566000);
# data.setValue(10, 2, 186978513);
# data.setValue(11, 2, 189505000);
# data.setValue(12, 2, 191888000);
# data.setValue(13, 2, 193954000);
# data.setValue(14, 2, 196027000);
# data.setValue(15, 2, 201933000);
# data.setValue(16, 2, 212287000);
# data.setValue(17, 2, 219670289);
# data.setValue(18, 2, 220932000);
# data.setValue(19, 2, 222343000);
# data.setValue(20, 2, 223648000);
# data.setValue(21, 2, 224884000);
# data.setValue(22, 2, 228404000);
# data.setValue(23, 2, 234792000);
# data.setValue(24, 2, 239659542);
# data.setValue(25, 2, 240528000);
# data.setValue(26, 2, 241559000);
# data.setValue(27, 2, 242448000);
# data.setValue(28, 2, 243350000);
# data.setValue(29, 2, 245571000);
# data.setValue(30, 2, 249933000);
# data.setValue(31, 2, 253270000);
# data.setValue(32, 2, 254082000);
# data.setValue(33, 2, 255003000);
# data.setValue(34, 2, 255917000);
# data.setValue(35, 2, 257460000);
# data.setValue(36, 2, 259200000);
# data.setValue(37, 2, 261956000);
# data.setValue(38, 2, 264655000);
# data.setValue(39, 2, 266200000);
# data.setValue(40, 2, 267750733);
# data.setValue(41, 2, 271144000);
# data.setValue(42, 2, 274649000);
# data.setValue(43, 2, 278270000);
# data.setValue(44, 2, 282099000);
# data.setValue(45, 2, 285611000);
# data.setValue(46, 2, 288493000);
# data.setValue(47, 2, 291594218);
# data.setValue(48, 2, 293206000);
# data.setValue(49, 2, 294474000);
# data.setValue(50, 2, 296313000);
# data.setValue(51, 2, 298696000);
# data.setValue(52, 2, 300404434);
# data.setValue(53, 2, 300739000);
# data.setValue(54, 2, 301082000);
# data.setValue(55, 2, 301368000);
# data.setValue(56, 2, 301638000);
# data.setValue(57, 2, 302390000);
# data.setValue(58, 2, 304014000);
# data.setValue(59, 2, 305311880);
# data.setValue(60, 2, 305533000);
# data.setValue(61, 2, 305775000);
# data.setValue(62, 2, 305989000);
# data.setValue(63, 2, 306206000);
# data.setValue(64, 2, 306755000);
# data.setValue(65, 2, 307850000);
# data.setValue(66, 2, 308840000);
# data.setValue(70, 2, 310171603);
# data.setValue(73, 2, 311573984);
# data.setValue(77, 2, 311925969);
# data.setValue(80, 2, 312936385);
# data.setValue(84, 2, 313182705);
# data.setValue(87, 2, 313736007);
# data.setValue(91, 2, 313997185);
# data.setValue(94, 2, 314320476);
# data.setValue(98, 2, 314420991);
# data.setValue(0, 3, 0);
# data.setValue(1, 3, 58175412);
# data.setValue(2, 3, 80186627);
# data.setValue(3, 3, 107007199);
# data.setValue(4, 3, 136241423);
# data.setValue(5, 3, 158022354);
# data.setValue(6, 3, 167946763);
# data.setValue(7, 3, 177457914);
# data.setValue(8, 3, 184976152);
# data.setValue(9, 3, 191833631);
# data.setValue(10, 3, 201167852);
# data.setValue(11, 3, 212360848);
# data.setValue(12, 3, 221295818);
# data.setValue(13, 3, 225318990);
# data.setValue(14, 3, 229338358);
# data.setValue(15, 3, 233920753);
# data.setValue(16, 3, 237762860);
# data.setValue(17, 3, 243138489);
# data.setValue(18, 3, 249893845);
# data.setValue(19, 3, 255672245);
# data.setValue(20, 3, 258190624);
# data.setValue(21, 3, 260610864);
# data.setValue(22, 3, 262803216);
# data.setValue(23, 3, 264920284);
# data.setValue(24, 3, 267502123);
# data.setValue(25, 3, 270977685);
# data.setValue(26, 3, 273848633);
# data.setValue(27, 3, 275140006);
# data.setValue(28, 3, 276456321);
# data.setValue(29, 3, 277609743);
# data.setValue(30, 3, 278737953);
# data.setValue(31, 3, 280192999);
# data.setValue(32, 3, 282238071);
# data.setValue(33, 3, 283879025);
# data.setValue(34, 3, 284616272);
# data.setValue(35, 3, 285375636);
# data.setValue(36, 3, 286072062);
# data.setValue(37, 3, 286760375);
# data.setValue(38, 3, 287732054);
# data.setValue(39, 3, 289167953);
# data.setValue(40, 3, 290238524);
# data.setValue(41, 3, 290644750);
# data.setValue(42, 3, 291051145);
# data.setValue(43, 3, 291439349);
# data.setValue(44, 3, 291791652);
# data.setValue(45, 3, 292431424);
# data.setValue(46, 3, 293553701);
# data.setValue(47, 3, 294258075);
# data.setValue(48, 3, 294486205);
# data.setValue(49, 3, 294707345);
# data.setValue(50, 3, 294904348);
# data.setValue(51, 3, 295112118);
# data.setValue(52, 3, 295514962);
# data.setValue(53, 3, 296197431);
# data.setValue(54, 3, 296940258);
# data.setValue(55, 3, 297614366);
# data.setValue(56, 3, 297742596);
# data.setValue(57, 3, 297839740);
# data.setValue(58, 3, 297936218);
# data.setValue(59, 3, 298155342);
# data.setValue(60, 3, 298588795);
# data.setValue(61, 3, 298844700);
# data.setValue(62, 3, 298916152);
# data.setValue(63, 3, 298989374);
# data.setValue(64, 3, 299066782);
# data.setValue(65, 3, 299149308);
# data.setValue(66, 3, 299251785);
# data.setValue(67, 3, 299456739);
# data.setValue(68, 3, 299576295);
# data.setValue(69, 3, 299609771);
# data.setValue(70, 3, 299641573);
# data.setValue(71, 3, 299668923);
# data.setValue(72, 3, 299695999);
# data.setValue(73, 3, 299765661);
# data.setValue(74, 3, 299887119);
# data.setValue(75, 3, 299967829);
# data.setValue(76, 3, 299991266);
# data.setValue(77, 3, 300011724);
# data.setValue(78, 3, 300033000);
# data.setValue(79, 3, 300056680);
# data.setValue(80, 3, 300101273);
# data.setValue(81, 3, 300181586);
# data.setValue(82, 3, 300232058);
# data.setValue(83, 3, 300247445);
# data.setValue(84, 3, 300261293);
# data.setValue(85, 3, 300274819);
# data.setValue(86, 3, 300290780);
# data.setValue(87, 3, 300397962);
# data.setValue(88, 3, 300574482);
# data.setValue(89, 3, 300699217);
# data.setValue(90, 3, 300761086);
# data.setValue(91, 3, 300800421);
# data.setValue(92, 3, 300839206);
# data.setValue(93, 3, 300880041);
# data.setValue(94, 3, 300959316);
# data.setValue(95, 3, 301082222);
# data.setValue(96, 3, 301153382);
# data.setValue(97, 3, 301174730);
# data.setValue(98, 3, 301196318);
# data.setValue(99, 3, 301216215);
# data.setValue(100, 3, 301238300);
# data.setValue(0, 4, 0);
# data.setValue(1, 4, 61684550);
# data.setValue(2, 4, 99910804);
# data.setValue(3, 4, 125017372);
# data.setValue(4, 4, 133802832);
# data.setValue(5, 4, 144067185);
# data.setValue(6, 4, 158493048);
# data.setValue(7, 4, 169969028);
# data.setValue(8, 4, 190801679);
# data.setValue(9, 4, 209530619);
# data.setValue(10, 4, 219056129);
# data.setValue(11, 4, 221395291);
# data.setValue(12, 4, 223673772);
# data.setValue(13, 4, 225609158);
# data.setValue(14, 4, 227500641);
# data.setValue(15, 4, 232302408);
# data.setValue(16, 4, 239748482);
# data.setValue(17, 4, 244519116);
# data.setValue(18, 4, 245657482);
# data.setValue(19, 4, 246936701);
# data.setValue(20, 4, 248066339);
# data.setValue(21, 4, 249188405);
# data.setValue(22, 4, 251585745);
# data.setValue(23, 4, 255337232);
# data.setValue(24, 4, 257672721);
# data.setValue(25, 4, 258393849);
# data.setValue(26, 4, 259196947);
# data.setValue(27, 4, 259924254);
# data.setValue(28, 4, 260701257);
# data.setValue(29, 4, 262021812);
# data.setValue(30, 4, 264102283);
# data.setValue(31, 4, 265723618);
# data.setValue(32, 4, 266686635);
# data.setValue(33, 4, 267808784);
# data.setValue(34, 4, 268711916);
# data.setValue(35, 4, 269818287);
# data.setValue(36, 4, 270527686);
# data.setValue(37, 4, 271598360);
# data.setValue(38, 4, 272994635);
# data.setValue(39, 4, 274432306);
# data.setValue(40, 4, 275826603);
# data.setValue(41, 4, 277314301);
# data.setValue(42, 4, 278881516);
# data.setValue(43, 4, 280230127);
# data.setValue(44, 4, 282101489);
# data.setValue(45, 4, 283533215);
# data.setValue(46, 4, 284158711);
# data.setValue(47, 4, 284606713);
# data.setValue(48, 4, 284967896);
# data.setValue(49, 4, 285308372);
# data.setValue(50, 4, 285951380);
# data.setValue(51, 4, 287020595);
# data.setValue(52, 4, 287661770);
# data.setValue(53, 4, 287833113);
# data.setValue(54, 4, 288021547);
# data.setValue(55, 4, 288205868);
# data.setValue(56, 4, 288404268);
# data.setValue(57, 4, 288750710);
# data.setValue(58, 4, 289330955);
# data.setValue(59, 4, 289803472);
# data.setValue(60, 4, 290153345);
# data.setValue(61, 4, 290257461);
# data.setValue(62, 4, 290349084);
# data.setValue(63, 4, 290442497);
# data.setValue(64, 4, 290674124);
# data.setValue(65, 4, 291122346);
# data.setValue(66, 4, 291340768);
# data.setValue(67, 4, 291410780);
# data.setValue(68, 4, 291483201);
# data.setValue(69, 4, 291545304);
# data.setValue(70, 4, 291622563);
# data.setValue(71, 4, 291759910);
# data.setValue(72, 4, 292042358);
# data.setValue(73, 4, 292223492);
# data.setValue(74, 4, 292264965);
# data.setValue(75, 4, 292303121);
# data.setValue(76, 4, 292343711);
# data.setValue(77, 4, 292387836);
# data.setValue(78, 4, 292484655);
# data.setValue(79, 4, 292682197);
# data.setValue(80, 4, 292761214);
# data.setValue(81, 4, 292791821);
# data.setValue(82, 4, 292822346);
# data.setValue(83, 4, 292853786);
# data.setValue(84, 4, 292890256);
# data.setValue(85, 4, 293001182);
# data.setValue(86, 4, 293214434);
# data.setValue(87, 4, 293355408);
# data.setValue(88, 4, 293420257);
# data.setValue(89, 4, 293461112);
# data.setValue(90, 4, 293500742);
# data.setValue(91, 4, 293542749);
# data.setValue(92, 4, 293628178);
# data.setValue(93, 4, 293778793);
# data.setValue(94, 4, 293901794);
# data.setValue(95, 4, 293989138);
# data.setValue(96, 4, 294021980);
# data.setValue(97, 4, 294052852);
# data.setValue(98, 4, 294086193);
# data.setValue(99, 4, 294148448);
# data.setValue(100, 4, 294257582);
# data.setValue(0, 5, 0);
# data.setValue(1, 5, 44232338);
# data.setValue(2, 5, 62606743);
# data.setValue(3, 5, 88448728);
# data.setValue(4, 5, 116759603);
# data.setValue(5, 5, 139715157);
# data.setValue(6, 5, 150130637);
# data.setValue(7, 5, 159300110);
# data.setValue(8, 5, 167738316);
# data.setValue(9, 5, 175355515);
# data.setValue(10, 5, 185570955);
# data.setValue(11, 5, 197852087);
# data.setValue(12, 5, 207866865);
# data.setValue(13, 5, 212681190);
# data.setValue(14, 5, 217083411);
# data.setValue(15, 5, 220998765);
# data.setValue(16, 5, 224706129);
# data.setValue(17, 5, 229771951);
# data.setValue(18, 5, 236845162);
# data.setValue(19, 5, 242439214);
# data.setValue(20, 5, 244877588);
# data.setValue(21, 5, 247191583);
# data.setValue(22, 5, 249357836);
# data.setValue(23, 5, 251505177);
# data.setValue(24, 5, 254167413);
# data.setValue(25, 5, 257955350);
# data.setValue(26, 5, 261027397);
# data.setValue(27, 5, 262654623);
# data.setValue(28, 5, 264078779);
# data.setValue(29, 5, 265421089);
# data.setValue(30, 5, 266615258);
# data.setValue(31, 5, 268189964);
# data.setValue(32, 5, 270279145);
# data.setValue(33, 5, 272047388);
# data.setValue(34, 5, 272828538);
# data.setValue(35, 5, 273600922);
# data.setValue(36, 5, 274339341);
# data.setValue(37, 5, 275105738);
# data.setValue(38, 5, 276024166);
# data.setValue(39, 5, 277478561);
# data.setValue(40, 5, 278762117);
# data.setValue(41, 5, 279316414);
# data.setValue(42, 5, 279874898);
# data.setValue(43, 5, 280357192);
# data.setValue(44, 5, 280828522);
# data.setValue(45, 5, 281383000);
# data.setValue(47, 5, 283230934);
# data.setValue(48, 5, 283497083);
# data.setValue(49, 5, 283758464);
# data.setValue(50, 5, 284001859);
# data.setValue(51, 5, 284250119);
# data.setValue(54, 5, 286143377);
# data.setValue(55, 5, 286825495);
# data.setValue(58, 5, 287169841);
# data.setValue(61, 5, 288201180);
# data.setValue(65, 5, 288522854);
# data.setValue(68, 5, 289326081);
# data.setValue(72, 5, 289527287);
# data.setValue(75, 5, 289855714);
# data.setValue(79, 5, 289945599);
# data.setValue(82, 5, 290175378);
# data.setValue(86, 5, 290234807);
# data.setValue(89, 5, 290598256);
# data.setValue(93, 5, 290753534);
# data.setValue(96, 5, 291041408);
# data.setValue(100, 5, 291132139);
# data.setValue(0, 6, 0);
# data.setValue(1, 6, 40118363);
# data.setValue(2, 6, 76837498);
# data.setValue(3, 6, 102685961);
# data.setValue(4, 6, 110741182);
# data.setValue(5, 6, 119743524);
# data.setValue(6, 6, 133873907);
# data.setValue(7, 6, 146283069);
# data.setValue(8, 6, 169054371);
# data.setValue(9, 6, 189258709);
# data.setValue(10, 6, 201010207);
# data.setValue(11, 6, 203451580);
# data.setValue(12, 6, 205596807);
# data.setValue(13, 6, 207544120);
# data.setValue(14, 6, 209388580);
# data.setValue(15, 6, 214759672);
# data.setValue(16, 6, 223645889);
# data.setValue(17, 6, 229266716);
# data.setValue(18, 6, 230406014);
# data.setValue(19, 6, 231560213);
# data.setValue(20, 6, 232682657);
# data.setValue(21, 6, 233803862);
# data.setValue(22, 6, 236505381);
# data.setValue(23, 6, 241081967);
# data.setValue(24, 6, 244069305);
# data.setValue(25, 6, 244763756);
# data.setValue(26, 6, 245469136);
# data.setValue(27, 6, 246064434);
# data.setValue(28, 6, 246645807);
# data.setValue(29, 6, 248143019);
# data.setValue(30, 6, 250661379);
# data.setValue(31, 6, 252598259);
# data.setValue(32, 6, 253482480);
# data.setValue(33, 6, 254485801);
# data.setValue(34, 6, 255492998);
# data.setValue(35, 6, 256715413);
# data.setValue(36, 6, 258200000);
# data.setValue(37, 6, 259200000);
# data.setValue(38, 6, 260600000);
# data.setValue(39, 6, 263139532);
# data.setValue(40, 6, 265344891);
# data.setValue(41, 6, 267407264);
# data.setValue(42, 6, 269447715);
# data.setValue(43, 6, 271513749);
# data.setValue(44, 6, 273281180);
# data.setValue(45, 6, 275132632);
# data.setValue(46, 6, 277083157);
# data.setValue(47, 6, 277724469);
# data.setValue(49, 6, 278658114);
# data.setValue(52, 6, 281516498);
# data.setValue(56, 6, 282228377);
# data.setValue(59, 6, 283872840);
# data.setValue(60, 6, 284361860);
# data.setValue(63, 6, 284649794);
# data.setValue(66, 6, 285538219);
# data.setValue(70, 6, 285762909);
# data.setValue(73, 6, 286301035);
# data.setValue(77, 6, 286435732);
# data.setValue(80, 6, 286822905);
# data.setValue(84, 6, 286919411);
# data.setValue(87, 6, 287180682);
# data.setValue(91, 6, 287265347);
# data.setValue(94, 6, 287917479);
# data.setValue(95, 6, 288060759);
# data.setValue(98, 6, 288218866);
# data.setValue(0, 7, 0);
# data.setValue(1, 7, 29631453);
# data.setValue(2, 7, 63845256);
# data.setValue(3, 7, 88357488);
# data.setValue(4, 7, 93679000);
# data.setValue(5, 7, 98421000);
# data.setValue(6, 7, 102454000);
# data.setValue(7, 7, 106132000);
# data.setValue(8, 7, 117138823);
# data.setValue(9, 7, 135845151);
# data.setValue(10, 7, 148358831);
# data.setValue(11, 7, 150920000);
# data.setValue(12, 7, 154408000);
# data.setValue(13, 7, 160822000);
# data.setValue(14, 7, 168041516);
# data.setValue(15, 7, 181419676);
# data.setValue(16, 7, 193446308);
# data.setValue(17, 7, 200159012);
# data.setValue(18, 7, 201207000);
# data.setValue(19, 7, 202160000);
# data.setValue(20, 7, 202997000);
# data.setValue(21, 7, 203885000);
# data.setValue(22, 7, 206600000);
# data.setValue(23, 7, 211238000);
# data.setValue(24, 7, 213970962);
# data.setValue(25, 7, 214533000);
# data.setValue(26, 7, 215161000);
# data.setValue(27, 7, 215741000);
# data.setValue(28, 7, 216295000);
# data.setValue(29, 7, 217723188);
# data.setValue(30, 7, 220610665);
# data.setValue(31, 7, 222619375);
# data.setValue(32, 7, 223066000);
# data.setValue(33, 7, 223574000);
# data.setValue(34, 7, 224006940);
# data.setValue(35, 7, 224450000);
# data.setValue(36, 7, 225353000);
# data.setValue(37, 7, 226878000);
# data.setValue(38, 7, 228821682);
# data.setValue(39, 7, 230158075);
# data.setValue(40, 7, 231000499);
# data.setValue(41, 7, 231950777);
# data.setValue(42, 7, 233833266);
# data.setValue(43, 7, 236000000);
# data.setValue(44, 7, 238246913);
# data.setValue(45, 7, 240307533);
# data.setValue(46, 7, 242130000);
# data.setValue(47, 7, 243855000);
# data.setValue(48, 7, 245996000);
# data.setValue(49, 7, 247445000);
# data.setValue(50, 7, 248854500);
# data.setValue(51, 7, 250720000);
# data.setValue(52, 7, 252097945);
# data.setValue(53, 7, 252390000);
# data.setValue(56, 7, 253040825);
# data.setValue(58, 7, 254593196);
# data.setValue(59, 7, 255449301);
# data.setValue(63, 7, 256485418);
# data.setValue(66, 7, 257897677);
# data.setValue(70, 7, 258119640);
# data.setValue(73, 7, 258898102);
# data.setValue(77, 7, 259119624);
# data.setValue(80, 7, 259626842);
# data.setValue(84, 7, 259720120);
# data.setValue(87, 7, 260023267);
# data.setValue(91, 7, 260163836);
# data.setValue(94, 7, 260492052);
# data.setValue(98, 7, 260581103);
# data.setValue(0, 8, 0);
# data.setValue(1, 8, 38268295);
# data.setValue(2, 8, 69762162);
# data.setValue(3, 8, 93687367);
# data.setValue(4, 8, 102116000);
# data.setValue(5, 8, 109363000);
# data.setValue(6, 8, 116242000);
# data.setValue(7, 8, 123065000);
# data.setValue(8, 8, 134100000);
# data.setValue(9, 8, 147946953);
# data.setValue(10, 8, 157975042);
# data.setValue(11, 8, 161963000);
# data.setValue(12, 8, 165706000);
# data.setValue(13, 8, 169329000);
# data.setValue(14, 8, 172898000);
# data.setValue(15, 8, 178200000);
# data.setValue(16, 8, 185308202);
# data.setValue(17, 8, 190925253);
# data.setValue(18, 8, 193291000);
# data.setValue(19, 8, 195897000);
# data.setValue(20, 8, 198052000);
# data.setValue(21, 8, 200290000);
# data.setValue(22, 8, 203700000);
# data.setValue(23, 8, 208167392);
# data.setValue(24, 8, 211537548);
# data.setValue(25, 8, 213114000);
# data.setValue(26, 8, 214673000);
# data.setValue(27, 8, 215877000);
# data.setValue(28, 8, 217179000);
# data.setValue(29, 8, 219095300);
# data.setValue(30, 8, 221402666);
# data.setValue(31, 8, 223117013);
# data.setValue(32, 8, 225719716);
# data.setValue(33, 8, 226804716);
# data.setValue(34, 8, 227755716);
# data.setValue(35, 8, 228743000);
# data.setValue(37, 8, 231478906);
# data.setValue(38, 8, 232795692);
# data.setValue(39, 8, 233484000);
# data.setValue(40, 8, 234205000);
# data.setValue(41, 8, 234911000);
# data.setValue(42, 8, 235587000);
# data.setValue(43, 8, 236318852);
# data.setValue(44, 8, 237361841);
# data.setValue(45, 8, 238344679);
# data.setValue(47, 8, 239234000);
# data.setValue(48, 8, 239662000);
# data.setValue(49, 8, 240093000);
# data.setValue(50, 8, 240500000);
# data.setValue(51, 8, 241216997);
# data.setValue(52, 8, 241770359);
# data.setValue(56, 8, 242921093);
# data.setValue(59, 8, 243910542);
# data.setValue(63, 8, 244603966);
# data.setValue(66, 8, 245332214);
# data.setValue(70, 8, 245792785);
# data.setValue(73, 8, 246244214);
# data.setValue(77, 8, 246547311);
# data.setValue(80, 8, 246900818);
# data.setValue(84, 8, 247112921);
# data.setValue(87, 8, 247598604);
# data.setValue(91, 8, 247782190);
# data.setValue(94, 8, 248195631);
# data.setValue(98, 8, 248415371);
# data.setValue(0, 9, 0);
# data.setValue(1, 9, 29661434);
# data.setValue(2, 9, 55909476);
# data.setValue(3, 9, 74403387);
# data.setValue(4, 9, 81161446);
# data.setValue(5, 9, 90463123);
# data.setValue(6, 9, 101394156);
# data.setValue(7, 9, 110927553);
# data.setValue(8, 9, 129236866);
# data.setValue(9, 9, 146457267);
# data.setValue(10, 9, 156012316);
# data.setValue(11, 9, 158174571);
# data.setValue(12, 9, 161127757);
# data.setValue(13, 9, 163075212);
# data.setValue(14, 9, 164962403);
# data.setValue(15, 9, 169973551);
# data.setValue(16, 9, 178079105);
# data.setValue(17, 9, 183080514);
# data.setValue(18, 9, 184338003);
# data.setValue(19, 9, 186143140);
# data.setValue(20, 9, 187354191);
# data.setValue(21, 9, 188525903);
# data.setValue(22, 9, 191356121);
# data.setValue(23, 9, 196072429);
# data.setValue(24, 9, 198947154);
# data.setValue(25, 9, 199809384);
# data.setValue(26, 9, 201013143);
# data.setValue(27, 9, 201886661);
# data.setValue(28, 9, 202651095);
# data.setValue(29, 9, 203994208);
# data.setValue(30, 9, 206030031);
# data.setValue(31, 9, 207722418);
# data.setValue(32, 9, 208663096);
# data.setValue(33, 9, 209732624);
# data.setValue(34, 9, 210467126);
# data.setValue(35, 9, 211305251);
# data.setValue(36, 9, 212309281);
# data.setValue(37, 9, 212935017);
# data.setValue(38, 9, 214223225);
# data.setValue(39, 9, 215925877);
# data.setValue(40, 9, 217369419);
# data.setValue(41, 9, 218708314);
# data.setValue(42, 9, 220014794);
# data.setValue(43, 9, 221443522);
# data.setValue(44, 9, 222675573);
# data.setValue(45, 9, 224125258);
# data.setValue(46, 9, 225627739);
# data.setValue(47, 9, 226346236);
# data.setValue(48, 9, 226851395);
# data.setValue(49, 9, 227256573);
# data.setValue(50, 9, 227807498);
# data.setValue(51, 9, 228628910);
# data.setValue(52, 9, 229180032);
# data.setValue(53, 9, 229350716);
# data.setValue(54, 9, 229595336);
# data.setValue(55, 9, 229743563);
# data.setValue(56, 9, 229871325);
# data.setValue(57, 9, 230102183);
# data.setValue(58, 9, 230508066);
# data.setValue(59, 9, 230813099);
# data.setValue(60, 9, 231073227);
# data.setValue(61, 9, 231165467);
# data.setValue(62, 9, 231225874);
# data.setValue(63, 9, 231277992);
# data.setValue(64, 9, 231378363);
# data.setValue(65, 9, 231583628);
# data.setValue(66, 9, 231708335);
# data.setValue(67, 9, 231744638);
# data.setValue(68, 9, 231787478);
# data.setValue(69, 9, 231819636);
# data.setValue(70, 9, 231853222);
# data.setValue(71, 9, 231922943);
# data.setValue(72, 9, 232057873);
# data.setValue(73, 9, 232142332);
# data.setValue(74, 9, 232165180);
# data.setValue(75, 9, 232190312);
# data.setValue(76, 9, 232209717);
# data.setValue(77, 9, 232228519);
# data.setValue(78, 9, 232275853);
# data.setValue(79, 9, 232366235);
# data.setValue(80, 9, 232398690);
# data.setValue(81, 9, 232411721);
# data.setValue(82, 9, 232427930);
# data.setValue(83, 9, 232440086);
# data.setValue(84, 9, 232452571);
# data.setValue(85, 9, 232540116);
# data.setValue(86, 9, 232706886);
# data.setValue(87, 9, 232803734);
# data.setValue(88, 9, 232830063);
# data.setValue(89, 9, 232879104);
# data.setValue(90, 9, 232902661);
# data.setValue(91, 9, 232927738);
# data.setValue(92, 9, 232992121);
# data.setValue(93, 9, 233109857);
# data.setValue(94, 9, 233198013);
# data.setValue(95, 9, 233267773);
# data.setValue(96, 9, 233290490);
# data.setValue(97, 9, 233310631);
# data.setValue(98, 9, 233331577);
# data.setValue(99, 9, 233375320);
# data.setValue(100, 9, 233452823);
# data.setValue(0, 10, 0);
# data.setValue(1, 10, 25473261);
# data.setValue(2, 10, 46795085);
# data.setValue(3, 10, 62163104);
# data.setValue(4, 10, 67237518);
# data.setValue(5, 10, 74197238);
# data.setValue(6, 10, 80986521);
# data.setValue(7, 10, 87178811);
# data.setValue(8, 10, 98783083);
# data.setValue(9, 10, 110064460);
# data.setValue(10, 10, 116554309);
# data.setValue(11, 10, 118148409);
# data.setValue(12, 10, 120383158);
# data.setValue(13, 10, 121775520);
# data.setValue(14, 10, 123141406);
# data.setValue(15, 10, 126218738);
# data.setValue(16, 10, 131239614);
# data.setValue(17, 10, 134502962);
# data.setValue(18, 10, 135331221);
# data.setValue(19, 10, 136693343);
# data.setValue(20, 10, 137596591);
# data.setValue(21, 10, 138402524);
# data.setValue(22, 10, 140186445);
# data.setValue(23, 10, 143307232);
# data.setValue(24, 10, 145356370);
# data.setValue(25, 10, 145947844);
# data.setValue(26, 10, 146871236);
# data.setValue(27, 10, 147464760);
# data.setValue(28, 10, 148003410);
# data.setValue(29, 10, 149025890);
# data.setValue(30, 10, 150608138);
# data.setValue(31, 10, 151793249);
# data.setValue(32, 10, 152223404);
# data.setValue(33, 10, 152881700);
# data.setValue(34, 10, 153282963);
# data.setValue(35, 10, 153592713);
# data.setValue(36, 10, 153835593);
# data.setValue(37, 10, 154171249);
# data.setValue(38, 10, 154493497);
# data.setValue(39, 10, 154719667);
# data.setValue(40, 10, 154967241);
# data.setValue(41, 10, 155275431);
# data.setValue(42, 10, 155562000);
# data.setValue(43, 10, 155890579);
# data.setValue(44, 10, 156238067);
# data.setValue(45, 10, 156549701);
# data.setValue(46, 10, 156781859);
# data.setValue(47, 10, 157077926);
# data.setValue(48, 10, 157257505);
# data.setValue(49, 10, 157408573);
# data.setValue(50, 10, 157608731);
# data.setValue(51, 10, 157871723);
# data.setValue(52, 10, 158034792);
# data.setValue(53, 10, 158087004);
# data.setValue(54, 10, 158155036);
# data.setValue(55, 10, 158201282);
# data.setValue(56, 10, 158238989);
# data.setValue(57, 10, 158311293);
# data.setValue(58, 10, 158440517);
# data.setValue(59, 10, 158520703);
# data.setValue(60, 10, 158543775);
# data.setValue(61, 10, 158579618);
# data.setValue(62, 10, 158603422);
# data.setValue(63, 10, 158620988);
# data.setValue(64, 10, 158681852);
# data.setValue(65, 10, 158794433);
# data.setValue(66, 10, 158873445);
# data.setValue(67, 10, 158940108);
# data.setValue(68, 10, 158963564);
# data.setValue(69, 10, 158983045);
# data.setValue(70, 10, 159005109);
# data.setValue(71, 10, 159043009);
# data.setValue(72, 10, 159119192);
# data.setValue(73, 10, 159165678);
# data.setValue(74, 10, 159177033);
# data.setValue(75, 10, 159190909);
# data.setValue(76, 10, 159201735);
# data.setValue(77, 10, 159215088);
# data.setValue(78, 10, 159242176);
# data.setValue(79, 10, 159299846);
# data.setValue(80, 10, 159324060);
# data.setValue(81, 10, 159332317);
# data.setValue(82, 10, 159343815);
# data.setValue(83, 10, 159353345);
# data.setValue(84, 10, 159362631);
# data.setValue(85, 10, 159379343);
# data.setValue(86, 10, 159414889);
# data.setValue(87, 10, 159437533);
# data.setValue(88, 10, 159443366);
# data.setValue(89, 10, 159449052);
# data.setValue(90, 10, 159454198);
# data.setValue(91, 10, 159466059);
# data.setValue(92, 10, 159478423);
# data.setValue(93, 10, 159502918);
# data.setValue(94, 10, 159522885);
# data.setValue(95, 10, 159539241);
# data.setValue(96, 10, 159545150);
# data.setValue(97, 10, 159550370);
# data.setValue(98, 10, 159555901);
# data.setValue(0, 11, 0);
# data.setValue(1, 11, 573776);
# data.setValue(2, 11, 1024342);
# data.setValue(3, 11, 1357376);
# data.setValue(4, 11, 1462549);
# data.setValue(5, 11, 1566091);
# data.setValue(6, 11, 1678385);
# data.setValue(7, 11, 1729226);
#
#     var options = {
# 	vAxis: {minValue: 0, format: '$#,###', textPosition: 'in', viewWindow: {min:0} },
#     title: 'Daily Cumulative Domestic Box Office',
#     curveType: 'function',
# 	interpolateNulls: true,
#     legend: { position: 'right' },
# 		  	width:680,
# 	height:360,
#
# 	chartArea: {left:0, width: '80%', height: '100%'},
# 	titlePosition: 'in', axisTitlesPosition: 'in',
# 	hAxis: {textPosition: 'in'}};
#
#         var chart = new google.visualization.LineChart(document.getElementById('franchise_chart_div'));
#
# 		var formatter = new google.visualization.NumberFormat( {prefix: '$', fractionDigits: 0});
# 		formatter.format(data, 1);
# formatter.format(data, 2);
# formatter.format(data, 3);
# formatter.format(data, 4);
# formatter.format(data, 5);
# formatter.format(data, 6);
# formatter.format(data, 7);
# formatter.format(data, 8);
# formatter.format(data, 9);
# formatter.format(data, 10);
# formatter.format(data, 11);
#
# 		var formatter2 = new google.visualization.NumberFormat( {prefix: 'Day: ', fractionDigits: 0});
# 		formatter2.format(data, 0);
#
#         chart.draw(data, options);
#
# }
# </script>
# <div id="franchise_chart_div" style="width: 760px; height: 360px; align: center;"></div>
# <br/>
# <br/><br/>
# <p><a href="/users/register">Register</a> with The Numbers for free to customize this chart.
# <center>
# <table class="display compact" id="franchise_movies_overview" style="width:100%">
# <thead><tr><th>Release<br/>Date</th><th>Title</th><th>Production<br/>Budget</th><th>Opening<br/>Weekend</th><th>Domestic<br/>Box Office</th><th>Worldwide<br/>Box Office</th></tr>
# </thead><tbody><tr><td data-sort="2021-11-12"><a href="/movies/release-schedule#2021-11-12">Nov 12, 2021</a></td><td><b><a href="/movie/Fantastic-Beasts-and-Where-to-Find-Them-3-(2021)#tab=summary">Fantastic Beasts and Where …</a></b></td>
# <td class="data"></td><td class="data"></td><td class="data"></td><td class="data"></td></tr>
# <tr><td data-sort="2018-11-16"><a href="/box-office-chart/daily/2018/11/16">Nov 16, 2018</a></td><td><b><a href="/movie/Fantastic-Beasts-The-Crimes-of-Grindelwald-(2018)#tab=summary">Fantastic Beasts: The Crime…</a></b></td>
# <td class="data">$200,000,000</td><td class="data">$62,163,104</td><td class="data">$159,555,901</td><td class="data">$652,220,086</td></tr>
# <tr><td data-sort="2016-11-18"><a href="/box-office-chart/daily/2016/11/18">Nov 18, 2016</a></td><td><b><a href="/movie/Fantastic-Beasts-and-Where-to-Find-Them#tab=summary">Fantastic Beasts and Where …</a></b></td>
# <td class="data">$180,000,000</td><td class="data">$74,403,387</td><td class="data">$234,037,575</td><td class="data">$814,037,575</td></tr>
# <tr><td data-sort="2016-10-14"><a href="/box-office-chart/daily/2016/10/14">Oct 14, 2016</a></td><td><b><a href="/movie/Harry-Potter-IMAX-Marathon-The#tab=summary">The Harry Potter IMAX Marathon</a></b></td>
# <td class="data"></td><td class="data">$1,357,376</td><td class="data">$1,729,226</td><td class="data">$1,729,226</td></tr>
# <tr><td data-sort="2011-07-15"><a href="/box-office-chart/daily/2011/07/15">Jul 15, 2011</a></td><td><b><a href="/movie/Harry-Potter-and-the-Deathly-Hallows-Part-II#tab=summary">Harry Potter and the Deathl…</a></b></td>
# <td class="data">$125,000,000</td><td class="data">$169,189,427</td><td class="data">$381,193,157</td><td class="data">$1,341,693,157</td></tr>
# <tr><td data-sort="2010-11-19"><a href="/box-office-chart/daily/2010/11/19">Nov 19, 2010</a></td><td><b><a href="/movie/Harry-Potter-and-the-Deathly-Hallows-Part-I#tab=summary">Harry Potter and the Deathl…</a></b></td>
# <td class="data">$125,000,000</td><td class="data">$125,017,372</td><td class="data">$296,131,568</td><td class="data">$960,431,568</td></tr>
# ...
# </tr>
# <tr>
# <td><a href="/person/127890401-Martin-Schadler"><b>Martin Schadler</b></a></td>
# <td class="data">2</td>
# <td>
# 					Art Director (2)</td>
# <td class="data">$1,878,290,224</td>
# <td class="data">$1,878,290,224</td>
# <td class="data">100.0%</td>
# </tr>
# <tr>
# <td><a href="/person/142120401-Lucinda-Thomson"><b>Lucinda Thomson</b></a></td>
# <td class="data">2</td>
# <td>
# 					Art Director (2)</td>
# <td class="data">$1,854,272,741</td>
# <td class="data">$1,958,069,774</td>
# <td class="data">94.7%</td>
# </tr>
# <tr>
# <td><a href="/person/976480401-Michael-Sharp"><b>Michael Sharp</b></a></td>
# <td class="data">2</td>
# <td>
# 					Unit Production Manager (2)					<br/>
# 					Co-Producer (2)</td>
# <td class="data">$1,466,257,661</td>
# <td class="data">$3,304,248,703</td>
# <td class="data">44.4%</td>
# </tr>
# <tr>
# <td><a href="/person/614260401-Josh-Robertson"><b>Josh Robertson</b></a></td>
# <td class="data">2</td>
# <td>
# 					First Assistant Director (2)					<br/>
# 					Associate Producer (1)</td>
# <td class="data">$1,466,257,661</td>
# <td class="data">$3,831,750,128</td>
# <td class="data">38.3%</td>
# </tr>
# <tr>
# <td><a href="/person/457610401-Alex-Walker"><b>Alex Walker</b></a></td>
# <td class="data">2</td>
# <td>
# 					Art Director (2)</td>
# <td class="data">$1,738,692,794</td>
# <td class="data">$1,738,692,794</td>
# <td class="data">100.0%</td>
# </tr>
# <tr>
# <td><a href="/person/316020401-Peter-Francis"><b>Peter Francis</b></a></td>
# <td class="data">2</td>
# <td>
# 					Art Director (2)</td>
# <td class="data">$1,854,272,741</td>
# <td class="data">$5,031,588,391</td>
# <td class="data">36.9%</td>
# </tr>
# <tr>
# <td><a href="/person/504540401-Alan-Gilmore"><b>Alan Gilmore</b></a></td>
# <td class="data">2</td>
# <td>
# 					Art Director (2)</td>
# <td class="data">$1,692,716,131</td>
# <td class="data">$2,337,061,755</td>
# <td class="data">72.4%</td>
# </tr>
# <tr>
# <td><a href="/person/1235710401-Jean-Philippe-Gossart"><b>Jean-Philippe Gossart</b></a></td>
# <td class="data">2</td>
# <td>
# 					Second Unit Director of Photography (2)</td>
# <td class="data">$1,466,257,661</td>
# <td class="data">$1,815,159,686</td>
# <td class="data">80.8%</td>
# </tr>
# <tr>
# <td><a href="/person/334170401-Glenn-Freemantle"><b>Glenn Freemantle</b></a></td>
# <td class="data">2</td>
# <td>
# 					Sound Designer (2)					<br/>
# 					Supervising Sound Editor (2)</td>
# <td class="data">$1,466,257,661</td>
# <td class="data">$4,802,278,943</td>
# <td class="data">30.5%</td>
# </tr>
# <tr>
# <td><a href="/person/153330401-Stuart-Wilson"><b>Stuart Wilson</b></a></td>
# <td class="data">2</td>
# <td>
# 					Sound Mixer (2)</td>
# <td class="data">$1,878,290,224</td>
# <td class="data">$8,271,673,548</td>
# <td class="data">22.7%</td>
# </tr>
# <tr>
# <td><a href="/person/349130401-Peter-Dorme"><b>Peter Dorme</b></a></td>
# <td class="data">2</td>
# <td>
# 					Set Designer (1)					<br/>
# 					Art Director (1)</td>
# <td class="data">$1,789,085,181</td>
# <td class="data">$4,528,659,465</td>
# <td class="data">39.5%</td>
# </tr>
# <tr>
# <td><a href="/person/426570401-Les-Tomkins"><b>Les Tomkins</b></a></td>
# <td class="data">2</td>
# <td>
# 					Art Director (2)</td>
# <td class="data">$1,466,257,661</td>
# <td class="data">$4,154,759,725</td>
# <td class="data">35.3%</td>
# </tr>
# <tr>
# <td><a href="/person/367280401-Christian-Huband"><b>Christian Huband</b></a></td>
# <td class="data">2</td>
# <td>
# 					Art Director (2)</td>
# <td class="data">$1,466,257,661</td>
# <td class="data">$3,016,831,874</td>
# <td class="data">48.6%</td>
# </tr>
# <tr>
# <td><a href="/person/423120401-Kate-Grimble"><b>Kate Grimble</b></a></td>
# <td class="data">2</td>
# <td>
# 					Art Director (2)</td>
# <td class="data">$1,466,257,661</td>
# <td class="data">$2,052,633,319</td>
# <td class="data">71.4%</td>
# </tr>
# <tr>
# <td><a href="/person/486940401-Huw-Arthur"><b>Huw Arthur</b></a></td>
# <td class="data">2</td>
# <td>
# 					Art Director (2)</td>
# <td class="data">$1,466,257,661</td>
# <td class="data">$3,259,731,573</td>
# <td class="data">45.0%</td>
# </tr>
# <tr>
# <td><a href="/person/654550401-Hayley-Easton-Street"><b>Hayley Easton-Street</b></a></td>
# <td class="data">2</td>
# <td>
# 					Art Director (2)</td>
# <td class="data">$1,466,257,661</td>
# <td class="data">$4,318,714,137</td>
# <td class="data">34.0%</td>
# </tr>
# <tr>
# <td><a href="/person/344050401-Dennis-Leonard"><b>Dennis Leonard</b></a></td>
# <td class="data">2</td>
# <td>
# 					Supervising Sound Editor (2)</td>
# <td class="data">$1,776,324,929</td>
# <td class="data">$9,877,123,438</td>
# <td class="data">18.0%</td>
# </tr>
# <tr>
# <td><a href="/person/141440401-Randy-Thom"><b>Randy Thom</b></a></td>
# <td class="data">2</td>
# <td>
# 					Sound Designer (2)					<br/>
# 					Supervising Sound Editor (1)</td>
# <td class="data">$1,776,324,929</td>
# <td class="data">$20,133,396,860</td>
# <td class="data">8.8%</td>
# </tr>
# <tr>
# <td><a href="/person/769510401-Anna-Worley"><b>Anna Worley</b></a></td>
# <td class="data">2</td>
# <td>
# 					Script Supervisor (2)</td>
# <td class="data">$1,466,257,661</td>
# <td class="data">$2,602,040,396</td>
# <td class="data">56.4%</td>
# </tr>
# <tr>
# <td><a href="/person/464710401-Marianne-Jenkins"><b>Marianne Jenkins</b></a></td>
# <td class="data">2</td>
# <td>
# 					Post-Production Executive (2)</td>
# <td class="data">$1,466,257,661</td>
# <td class="data">$4,448,440,629</td>
# <td class="data">33.0%</td>
# </tr>
# <tr>
# <td><a href="/person/449280401-Tim-Grover"><b>Tim Grover</b></a></td>
# <td class="data">2</td>
# <td>
# 					Post-Production Supervisor (2)</td>
# <td class="data">$1,466,257,661</td>
# <td class="data">$3,388,876,201</td>
# <td class="data">43.3%</td>
# </tr>
# <tr>
# <td><a href="/person/567910401-Bjorn-Ole-Schroeder"><b>Bjorn Ole Schroeder</b></a></td>
# <td class="data">2</td>
# <td>
# 					Sound Effects Editor (1)					<br/>
# 					Dialogue Editor (1)</td>
# <td class="data">$1,692,716,131</td>
# <td class="data">$2,306,487,963</td>
# <td class="data">73.4%</td>
# </tr>
# <tr>
# <td><a href="/person/214820401-Mark-Burton"><b>Mark Burton</b></a></td>
# <td class="data">2</td>
# <td>
# 					First Assistant Editor (2)</td>
# <td class="data">$1,466,257,661</td>
# <td class="data">$2,971,340,440</td>
# <td class="data">49.3%</td>
# </tr>
# <tr>
# <td><a href="/person/1235770401-Olly-Young"><b>Olly Young</b></a></td>
# <td class="data">2</td>
# <td>
# 					Visual Effects Producer (2)</td>
# <td class="data">$1,466,257,661</td>
# <td class="data">$1,815,159,686</td>
# <td class="data">80.8%</td>
# </tr>
# <tr>
# <td><a href="/person/254980401-Roger-Guyett"><b>Roger Guyett</b></a></td>
# <td class="data">2</td>
# <td>
# 					Visual Effects Supervisor (2)</td>
# <td class="data">$1,770,663,943</td>
# <td class="data">$11,783,226,205</td>
# <td class="data">15.0%</td>
# </tr>
# <tr>
# <td><a href="/person/614350401-Niv-Adiri"><b>Niv Adiri</b></a></td>
# <td class="data">2</td>
# <td>
# 					Re-recording Mixer (2)					<br/>
# 					Sound Designer (1)</td>
# <td class="data">$1,466,257,661</td>
# <td class="data">$3,934,328,147</td>
# <td class="data">37.3%</td>
# </tr>
# <tr>
# <td><a href="/person/423160401-Ian-Tapp"><b>Ian Tapp</b></a></td>
# <td class="data">2</td>
# <td>
# 					Re-recording Mixer (2)</td>
# <td class="data">$1,466,257,661</td>
# <td class="data">$3,093,886,843</td>
# <td class="data">47.4%</td>
# </tr>
# <tr>
# <td><a href="/person/311510401-Andy-Nelson"><b>Andy Nelson</b></a></td>
# <td class="data">2</td>
# <td>
# 					Re-recording Mixer (2)</td>
# <td class="data">$1,466,257,661</td>
# <td class="data">$22,746,885,500</td>
# <td class="data">6.4%</td>
# </tr>
# <tr>
# <td><a href="/person/678790401-Gillian-Dodders"><b>Gillian Dodders</b></a></td>
# <td class="data">2</td>
# <td>
# 					Supervising Dialogue/ADR Editor (2)</td>
# <td class="data">$1,466,257,661</td>
# <td class="data">$2,713,414,958</td>
# <td class="data">54.0%</td>
# </tr>
# <tr>
# <td><a href="/person/376500401-Anna-Pinnock"><b>Anna Pinnock</b></a></td>
# <td class="data">2</td>
# <td>
# 					Set Decorator (2)</td>
# <td class="data">$1,466,257,661</td>
# <td class="data">$6,883,888,769</td>
# <td class="data">21.3%</td>
# </tr>
# <tr>
# <td><a href="/person/1282640401-Pamela-Joyce"><b>Pamela Joyce</b></a></td>
# <td class="data">2</td>
# <td>
# 					Production Supervisor (2)</td>
# <td class="data">$1,466,257,661</td>
# <td class="data">$1,719,252,221</td>
# <td class="data">85.3%</td>
# </tr>
# </tr></table>
# </p></div>
# </div>
# <script src="/resources/js/activatables.js" type="text/javascript"></script>
# <script>
# activatables('tab', ['summary', 'video', 'news', 'acting', 'technical']);</script>
# <script type="text/javascript">
# 				var table_1 = $('#franchise_movies_overview').DataTable(
# 				{ 'order': [[ 0, 'desc' ]], 'pageLength': 150, 'aoColumns': [ { 'orderSequence': [ 'desc', 'asc' ] }, { 'orderSequence': [ 'asc', 'desc' ] }, { 'orderSequence': [ 'desc', 'asc' ] }, { 'orderSequence': [ 'desc', 'asc' ] }, { 'orderSequence': [ 'desc', 'asc' ] }, { 'orderSequence': [ 'desc', 'asc' ] }],  'paging':   false, 'searching': false, 'bInfo': false, 'columns': [ { 'type': 'html-num-fmt' }, null, { 'type': 'html-num-fmt' }, { 'type': 'html-num-fmt' }, { 'type': 'html-num-fmt' }, { 'type': 'html-num-fmt' }],
# 				keepConditions: true, 'bAutoWidth': true }
# 				);
# 				</script>
# <a href="https://beta.productionnext.com/register/the-numbers"><img alt="ProductionNext" border="0" height="90" src="/images/pn-banner-official.gif" style="margin:auto; display:block; padding:3px;" width="728"/></a>
# <center>
# <div id="rcjsload_7ce5b7"></div>
# <script type="text/javascript">
# (function() {
# var referer="";try{if(referer=document.referrer,"undefined"==typeof referer)throw"undefined"}catch(exception){referer=document.location.href,(""==referer||"undefined"==typeof referer)&&(referer=document.URL)}referer=referer.substr(0,700);
# var rcel = document.createElement("script");
# rcel.id = 'rc_' + Math.floor(Math.random() * 1000);
# rcel.type = 'text/javascript';
# rcel.src = "https://trends.revcontent.com/serve.js.php?w=71375&t="+rcel.id+"&c="+(new Date()).getTime()+"&width="+(window.outerWidth || document.documentElement.clientWidth)+"&referer="+referer;
# rcel.async = true;
# var rcds = document.getElementById("rcjsload_7ce5b7"); rcds.appendChild(rcel);
# })();
# </script></center>
#
# <div id="sidebar">
# <h1>Quick Links</h1>
# <ul style="display: inline-block;font-size: 100%;">
# <li><a href="/weekly-deg-watched-at-home-chart">DEG Watched at Home Top 20</a></li>
# <li><a href="/weekly-video-sales-chart">Weekly DVD+Blu-ray Chart</a></li>
# <li><a href="/news/">News</a></li>
# <li><a href="/movies/release-schedule">Release Schedule</a></li>
# <li><a href="/daily-box-office-chart">Daily Box Office</a></li>
# <li><a href="/weekend-box-office-chart">Weekend Box Office</a></li>
# <li><a href="/weekly-box-office-chart">Weekly Box Office</a></li>
# <li><a href="/market/2019/summary">Annual Box Office</a></li>
# <li><a href="/box-office-records/">Box Office Records</a></li>
# <li><a href="/international-charts-overview">International Box Office</a></li>
# <li><a href="/market/distributors">Distributors</a></li>
# <li><a href="/box-office-star-records/">People Records</a></li>
# <li><a href="/people-ind">People Index</a></li>
# <li><a href="/market/genres">Genre Tracking</a></li>
# <li><a href="/movies/keywords">Keyword Tracking</a></li>
# <li><a href="/movies/franchises">Franchises</a></li>
# <li><a href="/research-tools">Research Tools</a></li>
# <li><a href="/bankability">Bankability Index</a></li>
# </ul>
# <center>
# <h1>Search</h1>
# <form action="/custom-search" method="get">
# <input name="searchterm" onkeyup="if (event.keyCode == 13) { this.form.submit(); return false; }" size="36" type="text" value=""/>
# </form>
# </center>
# <br/>
# <center>
# <script type="text/javascript"><!--
# e9 = new Object();
# e9.size = "300x250";
# //--></script>
# <script src="//tags.expo9.exponential.com/tags/TheNumbers/ROS/tags.js" type="text/javascript"></script>
# </center>
# <h1><a class="inh1" href="/movies/most-anticipated">Most Anticipated Movies</a></h1>
# <ul>
# <li><a href="/movie/Tenet-(2020)#tab=summary">Tenet</a></li>
# <li><a href="/movie/Scoob#tab=summary">Scoob!</a></li>
# <li><a href="/movie/Sound-of-Freedom#tab=summary">Sound of Freedom</a></li>
# <li><a href="/movie/No-Time-to-Die#tab=summary">No Time to Die</a></li>
# <li><a href="/movie/Mulan-(2020)#tab=summary">Mulan</a></li>
# <li><a href="/movie/Dune-(2020)#tab=summary">Dune</a></li>
# <li><a href="/movie/Quiet-Place-Part-II-A-(2020)#tab=summary">A Quiet Place: Part II</a></li>
# <li><a href="/movie/Infinite-(2020)#tab=summary">Infinite</a></li>
# <li><a href="/movie/Black-Widow-(2020)#tab=summary">Black Widow</a></li>
# <li><a href="/movie/Fantastic-Beasts-and-Where-to-Find-Them-3-(2021)#tab=summary">Fantastic Beasts and Where to Find Them 3</a></li>
# </ul>
# <center>
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- right panel 2 main -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-0505053220181058" data-ad-format="rectangle" data-ad-slot="1574707950" style="display:block"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script></center>
# <h1><a class="inh1" href="/movies/trending">Trending Movies</a></h1>
# <ul>
# <li><a href="/movie/Doctor-Sleep-(2019)#tab=summary">Doctor Sleep</a></li>
# <li><a href="/movie/Little-Women-(2019)#tab=summary">Little Women</a></li>
# <li><a href="/movie/Escape-From-Pretoria-(UK)#tab=summary">Escape From Pretoria</a></li>
# <li><a href="/movie/Midway-(2019)#tab=summary">Midway</a></li>
# <li><a href="/movie/Birds-of-Prey-(And-the-Fantabulous-Emancipation-of-One-Harley-Quinn)-(2020)#tab=summary">Birds of Prey (And the Fantabulous Emancipation of One Harley Quinn)</a></li>
# <li><a href="/movie/Avengers-Endgame-(2019)#tab=summary">Avengers: Endgame</a></li>
# <li><a href="/movie/Star-Wars-The-Rise-of-Skywalker-(2019)#tab=summary">Star Wars: The Rise of Skywalker</a></li>
# <li><a href="/movie/Playing-with-Fire-(2019)#tab=summary">Playing with Fire</a></li>
# <li><a href="/movie/Trolls-World-Tour-(2020)#tab=summary">Trolls: World Tour</a></li>
# <li><a href="/movie/Frozen-II-(2019)#tab=summary">Frozen II</a></li>
# </ul>
# <center>
# <!-- Insticator API Fire Widget -->
# <div id="insticator-container">
# <div id="div-insticator-ad-1"></div>
# <div id="insticator-embed"></div>
# <div id="div-insticator-ad-2"></div>
# <script data-cfasync="false" type="text/javascript">
# /*<![CDATA[*/Insticator.ad.loadAd("div-insticator-ad-1");Insticator.ad.loadAd("div-insticator-ad-2");Insticator.load("em",{id : "26fd9024-230f-4e85-8bb3-d545d8a710d4"})/*]]>*/
# </script>
# </div>
# <!-- End Insticator API Fire Widget --></center>
# <h1><a class="inh1" href="/box-office-star-records/domestic/lifetime-acting/top-grossing-leading-stars">Top Domestic Leading Stars</a></h1>
# <ul>
# <ul style="display: inline-block;font-size: 100%;">
# <li><a href="/person/670401-L-Jackson-Samuel">Samuel L. Jackson</a></li>
# <li><a href="/person/41500401-Jr-Downey-Robert">Robert Downey, Jr.</a></li>
# <li><a href="/person/650401-Tom-Hanks">Tom Hanks</a></li>
# <li><a href="/person/72460401-Scarlett-Johansson">Scarlett Johansson</a></li>
# <li><a href="/person/31530401-Bradley-Cooper">Bradley Cooper</a></li>
# </ul><ul style="display: inline-block;font-size: 100%;">
# <li><a href="/person/45600401-Chris-Evans">Chris Evans</a></li>
# <li><a href="/person/64300401-Chris-Hemsworth">Chris Hemsworth</a></li>
# <li><a href="/person/126330401-Zoe-Saldana">Zoe Saldana</a></li>
# <li><a href="/person/116290401-Chris-Pratt">Chris Pratt</a></li>
# <li><a href="/person/600401-Harrison-Ford">Harrison Ford</a></li>
# </ul>
# <center>
# <!-- Insticator API Fire Widget Ads Code -->
# <div id="div-insticator-ad-3"></div>
# <script data-cfasync="false" type="text/javascript">
# /*<![CDATA[*/Insticator.ad.loadAd("div-insticator-ad-3");/*]]>*/
# </script>
# <!-- End Insticator API Fire Widget Ads Code --></center>
# </ul></div>
# <div id="footer">
# <b>© 1997-2020 <a href="https://www.nashinfoservices.com" rel="nofollow">Nash Information Services, LLC</a>. All rights reserved.</b><br/>
# <b>The Numbers is a registered trademark of Nash Information Services, LLC</b><br/>
# <b>For comments or corrections, please email us at <a href="mailto:corrections@the-numbers.com">corrections@the-numbers.com</a></b>
# <br/><br/>
# <a href="/privacy">Privacy Policy</a> - <a href="/about">About Us</a> - <a href="/glossary">Glossary</a>
# </div>

# %%
numbers_summary = page_soup.find('table',{'id':'franchise_movies_overview'})
table_rows= numbers_summary.select('table tbody tr')

movies = []
for elem in table_rows: # we expect all rows
    movies.append(elem.find_all('td')[1].getText())

print(movies)
# Out:
# ['Fantastic Beasts and Where …', 'Fantastic Beasts: The Crime…', 'Fantastic Beasts and Where …', 'The Harry Potter IMAX Marathon', 'Harry Potter and the Deathl…', 'Harry Potter and the Deathl…', 'Harry Potter and the Half-B…', 'Harry Potter and the Order …', 'Harry Potter and the Goblet…', 'Harry Potter and the Prison…', 'Harry Potter and the Chambe…', 'Harry Potter and the Sorcer…']

# %%
production_budget = []
for elem in table_rows: # we expect all rows
    production_budget.append(elem.find_all('td')[2].getText())

print(production_budget)
# Out:
# ['', '$200,000,000', '$180,000,000', '', '$125,000,000', '$125,000,000', '$250,000,000', '$150,000,000', '$150,000,000', '$130,000,000', '$100,000,000', '$125,000,000']
