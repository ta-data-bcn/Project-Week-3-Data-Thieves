# %% [markdown]
# # The Top 10'000 Books from Goodreads on Kaggle

# %%
import pandas as pd
import numpy as np
import requests
import re
import json

# %% [markdown]
# Source of data can be found in the source.txt file. Very useful information is in the latter two data sets, they have a bug, am working on fixing it. Data sets 1-5 will require some work merging and organizing.

# %% [markdown]
# ### Data Set "Books"

# %%
data1 = pd.read_csv(r'data/books.csv')
books = pd.DataFrame(data1)
books.head()
# Out:
#    id  book_id  best_book_id  work_id  books_count       isbn        isbn13  \
# 0   1  2767052       2767052  2792775          272  439023483  9.780439e+12
# 1   2        3             3  4640799          491  439554934  9.780440e+12
# 2   3    41865         41865  3212258          226  316015849  9.780316e+12
# 3   4     2657          2657  3275794          487   61120081  9.780061e+12
# 4   5     4671          4671   245494         1356  743273567  9.780743e+12
#
#                        authors  original_publication_year  \
# 0              Suzanne Collins                     2008.0
# 1  J.K. Rowling, Mary GrandPré                     1997.0
# 2              Stephenie Meyer                     2005.0
# 3                   Harper Lee                     1960.0
# 4          F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# 0                          The Hunger Games  ...       4780653
# ...

# %% [markdown]
# ### Data Set "Book Tags"

# %%
data2 = pd.read_csv(r'data/book_tags.csv')
book_tags = pd.DataFrame(data2)
book_tags.head()
# Out:
#    goodreads_book_id  tag_id   count
# 0                  1   30574  167697
# 1                  1   11305   37174
# 2                  1   11557   34173
# 3                  1    8717   12986
# 4                  1   33114   12716

# %% [markdown]
# ### Data Set "Tags"

# %%
data3 = pd.read_csv(r'data/tags.csv')
tags = pd.DataFrame(data3)
tags.head()
# Out:
#    tag_id tag_name
# 0       0        -
# 1       1     --1-
# 2       2    --10-
# 3       3    --12-
# 4       4   --122-

# %%
tags_list = list(tags.tag_name.unique())
tags_list # this is a mess
# Out:
# ['-',
#  '--1-',
#  '--10-',
#  '--12-',
#  '--122-',
#  '--166-',
#  '--17-',
#  '--19-',
#  '--2-',
#  '--258-',
#  '--3-',
#  '--33-',
#  '--4-',
#  '--5-',
#  '--51-',
#  '--6-',
#  '--62-',
#  '--8-',
#  '--99-',
#  '--available-at-raspberrys--',
#  '-2001--',
#  '-calif--',
#  '-d-c--',
#  '-dean',
#  '-england-',
#  '-fiction',
#  '-fictional',
#  '-fictitious',
#  '-football-',
#  '-george',
#  '-gr-',
#  '-history',
#  '-imaginary',
#  '-italy-',
#  '-la--',
#  '-los',
#  '-mass--',
#  '-murder-',
#  '-n-y--',
#  '-non-poetry-',
#  '-performing',
#  '-post',
#  '-psychology-',
#  '-read',
#  '-single',
#  '-specific',
#  '-television',
#  '0',
#  '0-0-0-0cant-find',
#  '0-0-bingo',
#  '0-4-star-rating',
#  '0-a-find-2016-summer-00',
#  '0-all2',
#  '0-best-picture-younger',
#  '0-boxed',
#  '0-c',
#  '0-eric-s-books',
#  '0-house-lbkc',
#  '0-kindle',
#  '0-love-funny',
#  '0-made-me-cry-moved-me',
#  '0-nonfiction',
#  '0-owned',
#  '0-paperback',
#  '0-pgs-200-to-299',
# ...

# %% [markdown]
# ### Data Set "Ratings"

# %%
data4 = pd.read_csv(r'data/ratings.csv')
ratings = pd.DataFrame(data4)
ratings.head()
# Out:
#    book_id  user_id  rating
# 0        1      314       5
# 1        1      439       3
# 2        1      588       5
# 3        1     1169       4
# 4        1     1185       4

# %% [markdown]
# ### Data Set "to_read"

# %%
data5 = pd.read_csv(r'data/to_read.csv')
to_read = pd.DataFrame(data5)
to_read.head()
# Out:
#    user_id  book_id
# 0        1      112
# 1        1      235
# 2        1      533
# 3        1     1198
# 4        1     1874

# %% [markdown]
# ### Data Set "Top 100 Books"

# %%
data6 = pd.read_csv('data/top_100_books.csv', encoding = "ISO-8859-1")
top100 = pd.DataFrame(data6)
top100.head()
# Out:
#    idx  rank2                 book2         author2  ratings2  reviews2  \
# 0    1      1              Becoming  Michelle Obama       4.9     13347
# 1    2      2  Girl, Wash Your Face   Rachel Hollis       4.6     10521
# 2    3      3      The Wonky Donkey     Craig Smith       4.7      5503
# 3    4      4         Fire and Fury   Michael Wolff       4.2      9931
# 4    5      5                  Fear    Bob Woodward       4.5      3220
#
#        type2  price2
# 0  Hardcover   17.95
# 1  Hardcover   13.63
# 2  Paperback    4.99
# 3  Hardcover   15.57
# 4  Hardcover   15.47

# %% [markdown]
# ### Data Set "NYT Bestsellers"

# %%
data7 = pd.read_csv('data/nyt_bestsellers.csv', encoding = "ISO-8859-1").drop(columns='Unnamed: 0')

nyt_bestsellers = pd.DataFrame(data7)
nyt_bestsellers.head()
# Out:
#                                         book_name     genre
# 0     I Love Dad with The Very Hungry Caterpillar  children
# 1                The Wonderful Things You Will Be  children
# 2  Dr. Seuss's I Love Pop!: A Celebration of Dads  children
# 3                              Dragons Love Tacos  children
# 4                        How to Babysit a Grandpa  children

# %%
nyt_bestsellers.genre.unique()
# Out:
# array(['children', 'fiction', 'non-fiction', 'misc', 'young_adult'],
#       dtype=object)
