# %% [markdown]
# # Characters

# %%
import pandas as pd
import numpy as np

# %%
characters = pd.read_csv(r'data/Characters.csv', encoding = "ISO-8859-1", sep=';')
characters.head()
# Out:
#    Id                                     Name  Gender  \
# 0   1                       Harry James Potter    Male
# 1   2                    Ronald Bilius Weasley    Male
# 2   3                    Hermione Jean Granger  Female
# 3   4  Albus Percival Wulfric Brian Dumbledore    Male
# 4   5                            Rubeus Hagrid    Male
#
#                                                  Job       House  \
# 0                                            Student  Gryffindor
# 1                                            Student  Gryffindor
# 2                                            Student  Gryffindor
# 3                                         Headmaster  Gryffindor
# 4  Keeper of Keys and Grounds | Professor of Care...  Gryffindor
#
#                                  Wand              Patronus  \
# 0         11"  Holly  phoenix feather                  Stag
# 1          12" Ash unicorn tail hair   Jack Russell terrier
# ...

# %%
characters.House.unique()
# Out:
# array(['Gryffindor', 'Ravenclaw', 'Slytherin', nan, 'Hufflepuff',
#        'Beauxbatons Academy of Magic', 'Durmstrang Institute'],
#       dtype=object)

# %%
characters.Wand.unique()
# Out:
# array(['11"  Holly  phoenix feather', '12" Ash unicorn tail hair ',
#        '10¾"  vine wood dragon heartstring',
#        '15" Elder Thestral tail hair core', '16"  Oak unknown core',
#        '13" Cherry unicorn hair', 'Unknown', '10¼"  Willow  unknown core',
#        '11"  Mahogany  unknown core', '10¼" Cypress unicorn hair',
#        '9¼" Chestnut dragon heartstring', '12"  Ash unicorn tail hair',
#        '9½" Fir dragon heartstring', '9" Alder unicorn hair bendy',
#        '9" Cherry dragon heartstring', '9 ½\x94 hazel unicorn hair core',
#        '12¾" Hornbeam dragon heartstring', '10" Hawthorn unicorn hair',
#        '12¾" Walnut dragon heartstring', '8" Birch dragon heartstring',
#        '10¼" Cedar dragon heartstring fairly flexible',
#        'Elm and dragon heartstring', '13½" Yew phoenix feather core',
#        'snakewood, Basilisk horn', nan, '12¼", Ash, unicorn hair',
#        'Inherited by his son, Neville. It was broken in battle at the Department of Mysteries.',
# ...

# %%
characters.loc[characters['Name'] == 'Luna Lovegood']
# Out:
#     Id           Name  Gender      Job      House     Wand Patronus Species  \
# 34  35  Luna Lovegood  Female  Student  Ravenclaw  Unknown     Hare   Human
#
#                 Blood status   Hair colour    Eye colour  \
# 34  Pure-blood or half-blood  Dirty-blonde  Pale silvery
#
#                                               Loyalty            Skills  \
# 34  Dumbledore's Army |Hogwarts School of Witchcra...  Spotting Nargles
#
#                 Birth Death
# 34  13 February, 1981   NaN

# %%
characters.loc[characters['Name'] == 'Hermione Jean Granger']
# Out:
#    Id                   Name  Gender      Job       House  \
# 2   3  Hermione Jean Granger  Female  Student  Gryffindor
#
#                                  Wand Patronus Species Blood status  \
# 2  10¾"  vine wood dragon heartstring    Otter   Human  Muggle-born
#
#   Hair colour Eye colour                                            Loyalty  \
# 2       Brown      Brown  Dumbledore's Army | Order of the Phoenix | Hog...
#
#               Skills               Birth Death
# 2  Almost everything  19 September, 1979   NaN

# %% [markdown]
# # Spells

# %%
spells = pd.read_csv(r'data/Spells.csv', encoding = "ISO-8859-1", sep=';')
spells
# Out:
#                                   Name         Incantation  \
# 0                      Summoning Charm               Accio
# 1                             Age Line             Unknown
# 2                   Water-Making Spell           Aguamenti
# 3     Launch an object up into the air    Alarte Ascendare
# 4    Albus Dumbledore's Forceful Spell             Unknown
# ..                                 ...                 ...
# 296                          Waddiwasi           Waddiwasi
# 297                   Washing up spell             Unknown
# 298                   Levitation Charm  Wingardium Leviosa
# 299                       White sparks             Unknown
# 300                            Episkey             Episkey
#
#                      Type                                             Effect  \
# 0                   Charm                                  Summons an object
# 1                   Charm  Prevents people above or below a certain age f...
# ...

# %%
spells.loc[spells['Incantation'] == 'Expecto Patronum']
# Out:
#               Name       Incantation   Type                      Effect  \
# 91  Patronus Charm  Expecto Patronum  Charm  Conjures a spirit guardian
#
#      Light
# 91  Silver

# %%
spells.Light.unique()
# Out:
# array(['None', 'Blue', 'Icy blue', 'Red',
#        'Invisible, blue, yellow, or purple', nan, 'Purple',
#        'Swirl of gold', 'Ice Blue', 'Green', 'Orange', 'White',
#        'Bright blue', 'Red or Purple', 'Pink', 'Orange or Purple',
#        'Fiery Orange', 'Red or None', 'Violet', 'White or Red',
#        'Light green, pink or red', 'Fiery orange', 'Yellow or Purple',
#        'Bluish-white', 'Silver', 'Scarlet', 'Blueish white', 'Fire',
#        'Crimson and gold', 'Fiery scarlet', 'Grey', 'Dark Red', 'Gold ',
#        'Orange or Green', 'Turquoise', 'Orange and Red',
#        'Psychadelic transparent wave', 'Bright yellow', 'None or Green',
#        'Gold', 'Invisible on its own, reflects light of spell',
#        'None (bang)', 'None (haze)', 'Purple or Orange', 'Crystal clear',
#        'Yellow', 'Black smoke'], dtype=object)

# %% [markdown]
# # Potions

# %%
potions = pd.read_csv(r'data/Potions.csv', encoding = "ISO-8859-1", sep=';')
potions
# Out:
#                        Name  \
# 0             Ageing Potion
# 1                Amortentia
# 2   Antidote to Veritaserum
# 3         Babbling Beverage
# 4   Baruffio's Brain Elixir
# ..                      ...
# 67               Weedosoros
# 68            Wideye Potion
# 69    Wit-Sharpening Potion
# 70         Wolfsbane Potion
# 71    Wound-cleaning potion
#
#                                     Known ingredients  \
# 0                              Newt spleens , Bananas
# 1                                                 NaN
# 2                                                 NaN
# 3                   Valerian sprigs, Aconite, Dittany
# 4   Leaping Toadstools, Frog Brains, Runespoor egg...
# ..                                                ...
# 67                                                NaN
# 68  6 snake fangs, 4 measures of Standard Ingredie...
# 69  Ground scarab beetles, Cut ginger roots, Armad...
# 70                                          Wolfsbane
# ...

# %%
potions.loc[potions['Name'] == 'Wideye Potion']['Known ingredients']
# Out:
# 68    6 snake fangs, 4 measures of Standard Ingredie...
# Name: Known ingredients, dtype: object

# %%
potions['Known ingredients'].unique()
# Out:
# array(['Newt spleens , Bananas', nan, 'Valerian sprigs, Aconite, Dittany',
#        'Leaping Toadstools, Frog Brains, Runespoor eggs, Powdered dragon claw',
#        'Scurvy grass, Lovage, Sneezewort',
#        'Bursting mushrooms, Salamander blood, Wartcap powder',
#        'Dragon claw', 'Dark yellow in colour',
#        'Dried nettles, 6 snake fangs, 4 horned slugs, 2 porcupine quills, Pungous Onions, Flobberworm Mucus, Ginger root, Shrake spines',
#        'Bundimun Ooze, Streeler shells, Dragon liver, Hemlock essence, Tormentil tincture, Cowbane essence',
#        'Standard potioning water, Powdered Root of Asphodel, Infusion of Wormwood, Valerian root, A Sopophorous bean, A Sloth brain',
#        'Powdered moonstone, Syrup of Hellebore, Powdered Unicorn horn, Powdered Porcupine quills',
#        'Emerald green in colour, Glows phosphorescently',
#        "Philosopher's Stone",
#        'Shrivelfig, Porcupine quills, Peppermint sprigs, Sopophorous beans, Wormwood',
# ...
