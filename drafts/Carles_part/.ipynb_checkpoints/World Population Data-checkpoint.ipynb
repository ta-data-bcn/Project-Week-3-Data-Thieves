# %%
import pandas as pd
import json
import numpy as np

# %%
#call the data
ppl = pd.read_csv('5e2073ba-5d1d-405c-8fad-5d51b9df65ec_Data.csv')

#create a DataFrame and a save copy of the data
ppl_df = pd.DataFrame(ppl)
ppl_df_copy = ppl_df.copy()
ppl_df
# Out:
#                                           Series Name        Series Code  \
# 0                                   Population, total        SP.POP.TOTL
# 1        Population ages 0-14 (% of total population)  SP.POP.0014.TO.ZS
# 2       Population ages 15-64 (% of total population)  SP.POP.1564.TO.ZS
# 3   Population ages 65 and above (% of total popul...  SP.POP.65UP.TO.ZS
# 4   Age dependency ratio, young (% of working-age ...     SP.POP.DPND.YG
# 5   Age dependency ratio, old (% of working-age po...     SP.POP.DPND.OL
# 6                Death rate, crude (per 1,000 people)     SP.DYN.CDRT.IN
# 7                Birth rate, crude (per 1,000 people)     SP.DYN.CBRT.IN
# 8                                                 NaN                NaN
# 9                                                 NaN                NaN
# 10                                                NaN                NaN
# 11   Data from database: World Development Indicators                NaN
# ...

# %%
#delete indexing
blankIndex=[''] * len(ppl_df)
ppl_df.index=blankIndex

# %%
#clean unnecessary columns
ppl_df = ppl_df.drop(columns=['Country Name', 'Country Code', 'Series Code'])

#reduce the list for only the data we need
ppl_df = ppl_df.head(4)
ppl_df
# Out:
#                                         Series Name  1960 [YR1960]  \
#                                   Population, total   3.031438e+09
#        Population ages 0-14 (% of total population)   3.717277e+01
#       Population ages 15-64 (% of total population)   5.785721e+01
#   Population ages 65 and above (% of total popul...   4.970019e+00
#
#   1961 [YR1961]  1962 [YR1962]  1963 [YR1963]  1964 [YR1964]  1965 [YR1965]  \
#    3.072481e+09   3.125457e+09   3.190564e+09   3.256065e+09   3.322973e+09
#    3.734940e+01   3.757152e+01   3.778132e+01   3.790233e+01   3.791627e+01
#    5.763363e+01   5.738587e+01   5.716639e+01   5.704094e+01   5.702587e+01
#    5.016976e+00   5.042611e+00   5.052289e+00   5.056728e+00   5.057858e+00
#
#   1966 [YR1966]  1967 [YR1967]  1968 [YR1968]  ...  2010 [YR2010]  \
#    3.393032e+09   3.462460e+09   3.532827e+09  ...   6.921872e+09
#    3.800383e+01   3.795737e+01   3.783012e+01  ...   2.701544e+01
# ...

# %%
#create a list for the columns
years = ['Year']
for i in range(1960,2020):
    years.append(i)
ppl_df.columns = [years]

#Transpose the data so is easier to analy
ppl_df = ppl_df.T
ppl_df
# Out:
#                                                                        \
# Year  Population, total  Population ages 0-14 (% of total population)
# 1960        3.03144e+09                                       37.1728
# 1961        3.07248e+09                                       37.3494
# 1962        3.12546e+09                                       37.5715
# 1963        3.19056e+09                                       37.7813
# ...                 ...                                           ...
# 2015        7.33896e+09                                       26.2157
# 2016        7.42428e+09                                       26.0741
# 2017        7.50907e+09                                       25.9353
# 2018        7.59193e+09                                        25.796
# 2019         7673533972                              25.6488355687986
#
#                                                      \
# Year  Population ages 15-64 (% of total population)
# ...

# %%
#Mar intermision

# %%
def get_data():
    return ppl_df
